# %% [markdown]
# # Creación y Almacenamiento de Embeddings en ChromaDB
#
# En el presente Notebook se crearán la documentación base del esquema reducido con el que trabajaremos, basada en el `information_schema` correspondiente, que luego se nutrirá por fuera con mayor información relevante para negocio.
#
# Adicionalmente, por fuera del Notebook, se confeccionará más documentación, como reglas de negocio y few-shot examples para, finalmente, obtener chunks de todos estos documentos y crear y almacenar los mismos, con su metadata asociada, en una base de datos vectorial de Chroma DB.

# %% [markdown]
# ---
#
# ## Inicialización

# %% [markdown]
# ### Librerías

# %%
# Importamos librerías estándar
import sys
from pathlib import Path
from dotenv import load_dotenv
import yaml
import json
from IPython.display import Markdown

from collections import OrderedDict
import pandas as pd

from langchain.prompts import ChatPromptTemplate
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI
from langchain.schema import StrOutputParser


# Aplicamos operaciones sobre librerías estándar
load_dotenv('../.env')
pd.set_option('display.max_columns', None)
yaml.add_representer(OrderedDict, lambda dumper, data: dumper.represent_dict(data.items()))


# Añadimos el directorio raíz del proyecto al path
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))


# Importamos paquetes personalizados
from src.utils.doc_generators import BaseMdlGenerator
from src.utils.splitters import MdlSplitter, ExtendedMarkdownSplitter, JsonExamplesSplitter
from src.back.embeddings import GenAIExtendedEmbeddingFunction
from src.back.chroma_collections import (
    MdlHierarchicalChromaCollections, 
    ContextEnricherChromaCollection, 
    ExamplesChromaCollection
)

# %% [markdown]
# ### Constantes

# %%
TARGET_DB_NAME = 'adventure_works_dw'
TARGET_SCHEMA_NAME = 'sales'

BASE_QUERY_PATH = '../data/embeddings/auxs/get_information_schema.sql'
OUTPUT_PATH = '../data/embeddings/auxs'
MDL_PATH = '../data/embeddings/documents/MDL_adventure_works_dw.yaml'
BUSINESS_RULES_PATH = '../data/embeddings/documents/business_rules.md'
EXAMPLES_PATH = '../data/embeddings/documents/query_examples.json'

BUSINESS_RULES_CHUNK_SIZE = 2000
BUSINESS_RULES_CHUNK_OVERLAP = int(0.15 * BUSINESS_RULES_CHUNK_SIZE)

CHROMA_DB_PATH = '../data/embeddings/chroma'
TABLES_SUMMARY_COLLECTION_NAME = 'mdl_tables_summary'
COLUMNS_COLLECTION_NAME = 'mdl_columns'
BUSINESS_LOGIC_COLLECTION_NAME = 'business_logic'
EXAMPLES_COLLECTION_NAME = 'query_examples'

AZURE_OPENAI_EMBEDDING_MODEL = 'text-embedding-3-large'
GENAI_EMBEDDING_MODEL = 'gemini-embedding-001'

# %% [markdown]
# ---
#
# ## Fichero YAML con MDL del esquema de interés
#
# ### Obtener fichero base desde `information_schema`
#
# Primero obtendremos un fichero base construido utilizando la query `/data/embeddings/auxs/get_information_schema.sql`, identificada bajo la constante `BASE_QUERY_PATH`, sobre el que luego se añadirá metadata extra. Para esto, previamente, en la sección **Clases personalizadas**, hemos implementado la clase `BaseMdlGenerator`, que contine métodos que nos facilitarán estas tareas.
#
# Mostremos los resultados en Pandas para que sean más vistosos:

# %%
mdl_generator = BaseMdlGenerator(BASE_QUERY_PATH)
information_schema_data = mdl_generator.get_information_schema_data(
    target_db_names= TARGET_DB_NAME,
    target_schema_names= TARGET_SCHEMA_NAME,
    format= 'pandas'
)

information_schema_data
# Out:
#                 db_name schema_name    table_name         column_name  \
# 0    adventure_works_dw       sales  dim_customer        customer_key
# 1    adventure_works_dw       sales  dim_customer       geography_key
# 2    adventure_works_dw       sales  dim_customer  customer_full_name
# 3    adventure_works_dw       sales  dim_customer          birth_date
# 4    adventure_works_dw       sales  dim_customer      marital_status
# ..                  ...         ...           ...                 ...
# 107  adventure_works_dw       sales    fact_sales             freight
# 108  adventure_works_dw       sales    fact_sales          order_date
# 109  adventure_works_dw       sales    fact_sales            due_date
# 110  adventure_works_dw       sales    fact_sales           ship_date
# 111  adventure_works_dw       sales    fact_sales         sale_source
#
#     column_type  primary_key  foreign_key                             target
# 0          INT4         True        False                               None
# 1          INT4        False         True  sales.dim_geography.geography_key
# 2          TEXT        False        False                               None
# 3          DATE        False        False                               None
# 4     BPCHAR(1)        False        False                               None
# ..          ...          ...          ...                                ...
# 107     NUMERIC        False        False                               None
# 108        DATE        False        False                               None
# 109        DATE        False        False                               None
# 110        DATE        False        False                               None
# 111        TEXT        False        False                               None
#
# [112 rows x 8 columns]

# %% [markdown]
# Ahora procederemos a crear el YAML base con el MDL de nuestro esquema, que podremos tomar como punto de partida para luego añadirle metadata extra manualmente:

# %%
mdl_generator.create_base_mdl_files(
    OUTPUT_PATH,
    TARGET_DB_NAME,
    TARGET_SCHEMA_NAME,
    encoding= 'utf-8'
)
# Out:
# ['../data/embeddings/auxs/MDL_adventure_works_dw.yaml']

# %% [markdown]
# ### Creación de embeddings
#
# #### Chunking
#
# Tomando como base el fichero obtenido en el apartado anterior, se ha creado un fichero que del MDL de nuestro esquema de interés que ha sido nutrido con metadata adicional, como descripciones para cada tabla y campo. Este fichero se encuentra en la ruta `/data/embeddings/documents/MDL_adventure_works_dw.yaml`.
#
# Procederemos ahora a procesar este fichero para crear chunks de la información de cada una de las tablas y almacenar sus embeddings en nuestra base de datos vectorial de `chroma_db`, persistida en la ruta `/data/embeddings/chroma_db/`.
#
# En la sección **Clases personalizadas**, hemos implementado la clase `MDLSplitter`, que nos permitirá obtener tanto los chunks correspondientes a los summary de las tablas, como también el de cada una de las columnas que no sean claves dentro de cada tabla:

# %%
mdl_splitter = MdlSplitter()
table_chunks, column_chunks = mdl_splitter.split_documents(MDL_PATH, 'utf-8')

# %% [markdown]
# Veamos ahora el aspecto que tiene, por ejemplo, el chunk de mayor tamaño para cada uno de los tipos:

# %%
max_len = max([len(c.page_content) for c in table_chunks])
print(f'{max_len=}')
print()
print([c.page_content for c in table_chunks if len(c.page_content) == max_len][0])
print()
print([c.metadata for c in table_chunks if len(c.page_content) == max_len][0])
# Out:
# max_len=1020
#
# Database: adventure_works_dw
# Schema: sales
# Table: fact_sales
# Table description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.
# Table PRIMARY KEY:
# - sales_order_number
# - sales_order_line_number
# Table FOREIGN KEYS (Column name, Reference):
# - (product_key, sales.dim_product.product_key)
# - (reseller_key, sales.dim_reseller.reseller_key)
# - (employee_key, sales.dim_sales_person.employee_key)
# - (customer_key, sales.dim_customer.customer_key)
# - (promotion_key, sales.dim_promotion.promotion_key)
# - (sales_territory_key, sales.dim_sales_territory.sales_territory_key)
#
# {'file_name': 'MDL_adventure_works_dw.yaml', 'table_id': '85e28078-2e08-4019-8ce9-3f4bf4438e1c', 'database_name': 'adventure_works_dw', 'schema_name': 'sales', 'table_name': 'fact_sales'}

# %%
max_len = max([len(c.page_content) for c in column_chunks])
print(f'{max_len=}')
print()
print([c.page_content for c in column_chunks if len(c.page_content) == max_len][0])
print()
print([c.metadata for c in column_chunks if len(c.page_content) == max_len][0])
# Out:
# max_len=291
#
# Column name: ship_date
# Column data type: DATE
# Column description: Fecha en la que se envió el pedido al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de preparación de pedidos. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.
#
# {'file_name': 'MDL_adventure_works_dw.yaml', 'table_id': '85e28078-2e08-4019-8ce9-3f4bf4438e1c', 'database_name': 'adventure_works_dw', 'schema_name': 'sales', 'table_name': 'fact_sales', 'column_name': 'ship_date', 'column_data_type': 'DATE'}

# %% [markdown]
# #### LangChain: ChromaDB + Azure OpenAI Embeddings
#
# Ahora haremos una primera implementación de prueba de Chroma valiéndonos de funcionalidades de la librería LangChain, usando un modelo de embeddings de OpenAI a través de Azure AI Foundry.
#
# El primer paso es crear un cliente persistente de ChromaDB, e inicializar las colecciones tanto a nivel de tablas como de columnas. Al inicializar las colecciones, especificaremos que queremos usar como métrica de distancia la distancia de Coseno, que se calcula de la siguiente manera:
#
# $$Distancia = 1 - \frac{A \cdot B}{\|A\| \|B\|}$$
#
# Donde:
# * $A \cdot B$ es el producto punto (producto escalar) de los vectores $A$ y $B$.
# * $∥A∥$ y $∥B∥$ son las magnitudes (o normas euclidianas) de los vectores $A$ y $B$, respectivamente.
# ​
#
# La métrica **Distancia del Coseno** mide solo el ángulo entre vectores, lo que lo hace ideal para embeddings de texto, y particularmente para modelos de embeddings como [`text-embedding-3-large` de OpenAI cuyos valores vienen normalizados](https://help.openai.com/en/articles/8984345-which-distance-function-should-i-use).
#
# Como es fácil ver en su expresión, esta métrica de distancia devuelve valores en el rango $[0, 2]$. Cuanto más cerca de 0, más similares serán los vectores $A$ y $B$. Esto nos deja en la necesidad de definir una métrica de `relevance_score` personalizada, que nos permita reescalar los resultados en valores comprendidos entre $[0, 1]$, siendo los valores más cercanos a 1 indicativo de mayor similitud entre los vectores. Esta métrica la hemos definido en la función `cosine_distance_relevance_score_fn` de la siguiente manera:
#
# $$R_{score} = 1 - \frac{Distancia}{2}$$

# %%
openai_embeddings = AzureOpenAIEmbeddings(model=AZURE_OPENAI_EMBEDDING_MODEL)

mdl_hierarchical_openai_collection = MdlHierarchicalChromaCollections(
    collection_names= (TABLES_SUMMARY_COLLECTION_NAME, COLUMNS_COLLECTION_NAME),
    create_collections_if_not_exists= True,
    clear_collections= True,
    embedding_function= openai_embeddings,
    collections_configuration= {'hnsw': {'space': 'cosine'}}
)

mdl_hierarchical_openai_collection.upsert_hierarchical_data(documents= (table_chunks, column_chunks))
# Out:
# (({'ids': [], 'documents': [], 'metadatas': []},
#   {'ids': [], 'documents': [], 'metadatas': []}),
#  (['8f442e80-6240-4071-88d5-ae9925d729df',
#    '568d6995-778e-4a28-911a-67e997c878d2',
#    '82a8ade4-8109-4f39-8315-5170ff29ad68',
#    '053ca97b-75d2-485f-9c59-b31066329272',
#    'a4f08a0d-fbca-4c3d-8dbe-5369c85b6ac6',
#    'c6bf463a-b903-45af-a89a-39774dc76778',
#    'cf1459a1-09df-4a26-b677-9cc387cd86d9',
#    '314cc945-bd9f-4e63-9d72-90fc3bdf267d',
#    'c85424e7-834c-48ec-9eac-2d21ae76685d',
#    '85e28078-2e08-4019-8ce9-3f4bf4438e1c'],
#   ['01fc4477-7d83-4e0c-9b48-7c98eb1bc731',
#    '8791f4eb-04c8-49ee-91b1-22e47273e7b8',
#    '6a9f379f-9fe1-4d65-acd0-9a33387a6215',
#    'ca91c76f-0cf2-4034-aa89-d588416c6a57',
#    'ff213c1d-0e4b-44d9-9e28-1cce7120de56',
#    '1b12b55e-e44d-4c27-8966-cf5af29b56be',
#    'eb665c0f-2515-4467-9c29-a7cb3e020b0b',
#    'eaa49833-121b-42bc-8de6-6a1673fe7eae',
#    '2ac88db1-c46f-4714-b78f-ee3e08ffb56b',
#    '725a2d3d-8893-44e0-9ee5-27805af17889',
#    '8f7c3ca5-7394-495d-bdef-d1d229d88a40',
#    '7ab12d07-8de2-463e-a778-b1eb58e22f1e',
#    '57cd72f1-2e71-4920-b2e7-76620b3739f9',
#    '8a67ca44-833c-47ef-a42b-6386a0512687',
#    '143b1fda-5887-4de3-83db-b5f4be969d96',
#    '8b635f7e-7a7e-459d-897f-65b1b05f847d',
#    '460921cf-4008-44e4-8e24-cd1a7d5553f7',
#    'e0847fdf-c572-4858-8082-8810e399560f',
#    '1c0a09a7-51b7-423b-ab77-cf8d6211ac9a',
#    'ac8e2f4a-f67e-42c8-858d-6b9296a83530',
#    'e49fb8f5-b874-4290-8652-a4673e7930de',
#    'c65f25cb-9725-4abf-83a0-6991b55ef956',
#    'c10d13e0-a844-4db3-a587-fdb0281f7ab3',
#    'c68c473e-e195-4e83-886e-4b170621031b',
#    'f087db95-d0a5-4599-b3e6-2ba274b1f4c6',
#    '34ad30ae-87a4-4e93-b35b-859fbbe41cc2',
#    '9fc37951-8732-4e67-bf91-f3c4292f7199',
#    'be0308f8-605f-4133-988b-491b7fb85b45',
#    '9315a14e-11d0-45b5-a5e4-714123e32c5e',
#    '3f6eb285-1811-4195-99c2-a9994e130ce6',
#    '043eeab9-d4f6-491a-840d-6d574e055046',
#    'f19fa7d1-ff68-44f6-9947-6096f48ebc5c',
#    '34745f2a-a758-4918-950f-4dca618090d0',
#    '93d1bf75-54a8-43df-815c-490f48592b5f',
#    '584b8c21-3ccf-44c9-b094-356e18d14171',
#    '3406851a-d535-4359-a0fd-1da0680cd5b0',
#    '1392c4ad-7cda-46cb-ae5c-05ac63c972ae',
#    '36cb5608-d02c-446c-ab0a-20d2dd5f0f7d',
#    'ae1ff820-bf5f-4533-86f8-ebdcded4fb9f',
#    '5c6beb40-e745-42ae-8ccf-196277e43291',
#    '4e4eb24a-d20c-412b-a917-38854836d955',
#    '334b5f01-a4be-4255-a0f0-8a2331b3dc68',
#    '03e95dca-c01f-4a7c-a9b9-15f270d7074e',
#    'e2281cfb-5f57-444e-b5e8-e44199a8dcae',
#    '1b34de47-5653-49ab-98fe-6023269d518f',
#    '25d9faa1-9123-44ca-bb2f-8525a3c4eaa6',
#    'fb7d95ce-a75d-4a18-80a6-ca02c6c012af',
#    '9a09bd34-1f3b-43ad-9eaa-e1960355d8e0',
#    '990c5ea3-65b7-4995-8dee-05c047fff1a4',
#    'd1708a72-a52b-48da-9db4-0c7a483eea7e',
#    '826f7bc6-2c58-4508-8748-4fcb8dddf320',
#    '9c222a9f-e9a8-43cb-a5ab-b5717f29a18d',
#    '05707b43-c73b-4977-90a3-4454a04508c1',
#    'f094dacc-f4f2-4602-8596-34de14ffe5f5',
#    'c07360ea-dda5-44ff-8b95-c3f1a4550630',
#    '95498a5a-c21e-4d77-8eed-e0e72efdfc91',
#    'd8e5f96e-7ebd-43b9-bdeb-c2962545bd0d',
#    '7e023ea6-cbfb-4d34-b286-5d5632202f91',
#    'dcf63147-0438-4a11-97f7-775620a1a9ca',
#    '51cafdab-cfc4-4416-a55f-04af7d9a0d75',
#    '14680578-c735-4475-a166-5e6ef98a7cf7',
#    '5cbaf4b3-9bcb-48c9-a372-49f220b9f4bf',
#    '79c7c867-d129-42d0-8a49-95c7e7b70912',
#    '0ef7bd61-8bb2-4ac3-9468-dc7ccb8f2df7',
#    'f48b69e5-97ef-4742-a940-b60e107a42a4',
#    '56b1ebf0-7c2c-4b0a-9021-02d04d00efd7',
#    '6d90fe9b-2225-42c7-80fb-aa19fa3b7d7a',
#    'bbe5c477-ea6c-4977-9bbc-0ef871cf79f6',
#    '210b3c52-989e-481e-aca1-5a7c1cd95f8b',
#    '52220d5e-109c-4f38-9da0-9dbb1de3c6ae',
#    'e42de227-963c-4178-a8f8-a80fd2cdadaf',
#    'f52d329d-59a5-41fd-9513-861e07afe697',
#    '432c7947-0e4a-46da-9e19-0731a7d4f292',
#    '46bf1602-0cb3-45dd-b055-ea2ecb3d7c71',
#    '8025cde0-4b67-421f-bc11-ef70570785f7',
#    'e28ac989-e4d7-4efd-82c2-a974f3c585af',
#    'ef8a2fbd-202c-4e86-acad-7f95c7ad9ec6',
#    'de73919e-1a2c-4536-a8de-6c5b8368c284',
#    '78e5532c-c955-4100-8acb-42b3f0ba3237',
#    'ec2be366-b365-4473-8954-7d4e21c89483',
#    '89f832e6-69d3-4b08-9896-e0cf6417d6c1',
#    'b617b4b0-196d-4a85-98d1-2e20b6d892ff',
#    '69fce216-2078-4378-a256-08ba816cda5a',
#    'b63d42c1-d730-42fb-9b84-13673e2351d9',
#    '45675f81-6651-45c0-84cd-d3611aec9146',
#    'cdd78528-bbdf-49cd-ad83-6673a77efb05',
#    '06044300-5bb5-4460-bd0e-93aadb821d18',
#    'fd291d5e-f81d-44ca-8981-6d364e136be2',
#    '364e244e-df0f-440d-8c64-30f7ffd4c5e9',
#    '4b7e3a98-a953-47db-8f54-09ca4f0309a9']))

# %% [markdown]
# ##### Hierarchical RAG
#
# Dada la naturaleza de nuestras colecciones, donde las columnas existen dentro del contexto de cada tabla, nos proponemos a utilizar la técnica de [**RAG jerárquico**](https://github.com/NirDiamant/RAG_Techniques/blob/main/all_rag_techniques/hierarchical_indices.ipynb) sobre las coleciones creadas. Esto significa que, primero buscaremos las tablas que sean más relevantes semánticamente para la query del usuario (en la coleción `tables_summary`) y, luego, para cada tabla obtenida, buscaremos sus columnas más relevantes (en la coleción `collumns`, filtrando la metada para que coincida con el dato de la tabla):

# %%
QUERY = 'Los 10 artículos más comprados.'

openai_relevant_docs = mdl_hierarchical_openai_collection.hierarchical_similarity_search(
    queries= QUERY,
    k_tables= 10,
    tables_score_threshold= 0.60,
    k_columns= 15,
    columns_score_threshold= 0.60
)

print(json.dumps(openai_relevant_docs, indent=2, ensure_ascii=False))
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.6
# [
#   [
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#         "relevance_score": 0.6412285566329956
#       },
#       "columns": [
#         {
#           "content": "Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.",
#           "relevance_score": 0.6759496331214905
#         },
#         {
#           "content": "Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.",
#           "relevance_score": 0.6552140712738037
#         },
#         {
#           "content": "Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.",
#           "relevance_score": 0.6396479904651642
#         },
#         {
#           "content": "Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.",
#           "relevance_score": 0.6371640563011169
#         },
#         {
#           "content": "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. 'reseller_sales'=Pedido realizado por un vendedor para una tienda/distribuidor, 'internet_sales'=Pedido realizado en línea por un cliente.",
#           "relevance_score": 0.6329842209815979
#         },
#         {
#           "content": "Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.",
#           "relevance_score": 0.6299903988838196
#         },
#         {
#           "content": "Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.",
#           "relevance_score": 0.6296935081481934
#         },
#         {
#           "content": "Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.",
#           "relevance_score": 0.6258278489112854
#         },
#         {
#           "content": "Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado. Se debe priorizar esta fecha por sobre cualquiera de las otras para realizar cualquier cálculo relacionado con ventas.",
#           "relevance_score": 0.6255242824554443
#         },
#         {
#           "content": "Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.",
#           "relevance_score": 0.6231701672077179
#         },
#         {
#           "content": "Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.",
#           "relevance_score": 0.6226486563682556
#         },
#         {
#           "content": "Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.",
#           "relevance_score": 0.6190636456012726
#         },
#         {
#           "content": "Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de preparación de pedidos. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#           "relevance_score": 0.6065670549869537
#         },
#         {
#           "content": "Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de entrega. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#           "relevance_score": 0.6013708114624023
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_product\nTable description: Tabla de dimensión que almacena la información detallada de cada producto que alguna vez haya sido vendido. Relevante para cualquier consulta en la que se nos pida listar productos por su nombre.\nTable PRIMARY KEY:\n- product_key",
#         "relevance_score": 0.6381749510765076
#       },
#       "columns": [
#         {
#           "content": "Column name: list_price\nColumn data type: NUMERIC\nColumn description: Precio de venta del producto en USD.",
#           "relevance_score": 0.6599270105361938
#         },
#         {
#           "content": "Column name: english_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (INGLÉS). NUNCA viene a NULL.",
#           "relevance_score": 0.646866112947464
#         },
#         {
#           "content": "Column name: english_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (INGLÉS). Las categorías son 'Clothing', 'Components', 'Accessories' y 'Bikes'. NUNCA viene a NULL.",
#           "relevance_score": 0.644867867231369
#         },
#         {
#           "content": "Column name: finished_goods_flag\nColumn data type: BOOL\nColumn description: Indicador de si se trata de un producto final vendible. '0'=El producto no es un artículo vendible, '1'=El producto es vendible.",
#           "relevance_score": 0.6424015164375305
#         },
#         {
#           "content": "Column name: reorder_point\nColumn data type: INT2\nColumn description: Nivel de stock que dispara una orden de compra o una orden de trabajo.",
#           "relevance_score": 0.6394508481025696
#         },
#         {
#           "content": "Column name: safety_stock_level\nColumn data type: INT2\nColumn description: Nivel de stock mínimo del producto.",
#           "relevance_score": 0.6353709101676941
#         },
#         {
#           "content": "Column name: english_description\nColumn data type: VARCHAR(400)\nColumn description: Descripción detallada del producto (INGLÉS). NUNCA viene a NULL.",
#           "relevance_score": 0.6331214308738708
#         },
#         {
#           "content": "Column name: english_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (INGLÉS). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.",
#           "relevance_score": 0.6318990588188171
#         },
#         {
#           "content": "Column name: active\nColumn data type: BOOL\nColumn description: Indicador de si el producto sigue disponible para la venta.",
#           "relevance_score": 0.6318128705024719
#         },
#         {
#           "content": "Column name: standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar del producto en USD.",
#           "relevance_score": 0.6308408677577972
#         },
#         {
#           "content": "Column name: spanish_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (ESPAÑOL). Las categorías son 'Prenda', 'Componente', 'Accesorio' y 'Bicicleta'  NUNCA viene a NULL.",
#           "relevance_score": 0.6290216445922852
#         },
#         {
#           "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto estuvo disponible para la venta.",
#           "relevance_score": 0.6287546753883362
#         },
#         {
#           "content": "Column name: size\nColumn data type: VARCHAR(50)\nColumn description: Talla del producto. Ej. 48, L. Puede venir a NULL.",
#           "relevance_score": 0.6284976303577423
#         },
#         {
#           "content": "Column name: spanish_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (ESPAÑOL). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.",
#           "relevance_score": 0.6266202032566071
#         },
#         {
#           "content": "Column name: spanish_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (ESPAÑOL). Puede venir a NULL.",
#           "relevance_score": 0.6263260245323181
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_reseller\nTable description: Tabla de dimensión que almacena la información detallada de cada tienda/distribuidor del segmento mayorista (B2B). Relevante siempre que se pida obtener listado con datos de tiendas/distribuidores porque en esta tabla se almacenan sus nombres.\nTable PRIMARY KEY:\n- reseller_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#         "relevance_score": 0.6123942732810974
#       },
#       "columns": [
#         {
#           "content": "Column name: last_order_year\nColumn data type: INT4\nColumn description: Año de última compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#           "relevance_score": 0.6360934674739838
#         },
#         {
#           "content": "Column name: reseller_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre de la tienda / distribuidor.",
#           "relevance_score": 0.6331160664558411
#         },
#         {
#           "content": "Column name: business_type\nColumn data type: VARCHAR(20)\nColumn description: Tipo de negocio / tienda del que se trata. Ej. Value Added Reseller, Specialty Bike Shop, Warehouse",
#           "relevance_score": 0.6262716352939606
#         },
#         {
#           "content": "Column name: product_line\nColumn data type: VARCHAR(50)\nColumn description: Línea de productos en la que se especializa el distribuidor. Ej. Road, Mountain, Touring.",
#           "relevance_score": 0.6171607375144958
#         },
#         {
#           "content": "Column name: first_order_year\nColumn data type: INT4\nColumn description: Año de primera compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#           "relevance_score": 0.6170526742935181
#         },
#         {
#           "content": "Column name: number_employees\nColumn data type: INT4\nColumn description: Cantidad de empleados de la tienda / distribuidor.",
#           "relevance_score": 0.6158704161643982
#         },
#         {
#           "content": "Column name: order_frequency\nColumn data type: BPCHAR(1)\nColumn description: Frecuencia con la que se espera que compre un distribuidor. 'A'=Anually(Anual), 'S'=Semestrally(Semestral), 'Q'=Quaterlly(Trimestral).",
#           "relevance_score": 0.6090793609619141
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_reason\nTable description: Tabla de dimensión que almacena la información detallada de cada motivo de venta. Relevante cuando se busca comprender los principales motivos por los que se han logrado las ventas.\nTable PRIMARY KEY:\n- sales_reason_key",
#         "relevance_score": 0.6087535917758942
#       },
#       "columns": [
#         {
#           "content": "Column name: sales_reason_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del motivo de venta. NUNCA viene a NULL.Ej. Price, On Promotion, Magazine Advertisement.",
#           "relevance_score": 0.6247309148311615
#         },
#         {
#           "content": "Column name: sales_reason_reason_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo del motivo de venta. NUNCA viene a NULL. Ej. Other, Promotion, Marketing.",
#           "relevance_score": 0.6223631501197815
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_promotion\nTable description: Tabla de dimensión que almacena la información detallada de las diferentes promociones / descuentos que pueden aplicarse a las ventas. Relevante cuando se quiere segmentar las promociones que han sido aplicadas en las ventas.\nTable PRIMARY KEY:\n- promotion_key",
#         "relevance_score": 0.608528196811676
#       },
#       "columns": [
#         {
#           "content": "Column name: max_qty\nColumn data type: INT4\nColumn description: Cantidad máxima a la que será aplicable la promoción. En caso de venir a NULL, significa que no hay límite.",
#           "relevance_score": 0.6358386278152466
#         },
#         {
#           "content": "Column name: english_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (INGLÉS). NUNCA será NULL. Ej. No Discount, Volume Discount, Seasonal Discount.",
#           "relevance_score": 0.6292128562927246
#         },
#         {
#           "content": "Column name: spanish_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (ESPAÑOL). NUNCA será NULL. Ej. Sin descuento, Descuento por volumen, Descuento de temporada.",
#           "relevance_score": 0.6287905871868134
#         },
#         {
#           "content": "Column name: min_qty\nColumn data type: INT4\nColumn description: Cantidad mínima necesaria para aplicar la promoción. NUNCA será NULL.",
#           "relevance_score": 0.6253530979156494
#         },
#         {
#           "content": "Column name: english_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (INGLÉS). NUNCA será NULL. Indica si es aplicable a un distribuidor (Reseller) o a un cliente final (Customer).",
#           "relevance_score": 0.6215106248855591
#         },
#         {
#           "content": "Column name: english_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (INGLÉS). NUNCA será NULL.",
#           "relevance_score": 0.6152471303939819
#         },
#         {
#           "content": "Column name: spanish_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (ESPAÑOL). NUNCA será NULL. Indica si es aplicable a un distribuidor (Distribuidor) o a un cliente final (Cliente).",
#           "relevance_score": 0.61419278383255
#         },
#         {
#           "content": "Column name: discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicable a la promoción, en decimal. Comprendido entre 0 y 1. NUNCA será NULL. Ej. 0, 0.02, 0.05.",
#           "relevance_score": 0.6117531657218933
#         },
#         {
#           "content": "Column name: spanish_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (ESPAÑOL). NUNCA será NULL.",
#           "relevance_score": 0.6092495620250702
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_person\nTable description: Tabla de dimensión que almacena la información detallada de cada vendedor. Relevante cuando se nos pide sacar información relativa a las ventas que ha hecho cada vendedor, ya que en esta tabla se tiene el nombre de cada uno.\nTable PRIMARY KEY:\n- employee_key",
#         "relevance_score": 0.6045384705066681
#       },
#       "columns": [
#         {
#           "content": "Column name: title\nColumn data type: VARCHAR(50)\nColumn description: Título que ese vendedor tiene dentro de la compañía como empleado.",
#           "relevance_score": 0.6241055130958557
#         },
#         {
#           "content": "Column name: employee_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del vendedor.",
#           "relevance_score": 0.6201631426811218
#         },
#         {
#           "content": "Column name: sales_person_flag\nColumn data type: BOOL\nColumn description: Indicador que se trata de un empleado vendedor. SIEMPRE vendrá a true.",
#           "relevance_score": 0.6072057485580444
#         },
#         {
#           "content": "Column name: gender\nColumn data type: BPCHAR(1)\nColumn description: Género del vendedor. 'F'=Female(Mujer), 'M'=Male(Hombre)",
#           "relevance_score": 0.6060847640037537
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_customer\nTable description: Tabla de dimensión que almacena la información detallada de cada cliente que haya comprado online (por internet), para el segmento minorista (B2C). Relevante cuando se hacen consultas relativas a clientes, como su nombre, análisis por género y estado civil o ingresos de los mismos.\nTable PRIMARY KEY:\n- customer_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#         "relevance_score": 0.6042124330997467
#       },
#       "columns": [
#         {
#           "content": "Column name: customer_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del cliente.",
#           "relevance_score": 0.6145213544368744
#         },
#         {
#           "content": "Column name: total_children\nColumn data type: INT2\nColumn description: Cantidad total de hijos del cliente.",
#           "relevance_score": 0.60736483335495
#         },
#         {
#           "content": "Column name: spanish_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (ESPAÑOL).",
#           "relevance_score": 0.6037447154521942
#         },
#         {
#           "content": "Column name: english_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (INGLÉS).",
#           "relevance_score": 0.6027345359325409
#         }
#       ]
#     }
#   ]
# ]

# %%
print(openai_relevant_docs)
# Out:
# [[{'table_summary': {'content': 'Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)', 'relevance_score': 0.6412285566329956}, 'columns': [{'content': 'Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.', 'relevance_score': 0.6759496331214905}, {'content': 'Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.', 'relevance_score': 0.6552140712738037}, {'content': 'Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.', 'relevance_score': 0.6396479904651642}, {'content': 'Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.', 'relevance_score': 0.6371640563011169}, {'content': "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. 'reseller_sales'=Pedido realizado por un vendedor para una tienda/distribuidor, 'internet_sales'=Pedido realizado en línea por un cliente.", 'relevance_score': 0.6329842209815979}, {'content': 'Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.', 'relevance_score': 0.6299903988838196}, {'content': 'Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.', 'relevance_score': 0.6296935081481934}, {'content': 'Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.', 'relevance_score': 0.6258278489112854}, {'content': 'Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado. Se debe priorizar esta fecha por sobre cualquiera de las otras para realizar cualquier cálculo relacionado con ventas.', 'relevance_score': 0.6255242824554443}, {'content': 'Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.', 'relevance_score': 0.6231701672077179}, {'content': 'Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.', 'relevance_score': 0.6226486563682556}, {'content': 'Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.', 'relevance_score': 0.6190636456012726}, {'content': 'Column name: ship_date\ ...

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0)

SYSTEM_PROMPT = """
You are a context summarizer that receives retrieval documents in JSON format.
Your role is to:

1. Analyze the given JSON documents carefully.
2. Identify and extract only the information relevant to answer the user's question.
3. Summarize relevant tables, columns, keys, and descriptions into a clear and concise text.
4. Exclude any irrelevant or low-relevance details.
5. Ensure factual accuracy; do not fabricate information.
6. Do NOT generate or suggest any SQL queries.
7. When it is possible, match the language of the query fields to the user's query. For example, if user's query is in spanish, use `spanish_...`.
8. Match the language of the summary to the user's query.

Input:
- Retrieval documents (JSON): {retrieval_documents}

Output:
- A concise summary of relevant context—focused on tables, columns, keys, and descriptions—that will help generate an accurate SQL query. Don't suggest any query, only bring information in plain text. 
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': json.dumps(openai_relevant_docs, indent=2, ensure_ascii=False)
})

Markdown(contexto_resumido)
# Out:
# Para obtener información sobre los 10 artículos más comprados, se pueden utilizar las siguientes tablas y columnas relevantes de la base de datos `adventure_works_dw` en el esquema `sales`:
#
# 1. **Tabla: fact_sales**
#    - **Descripción**: Tabla de hechos que contiene el detalle de las órdenes de ventas entregadas, con granularidad a nivel de línea.
#    - **Claves Primarias**:
#      - sales_order_number
#      - sales_order_line_number
#    - **Columnas relevantes**:
#      - **order_quantity**: Cantidad vendida de cada producto.
#      - **product_key**: Clave del producto (clave foránea que se relaciona con la tabla dim_product).
#
# 2. **Tabla: dim_product**
#    - **Descripción**: Tabla de dimensión que almacena la información detallada de cada producto vendido.
#    - **Claves Primarias**:
#      - product_key
#    - **Columnas relevantes**:
#      - **english_product_name**: Nombre del producto (en inglés).
#      - **spanish_product_name**: Nombre del producto (en español).
#      - **list_price**: Precio de venta del producto en USD.
#
# Para identificar los artículos más comprados, se debe considerar la columna `order_quantity` de la tabla `fact_sales` y relacionarla con la tabla `dim_product` a través de `product_key` para obtener los nombres de los productos.

# %% [markdown]
# #### LangChain: ChromaDB + Google GenAI Embeddings
#
# Ahora haremos una segunda implementación de prueba de Chroma valiéndonos de funcionalidades de la librería LangChain, usando un modelo de embeddings de Google Gemini a través de Gemini API, pero trabajando con VertexAI de fondo, lo que nos permite asegurar que los datos permanezcan en la region / location deseada.
#
# Dado que la clase implementada por LangChain para utilizar embeddings de Gemini API no soporta usar VertexAI por detrás, hemos procedido a implementar una clase personalizada que sí nos los permite, a la que hemos llamado `GenAIExtendedEmbeddingFunction`.
#
# Generamos una instancia de la clase y verificamos que los parámetros son los esperados:

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(model= GENAI_EMBEDDING_MODEL)
print(f'VertexAI: {genai_embeddings.genai_client._api_client.vertexai}')
print(f'Project: {genai_embeddings.genai_client._api_client.project}')
print(f'Location: {genai_embeddings.genai_client._api_client.location}')
print(f'Auth Tokens: {genai_embeddings.genai_client.auth_tokens}')
# Out:
# VertexAI: True
# Project: gen-lang-client-0151767776
# Location: europe-west1
# Auth Tokens: <google.genai.tokens.Tokens object at 0x00000255BD43FDD0>

# %% [markdown]
# El próximo paso es crear un cliente persistente de ChromaDB, e inicializar las colecciones tanto a nivel de tablas como de columnas. Al inicializar las colecciones, especificaremos que queremos usar como métrica de distancia la distancia de Coseno, que se calcula de la siguiente manera:
#
# $$Distancia = 1 - \frac{A \cdot B}{\|A\| \|B\|}$$
#
# Donde:
# * $A \cdot B$ es el producto punto (producto escalar) de los vectores $A$ y $B$.
# * $∥A∥$ y $∥B∥$ son las magnitudes (o normas euclidianas) de los vectores $A$ y $B$, respectivamente.
# ​
#
# La métrica **Distancia del Coseno** mide solo el ángulo entre vectores, lo que lo hace ideal para embeddings de texto, y particularmente para modelos de embeddings como el que usaremos [(`gemini-embedding-001`) cuyos valores vienen normalizados](https://ai.google.dev/gemini-api/docs/embeddings#quality-for-smaller-dimensions).
#
# Como es fácil ver en su expresión, esta métrica de distancia devuelve valores en el rango $[0, 2]$. Cuanto más cerca de 0, más similares serán los vectores $A$ y $B$. Esto nos deja en la necesidad de definir una métrica de `relevance_score` personalizada, que nos permita reescalar los resultados en valores comprendidos entre $[0, 1]$, siendo los valores más cercanos a 1 indicativo de mayor similitud entre los vectores. Esta métrica la hemos definido en la función `cosine_distance_relevance_score_fn` de la siguiente manera:
#
# $$R_{score} = 1 - \frac{Distancia}{2}$$

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)

mdl_hierarchical_genai_collection = MdlHierarchicalChromaCollections(
    collection_names= (TABLES_SUMMARY_COLLECTION_NAME, COLUMNS_COLLECTION_NAME),
    create_collections_if_not_exists= True,
    clear_collections= True,
    embedding_function= genai_embeddings,
    collections_configuration= {'hnsw': {'space': 'cosine'}}
)

mdl_hierarchical_genai_collection.upsert_hierarchical_data(documents= (table_chunks, column_chunks))
# Out:
# (({'ids': [], 'documents': [], 'metadatas': []},
#   {'ids': [], 'documents': [], 'metadatas': []}),
#  (['8f442e80-6240-4071-88d5-ae9925d729df',
#    '568d6995-778e-4a28-911a-67e997c878d2',
#    '82a8ade4-8109-4f39-8315-5170ff29ad68',
#    '053ca97b-75d2-485f-9c59-b31066329272',
#    'a4f08a0d-fbca-4c3d-8dbe-5369c85b6ac6',
#    'c6bf463a-b903-45af-a89a-39774dc76778',
#    'cf1459a1-09df-4a26-b677-9cc387cd86d9',
#    '314cc945-bd9f-4e63-9d72-90fc3bdf267d',
#    'c85424e7-834c-48ec-9eac-2d21ae76685d',
#    '85e28078-2e08-4019-8ce9-3f4bf4438e1c'],
#   ['01fc4477-7d83-4e0c-9b48-7c98eb1bc731',
#    '8791f4eb-04c8-49ee-91b1-22e47273e7b8',
#    '6a9f379f-9fe1-4d65-acd0-9a33387a6215',
#    'ca91c76f-0cf2-4034-aa89-d588416c6a57',
#    'ff213c1d-0e4b-44d9-9e28-1cce7120de56',
#    '1b12b55e-e44d-4c27-8966-cf5af29b56be',
#    'eb665c0f-2515-4467-9c29-a7cb3e020b0b',
#    'eaa49833-121b-42bc-8de6-6a1673fe7eae',
#    '2ac88db1-c46f-4714-b78f-ee3e08ffb56b',
#    '725a2d3d-8893-44e0-9ee5-27805af17889',
#    '8f7c3ca5-7394-495d-bdef-d1d229d88a40',
#    '7ab12d07-8de2-463e-a778-b1eb58e22f1e',
#    '57cd72f1-2e71-4920-b2e7-76620b3739f9',
#    '8a67ca44-833c-47ef-a42b-6386a0512687',
#    '143b1fda-5887-4de3-83db-b5f4be969d96',
#    '8b635f7e-7a7e-459d-897f-65b1b05f847d',
#    '460921cf-4008-44e4-8e24-cd1a7d5553f7',
#    'e0847fdf-c572-4858-8082-8810e399560f',
#    '1c0a09a7-51b7-423b-ab77-cf8d6211ac9a',
#    'ac8e2f4a-f67e-42c8-858d-6b9296a83530',
#    'e49fb8f5-b874-4290-8652-a4673e7930de',
#    'c65f25cb-9725-4abf-83a0-6991b55ef956',
#    'c10d13e0-a844-4db3-a587-fdb0281f7ab3',
#    'c68c473e-e195-4e83-886e-4b170621031b',
#    'f087db95-d0a5-4599-b3e6-2ba274b1f4c6',
#    '34ad30ae-87a4-4e93-b35b-859fbbe41cc2',
#    '9fc37951-8732-4e67-bf91-f3c4292f7199',
#    'be0308f8-605f-4133-988b-491b7fb85b45',
#    '9315a14e-11d0-45b5-a5e4-714123e32c5e',
#    '3f6eb285-1811-4195-99c2-a9994e130ce6',
#    '043eeab9-d4f6-491a-840d-6d574e055046',
#    'f19fa7d1-ff68-44f6-9947-6096f48ebc5c',
#    '34745f2a-a758-4918-950f-4dca618090d0',
#    '93d1bf75-54a8-43df-815c-490f48592b5f',
#    '584b8c21-3ccf-44c9-b094-356e18d14171',
#    '3406851a-d535-4359-a0fd-1da0680cd5b0',
#    '1392c4ad-7cda-46cb-ae5c-05ac63c972ae',
#    '36cb5608-d02c-446c-ab0a-20d2dd5f0f7d',
#    'ae1ff820-bf5f-4533-86f8-ebdcded4fb9f',
#    '5c6beb40-e745-42ae-8ccf-196277e43291',
#    '4e4eb24a-d20c-412b-a917-38854836d955',
#    '334b5f01-a4be-4255-a0f0-8a2331b3dc68',
#    '03e95dca-c01f-4a7c-a9b9-15f270d7074e',
#    'e2281cfb-5f57-444e-b5e8-e44199a8dcae',
#    '1b34de47-5653-49ab-98fe-6023269d518f',
#    '25d9faa1-9123-44ca-bb2f-8525a3c4eaa6',
#    'fb7d95ce-a75d-4a18-80a6-ca02c6c012af',
#    '9a09bd34-1f3b-43ad-9eaa-e1960355d8e0',
#    '990c5ea3-65b7-4995-8dee-05c047fff1a4',
#    'd1708a72-a52b-48da-9db4-0c7a483eea7e',
#    '826f7bc6-2c58-4508-8748-4fcb8dddf320',
#    '9c222a9f-e9a8-43cb-a5ab-b5717f29a18d',
#    '05707b43-c73b-4977-90a3-4454a04508c1',
#    'f094dacc-f4f2-4602-8596-34de14ffe5f5',
#    'c07360ea-dda5-44ff-8b95-c3f1a4550630',
#    '95498a5a-c21e-4d77-8eed-e0e72efdfc91',
#    'd8e5f96e-7ebd-43b9-bdeb-c2962545bd0d',
#    '7e023ea6-cbfb-4d34-b286-5d5632202f91',
#    'dcf63147-0438-4a11-97f7-775620a1a9ca',
#    '51cafdab-cfc4-4416-a55f-04af7d9a0d75',
#    '14680578-c735-4475-a166-5e6ef98a7cf7',
#    '5cbaf4b3-9bcb-48c9-a372-49f220b9f4bf',
#    '79c7c867-d129-42d0-8a49-95c7e7b70912',
#    '0ef7bd61-8bb2-4ac3-9468-dc7ccb8f2df7',
#    'f48b69e5-97ef-4742-a940-b60e107a42a4',
#    '56b1ebf0-7c2c-4b0a-9021-02d04d00efd7',
#    '6d90fe9b-2225-42c7-80fb-aa19fa3b7d7a',
#    'bbe5c477-ea6c-4977-9bbc-0ef871cf79f6',
#    '210b3c52-989e-481e-aca1-5a7c1cd95f8b',
#    '52220d5e-109c-4f38-9da0-9dbb1de3c6ae',
#    'e42de227-963c-4178-a8f8-a80fd2cdadaf',
#    'f52d329d-59a5-41fd-9513-861e07afe697',
#    '432c7947-0e4a-46da-9e19-0731a7d4f292',
#    '46bf1602-0cb3-45dd-b055-ea2ecb3d7c71',
#    '8025cde0-4b67-421f-bc11-ef70570785f7',
#    'e28ac989-e4d7-4efd-82c2-a974f3c585af',
#    'ef8a2fbd-202c-4e86-acad-7f95c7ad9ec6',
#    'de73919e-1a2c-4536-a8de-6c5b8368c284',
#    '78e5532c-c955-4100-8acb-42b3f0ba3237',
#    'ec2be366-b365-4473-8954-7d4e21c89483',
#    '89f832e6-69d3-4b08-9896-e0cf6417d6c1',
#    'b617b4b0-196d-4a85-98d1-2e20b6d892ff',
#    '69fce216-2078-4378-a256-08ba816cda5a',
#    'b63d42c1-d730-42fb-9b84-13673e2351d9',
#    '45675f81-6651-45c0-84cd-d3611aec9146',
#    'cdd78528-bbdf-49cd-ad83-6673a77efb05',
#    '06044300-5bb5-4460-bd0e-93aadb821d18',
#    'fd291d5e-f81d-44ca-8981-6d364e136be2',
#    '364e244e-df0f-440d-8c64-30f7ffd4c5e9',
#    '4b7e3a98-a953-47db-8f54-09ca4f0309a9']))

# %% [markdown]
# ##### Hierarchical RAG
#
# Dada la naturaleza de nuestras colecciones, donde las columnas existen dentro del contexto de cada tabla, nos proponemos a utilizar la técnica de [**RAG jerárquico**](https://github.com/NirDiamant/RAG_Techniques/blob/main/all_rag_techniques/hierarchical_indices.ipynb) sobre las coleciones creadas. Esto significa que, primero buscaremos las tablas que sean más relevantes semánticamente para la query del usuario (en la coleción `tables_summary`) y, luego, para cada tabla obtenida, buscaremos sus columnas más relevantes (en la coleción `collumns`, filtrando la metada para que coincida con el dato de la tabla):

# %%
QUERY = 'Los 10 artículos más comprados.'

genai_relevant_docs = mdl_hierarchical_genai_collection.hierarchical_similarity_search(
    queries= QUERY,
    k_tables= 10,
    tables_score_threshold= 0.75,
    k_columns= 15,
    columns_score_threshold= 0.75
)

print(json.dumps(genai_relevant_docs, indent=2, ensure_ascii=False))
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.75
# [
#   [
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#         "relevance_score": 0.8164840936660767
#       },
#       "columns": [
#         {
#           "content": "Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.",
#           "relevance_score": 0.8307241499423981
#         },
#         {
#           "content": "Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.",
#           "relevance_score": 0.8191922605037689
#         },
#         {
#           "content": "Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.",
#           "relevance_score": 0.8191658854484558
#         },
#         {
#           "content": "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. 'reseller_sales'=Pedido realizado por un vendedor para una tienda/distribuidor, 'internet_sales'=Pedido realizado en línea por un cliente.",
#           "relevance_score": 0.8181345164775848
#         },
#         {
#           "content": "Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado. Se debe priorizar esta fecha por sobre cualquiera de las otras para realizar cualquier cálculo relacionado con ventas.",
#           "relevance_score": 0.8162600994110107
#         },
#         {
#           "content": "Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.",
#           "relevance_score": 0.8134251534938812
#         },
#         {
#           "content": "Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de preparación de pedidos. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#           "relevance_score": 0.8130926191806793
#         },
#         {
#           "content": "Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.",
#           "relevance_score": 0.812057763338089
#         },
#         {
#           "content": "Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.",
#           "relevance_score": 0.8111943900585175
#         },
#         {
#           "content": "Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.",
#           "relevance_score": 0.8065106272697449
#         },
#         {
#           "content": "Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.",
#           "relevance_score": 0.80640709400177
#         },
#         {
#           "content": "Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de entrega. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#           "relevance_score": 0.8059392869472504
#         },
#         {
#           "content": "Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.",
#           "relevance_score": 0.8057128190994263
#         },
#         {
#           "content": "Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.",
#           "relevance_score": 0.8025482296943665
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_product\nTable description: Tabla de dimensión que almacena la información detallada de cada producto que alguna vez haya sido vendido. Relevante para cualquier consulta en la que se nos pida listar productos por su nombre.\nTable PRIMARY KEY:\n- product_key",
#         "relevance_score": 0.8155222535133362
#       },
#       "columns": [
#         {
#           "content": "Column name: list_price\nColumn data type: NUMERIC\nColumn description: Precio de venta del producto en USD.",
#           "relevance_score": 0.8261467218399048
#         },
#         {
#           "content": "Column name: active\nColumn data type: BOOL\nColumn description: Indicador de si el producto sigue disponible para la venta.",
#           "relevance_score": 0.8233605027198792
#         },
#         {
#           "content": "Column name: finished_goods_flag\nColumn data type: BOOL\nColumn description: Indicador de si se trata de un producto final vendible. '0'=El producto no es un artículo vendible, '1'=El producto es vendible.",
#           "relevance_score": 0.8231784999370575
#         },
#         {
#           "content": "Column name: spanish_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (ESPAÑOL). Las categorías son 'Prenda', 'Componente', 'Accesorio' y 'Bicicleta'  NUNCA viene a NULL.",
#           "relevance_score": 0.8229920864105225
#         },
#         {
#           "content": "Column name: english_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (INGLÉS). Las categorías son 'Clothing', 'Components', 'Accessories' y 'Bikes'. NUNCA viene a NULL.",
#           "relevance_score": 0.8216324746608734
#         },
#         {
#           "content": "Column name: style\nColumn data type: BPCHAR(2)\nColumn description: Público para el que está pensado el producto. 'W'=Womens(Mujeres), 'M'=Mens(Hombres), 'U'=Universal.  Puede venir a NULL.",
#           "relevance_score": 0.8185134828090668
#         },
#         {
#           "content": "Column name: english_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (INGLÉS). NUNCA viene a NULL.",
#           "relevance_score": 0.8172828555107117
#         },
#         {
#           "content": "Column name: english_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (INGLÉS). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.",
#           "relevance_score": 0.8170572221279144
#         },
#         {
#           "content": "Column name: spanish_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (ESPAÑOL). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.",
#           "relevance_score": 0.815524697303772
#         },
#         {
#           "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto estuvo disponible para la venta.",
#           "relevance_score": 0.8153621554374695
#         },
#         {
#           "content": "Column name: safety_stock_level\nColumn data type: INT2\nColumn description: Nivel de stock mínimo del producto.",
#           "relevance_score": 0.8147757351398468
#         },
#         {
#           "content": "Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto dejó de estar disponible para la venta. En caso de que siga disponible, vendrá a NULL.",
#           "relevance_score": 0.8147150278091431
#         },
#         {
#           "content": "Column name: size\nColumn data type: VARCHAR(50)\nColumn description: Talla del producto. Ej. 48, L. Puede venir a NULL.",
#           "relevance_score": 0.8142133057117462
#         },
#         {
#           "content": "Column name: class\nColumn data type: BPCHAR(2)\nColumn description: Gama a la que pertenece el producto. 'H'=High(Alta), 'M'=Medium(Media), 'L'=Low(Baja). Puede venir a NULL.",
#           "relevance_score": 0.8141178488731384
#         },
#         {
#           "content": "Column name: spanish_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (ESPAÑOL). Puede venir a NULL.",
#           "relevance_score": 0.8136493861675262
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_customer\nTable description: Tabla de dimensión que almacena la información detallada de cada cliente que haya comprado online (por internet), para el segmento minorista (B2C). Relevante cuando se hacen consultas relativas a clientes, como su nombre, análisis por género y estado civil o ingresos de los mismos.\nTable PRIMARY KEY:\n- customer_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#         "relevance_score": 0.8071207106113434
#       },
#       "columns": [
#         {
#           "content": "Column name: total_children\nColumn data type: INT2\nColumn description: Cantidad total de hijos del cliente.",
#           "relevance_score": 0.8068450391292572
#         },
#         {
#           "content": "Column name: commute_distance\nColumn data type: VARCHAR(15)\nColumn description: Distancia entre la casa del cliente y su lugar habitual de trabajo. Segmentado en 5 categorías: ['0-1 Miles', '1-2 Miles', '2-5 Miles', '5-10 Miles', '10+ Miles']",
#           "relevance_score": 0.8057973980903625
#         },
#         {
#           "content": "Column name: gender\nColumn data type: VARCHAR(1)\nColumn description: Género del cliente. 'F'=Female(Mujer), 'M'=Male(Hombre)",
#           "relevance_score": 0.8048632442951202
#         },
#         {
#           "content": "Column name: number_cars_owned\nColumn data type: INT2\nColumn description: Cantidad de tarjetas de crédito que posee el cliente.",
#           "relevance_score": 0.8042222261428833
#         },
#         {
#           "content": "Column name: house_owner\nColumn data type: BOOL\nColumn description: Indicador de si el cliente es propietario. 'True'=Propietario, 'False'=No Propietario",
#           "relevance_score": 0.8040944933891296
#         },
#         {
#           "content": "Column name: customer_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del cliente.",
#           "relevance_score": 0.8033779263496399
#         },
#         {
#           "content": "Column name: number_children_at_home\nColumn data type: INT2\nColumn description: Cantidad total de hijos convivientes del cliente.",
#           "relevance_score": 0.8027271628379822
#         },
#         {
#           "content": "Column name: yearly_income\nColumn data type: NUMERIC\nColumn description: Ingreso anual del cliente en USD.",
#           "relevance_score": 0.7981598377227783
#         },
#         {
#           "content": "Column name: english_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (INGLÉS).",
#           "relevance_score": 0.7957025170326233
#         },
#         {
#           "content": "Column name: english_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (INGLÉS).",
#           "relevance_score": 0.7942387461662292
#         },
#         {
#           "content": "Column name: birth_date\nColumn data type: DATE\nColumn description: Fecha de nacimiento del cliente.",
#           "relevance_score": 0.7926647663116455
#         },
#         {
#           "content": "Column name: spanish_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (ESPAÑOL).",
#           "relevance_score": 0.7923163771629333
#         },
#         {
#           "content": "Column name: marital_status\nColumn data type: BPCHAR(1)\nColumn description: Estado civil del cliente. 'M'=Married(Casada/o), 'S'=Single(Soltera/o)",
#           "relevance_score": 0.7916539907455444
#         },
#         {
#           "content": "Column name: spanish_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (ESPAÑOL).",
#           "relevance_score": 0.7916126847267151
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_reason\nTable description: Tabla de dimensión que almacena la información detallada de cada motivo de venta. Relevante cuando se busca comprender los principales motivos por los que se han logrado las ventas.\nTable PRIMARY KEY:\n- sales_reason_key",
#         "relevance_score": 0.8043584525585175
#       },
#       "columns": [
#         {
#           "content": "Column name: sales_reason_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del motivo de venta. NUNCA viene a NULL.Ej. Price, On Promotion, Magazine Advertisement.",
#           "relevance_score": 0.8135404586791992
#         },
#         {
#           "content": "Column name: sales_reason_reason_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo del motivo de venta. NUNCA viene a NULL. Ej. Other, Promotion, Marketing.",
#           "relevance_score": 0.8016177415847778
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_promotion\nTable description: Tabla de dimensión que almacena la información detallada de las diferentes promociones / descuentos que pueden aplicarse a las ventas. Relevante cuando se quiere segmentar las promociones que han sido aplicadas en las ventas.\nTable PRIMARY KEY:\n- promotion_key",
#         "relevance_score": 0.8031019866466522
#       },
#       "columns": [
#         {
#           "content": "Column name: max_qty\nColumn data type: INT4\nColumn description: Cantidad máxima a la que será aplicable la promoción. En caso de venir a NULL, significa que no hay límite.",
#           "relevance_score": 0.8087416291236877
#         },
#         {
#           "content": "Column name: min_qty\nColumn data type: INT4\nColumn description: Cantidad mínima necesaria para aplicar la promoción. NUNCA será NULL.",
#           "relevance_score": 0.8086339235305786
#         },
#         {
#           "content": "Column name: spanish_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (ESPAÑOL). NUNCA será NULL. Ej. Sin descuento, Descuento por volumen, Descuento de temporada.",
#           "relevance_score": 0.8066767454147339
#         },
#         {
#           "content": "Column name: english_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (INGLÉS). NUNCA será NULL. Ej. No Discount, Volume Discount, Seasonal Discount.",
#           "relevance_score": 0.8057228326797485
#         },
#         {
#           "content": "Column name: english_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (INGLÉS). NUNCA será NULL. Indica si es aplicable a un distribuidor (Reseller) o a un cliente final (Customer).",
#           "relevance_score": 0.8036238849163055
#         },
#         {
#           "content": "Column name: english_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (INGLÉS). NUNCA será NULL.",
#           "relevance_score": 0.8027089238166809
#         },
#         {
#           "content": "Column name: spanish_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (ESPAÑOL). NUNCA será NULL. Indica si es aplicable a un distribuidor (Distribuidor) o a un cliente final (Cliente).",
#           "relevance_score": 0.8024722933769226
#         },
#         {
#           "content": "Column name: spanish_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (ESPAÑOL). NUNCA será NULL.",
#           "relevance_score": 0.8012619614601135
#         },
#         {
#           "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que comienza a ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#           "relevance_score": 0.7987689971923828
#         },
#         {
#           "content": "Column name: discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicable a la promoción, en decimal. Comprendido entre 0 y 1. NUNCA será NULL. Ej. 0, 0.02, 0.05.",
#           "relevance_score": 0.798712819814682
#         },
#         {
#           "content": "Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que deja de ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#           "relevance_score": 0.7963289320468903
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_reseller\nTable description: Tabla de dimensión que almacena la información detallada de cada tienda/distribuidor del segmento mayorista (B2B). Relevante siempre que se pida obtener listado con datos de tiendas/distribuidores porque en esta tabla se almacenan sus nombres.\nTable PRIMARY KEY:\n- reseller_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#         "relevance_score": 0.8016248941421509
#       },
#       "columns": [
#         {
#           "content": "Column name: last_order_year\nColumn data type: INT4\nColumn description: Año de última compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#           "relevance_score": 0.8174338936805725
#         },
#         {
#           "content": "Column name: reseller_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre de la tienda / distribuidor.",
#           "relevance_score": 0.8164613842964172
#         },
#         {
#           "content": "Column name: order_frequency\nColumn data type: BPCHAR(1)\nColumn description: Frecuencia con la que se espera que compre un distribuidor. 'A'=Anually(Anual), 'S'=Semestrally(Semestral), 'Q'=Quaterlly(Trimestral).",
#           "relevance_score": 0.8149842619895935
#         },
#         {
#           "content": "Column name: first_order_year\nColumn data type: INT4\nColumn description: Año de primera compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#           "relevance_score": 0.8124535083770752
#         },
#         {
#           "content": "Column name: business_type\nColumn data type: VARCHAR(20)\nColumn description: Tipo de negocio / tienda del que se trata. Ej. Value Added Reseller, Specialty Bike Shop, Warehouse",
#           "relevance_score": 0.8073215484619141
#         },
#         {
#           "content": "Column name: number_employees\nColumn data type: INT4\nColumn description: Cantidad de empleados de la tienda / distribuidor.",
#           "relevance_score": 0.8055285215377808
#         },
#         {
#           "content": "Column name: product_line\nColumn data type: VARCHAR(50)\nColumn description: Línea de productos en la que se especializa el distribuidor. Ej. Road, Mountain, Touring.",
#           "relevance_score": 0.8032394647598267
#         },
#         {
#           "content": "Column name: year_opened\nColumn data type: NUMERIC\nColumn description: Año de apertura de la tienda / distribuidor.",
#           "relevance_score": 0.8026675581932068
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_territory\nTable description: Tabla de dimensión que almacena la información detallada de cada cada división territorial de ventas. Relevante cuando se quieren hacer análisis de venta a nivel territorial.\nTable PRIMARY KEY:\n- sales_territory_key",
#         "relevance_score": 0.7996747493743896
#       },
#       "columns": [
#         {
#           "content": "Column name: sales_territory_country\nColumn data type: VARCHAR(50)\nColumn description: País al que corresponde cada territorio de ventas. Ej. United States, France.",
#           "relevance_score": 0.8017082512378693
#         },
#         {
#           "content": "Column name: sales_territory_group\nColumn data type: VARCHAR(50)\nColumn description: Agrupación territorial a la que pertenece cada territorio de ventas. Ej. North America, Europe.",
#           "relevance_score": 0.7989974021911621
#         },
#         {
#           "content": "Column name: sales_territory_region\nColumn data type: VARCHAR(50)\nColumn description: Región a la que corresponde cada territorio de ventas, contextualizado dentro de cada country. En caso de que no haya región, será el propio country. Ej. Southeast, France.",
#           "relevance_score": 0.796128511428833
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_person\nTable description: Tabla de dimensión que almacena la información detallada de cada vendedor. Relevante cuando se nos pide sacar información relativa a las ventas que ha hecho cada vendedor, ya que en esta tabla se tiene el nombre de cada uno.\nTable PRIMARY KEY:\n- employee_key",
#         "relevance_score": 0.7995401322841644
#       },
#       "columns": [
#         {
#           "content": "Column name: gender\nColumn data type: BPCHAR(1)\nColumn description: Género del vendedor. 'F'=Female(Mujer), 'M'=Male(Hombre)",
#           "relevance_score": 0.8095482289791107
#         },
#         {
#           "content": "Column name: employee_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del vendedor.",
#           "relevance_score": 0.8071202635765076
#         },
#         {
#           "content": "Column name: title\nColumn data type: VARCHAR(50)\nColumn description: Título que ese vendedor tiene dentro de la compañía como empleado.",
#           "relevance_score": 0.802083283662796
#         },
#         {
#           "content": "Column name: sales_person_flag\nColumn data type: BOOL\nColumn description: Indicador que se trata de un empleado vendedor. SIEMPRE vendrá a true.",
#           "relevance_score": 0.7972428500652313
#         }
#       ]
#     },
#     {
#       "table_summary": {
#         "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_geography\nTable description: Tabla de dimensión que almacena información detallada sobre datos geográficos. Relevante cuando se desea analizar información desglosada a nivel ciudades, códigos postales, estados, países, etc.\nTable PRIMARY KEY:\n- geography_key\nTable FOREIGN KEYS (Column name, Reference):\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#         "relevance_score": 0.7987412214279175
#       },
#       "columns": [
#         {
#           "content": "Column name: city\nColumn data type: VARCHAR(30)\nColumn description: Nombre de la ciudad.",
#           "relevance_score": 0.798180878162384
#         },
#         {
#           "content": "Column name: english_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (INGLÉS).",
#           "relevance_score": 0.7949206829071045
#         },
#         {
#           "content": "Column name: state_province_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del estado/provincia.",
#           "relevance_score": 0.7939503788948059
#         },
#         {
#           "content": "Column name: postal_code\nColumn data type: VARCHAR(15)\nColumn description: Código postal",
#           "relevance_score": 0.7914683222770691
#         },
#         {
#           "content": "Column name: spanish_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (ESPAÑOL).",
#           "relevance_score": 0.7902377247810364
#         },
#         {
#           "content": "Column name: state_province_code\nColumn data type: VARCHAR(3)\nColumn description: Código del estado/provincia.",
#           "relevance_score": 0.7893475592136383
#         },
#         {
#           "content": "Column name: country_region_code\nColumn data type: VARCHAR(3)\nColumn description: Código del país.",
#           "relevance_score": 0.7884237468242645
#         }
#       ]
#     }
#   ]
# ]

# %%
print(genai_relevant_docs)
# Out:
# [[{'table_summary': {'content': 'Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)', 'relevance_score': 0.8164840936660767}, 'columns': [{'content': 'Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.', 'relevance_score': 0.8307241499423981}, {'content': 'Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.', 'relevance_score': 0.8191922605037689}, {'content': 'Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.', 'relevance_score': 0.8191658854484558}, {'content': "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. 'reseller_sales'=Pedido realizado por un vendedor para una tienda/distribuidor, 'internet_sales'=Pedido realizado en línea por un cliente.", 'relevance_score': 0.8181345164775848}, {'content': 'Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado. Se debe priorizar esta fecha por sobre cualquiera de las otras para realizar cualquier cálculo relacionado con ventas.', 'relevance_score': 0.8162600994110107}, {'content': 'Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.', 'relevance_score': 0.8134251534938812}, {'content': 'Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. Se debe priorizar solo en los casos que se quieran calcular tiempos de preparación de pedidos. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.', 'relevance_score': 0.8130926191806793}, {'content': 'Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.', 'relevance_score': 0.812057763338089}, {'content': 'Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.', 'relevance_score': 0.8111943900585175}, {'content': 'Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.', 'relevance_score': 0.8065106272697449}, {'content': 'Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.', 'relevance_score': 0.80640709400177}, {'content': 'Column name: due_date\nColumn data type: DATE\nColumn des ...

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0)

SYSTEM_PROMPT = """
You are a context summarizer that receives retrieval documents in JSON format.
Your role is to:

1. Analyze the given JSON documents carefully.
2. Identify and extract only the information relevant to answer the user's question.
3. Summarize relevant tables, columns, keys, and descriptions into a clear and concise text.
4. Exclude any irrelevant or low-relevance details.
5. Ensure factual accuracy; do not fabricate information.
6. Do NOT generate or suggest any SQL queries.
7. When it is possible, match the language of the query fields to the user's query. For example, if user's query is in spanish, use `spanish_...`.
8. Match the language of the summary to the user's query.

Input:
- Retrieval documents (JSON): {retrieval_documents}

Output:
- A concise summary of relevant context—focused on tables, columns, keys, and descriptions—that will help generate an accurate SQL query. Don't suggest any query, only bring information in plain text. 
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': json.dumps(genai_relevant_docs, indent=2, ensure_ascii=False)
})

Markdown(contexto_resumido)
# Out:
# Para obtener información sobre los 10 artículos más comprados, se pueden considerar las siguientes tablas y columnas relevantes de la base de datos `adventure_works_dw`:
#
# 1. **Tabla: fact_sales**
#    - **Descripción**: Contiene el detalle de las órdenes de ventas entregadas, con granularidad a nivel de línea.
#    - **Claves Primarias**:
#      - sales_order_number
#      - sales_order_line_number
#    - **Columnas relevantes**:
#      - **order_quantity**: Cantidad vendida de cada producto.
#      - **product_key**: Clave del producto (relacionada con la tabla dim_product).
#
# 2. **Tabla: dim_product**
#    - **Descripción**: Almacena información detallada de cada producto vendido.
#    - **Clave Primaria**:
#      - product_key
#    - **Columnas relevantes**:
#      - **english_product_name**: Nombre del producto en inglés.
#      - **spanish_product_name**: Nombre del producto en español.
#      - **list_price**: Precio de venta del producto en USD.
#
# Para determinar los artículos más comprados, se puede utilizar la columna `order_quantity` de la tabla `fact_sales` junto con la clave del producto para hacer referencia a la tabla `dim_product` y obtener los nombres de los productos.

# %% [markdown]
# #### Conclusiones e Implementación Final
#
# Como podemos ver, siguiendo el mismo proceso para ambos modelos de embeddings, el modelo `gemini-embedding-001` de Google, aunque parece devolver resultados similares que los que se obtienen con `text-embedding-3-large` de OpenAI, consigue mejores resultados en términos de relevancia. Esto nos hace pensar que es mejor al capturar la semántica de nuestro documentos frente a la de las consultas.
#
# Esto puede deberse, en gran medida, a que , aunque ambos modelos presentan un **tamaño de embeddings de 3072**, el modelo de Google presenta un rendimiento destacable en tareas multilingües, como puede apreciarse en el [paper de su presentación](https://arxiv.org/html/2503.07891v1). Este es un punto no menor al trabajar nuestra documentación, ya que la misma mezcla conceptos en inglés (nombres de tablas y campos) y en español (descripciones), como asi también al momento de consultar, que podrá hacerse en cualquiera de estos 2 idiomas de manera indistinta.
#
# Teniendo en cuenta estas conclusiones, finalmente, **procedemos a implementar nuestras colecciones de `ChromaDB` de manera definitiva usando el modelo `gemini-embedding-001`**.

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)

mdl_hierarchical_genai_collection = MdlHierarchicalChromaCollections(
    persist_directory= CHROMA_DB_PATH,
    collection_names= (TABLES_SUMMARY_COLLECTION_NAME, COLUMNS_COLLECTION_NAME),
    create_collections_if_not_exists= True,
    embedding_function= genai_embeddings,
    collections_configuration= {'hnsw': {'space': 'cosine'}}
)

mdl_hierarchical_genai_collection.upsert_hierarchical_data(documents= (table_chunks, column_chunks))
# Out:
# (({'ids': ['427a1063-be9c-4cbf-a799-6bbc299e311f',
#     'ec141c68-7f70-4798-b535-89f210517b27',
#     '5f915455-cb64-45ff-8662-59b92e5b79a7',
#     '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#     'df28f29d-594b-485e-91e8-84f0ed2405e4',
#     '36845231-b072-4bcb-9f19-ef298119e2e2',
#     'cc03e2fd-d7c4-42c5-bd6c-aa05977ff1e5',
#     '61d35dc6-5611-43c7-980f-ce1d3ca443be',
#     'f1053ef3-cef7-4ed9-83f6-912b4f022b1d',
#     '6653bb58-4980-405e-9054-4e454af25fdf'],
#    'documents': ['Database: adventure_works_dw\nSchema: sales\nTable: dim_customer\nTable description: Tabla de dimensión que almacena la información detallada de cada cliente que haya comprado online (por internet), para el segmento minorista (B2C). Relevante cuando se hacen consultas relativas a clientes, como su nombre, análisis por género y estado civil o ingresos de los mismos.\nTable PRIMARY KEY:\n- customer_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_geography\nTable description: Tabla de dimensión que almacena información detallada sobre datos geográficos. Relevante cuando se desea analizar información desglosada a nivel ciudades, códigos postales, estados, países, etc.\nTable PRIMARY KEY:\n- geography_key\nTable FOREIGN KEYS (Column name, Reference):\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_product\nTable description: Tabla de dimensión que almacena la información detallada de cada producto que alguna vez haya sido vendido. Relevante para cualquier consulta en la que se nos pida listar productos por su nombre.\nTable PRIMARY KEY:\n- product_key',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_promotion\nTable description: Tabla de dimensión que almacena la información detallada de las diferentes promociones / descuentos que pueden aplicarse a las ventas. Relevante cuando se quiere segmentar las promociones que han sido aplicadas en las ventas.\nTable PRIMARY KEY:\n- promotion_key',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_reseller\nTable description: Tabla de dimensión que almacena la información detallada de cada tienda/distribuidor del segmento mayorista (B2B). Relevante siempre que se pida obtener listado con datos de tiendas/distribuidores porque en esta tabla se almacenan sus nombres.\nTable PRIMARY KEY:\n- reseller_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_person\nTable description: Tabla de dimensión que almacena la información detallada de cada vendedor. Relevante cuando se nos pide sacar información relativa a las ventas que ha hecho cada vendedor, ya que en esta tabla se tiene el nombre de cada uno.\nTable PRIMARY KEY:\n- employee_key',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_reason\nTable description: Tabla de dimensión que almacena la información detallada de cada motivo de venta. Relevante cuando se busca comprender los principales motivos por los que se han logrado las ventas.\nTable PRIMARY KEY:\n- sales_reason_key',
#     'Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_territory\nTable description: Tabla de dimensión que almacena la información detallada de cada cada división territorial de ventas. Relevante cuando se quieren hacer análisis de venta a nivel territorial.\nTable PRIMARY KEY:\n- sales_territory_key',
#     'Database: adventure_works_dw\nSchema: sales\nTable: fact_internet_sales_reason\nTable description: Tabla de referencias cruzadas que asigna líneas de ordenes de ventas a códigos de motivo de venta. La relación es de 1 línea de ordenes de ventas a N motivos de venta. La clave primaria de esta tabla se conforma por los tres campos que la componen en conjunto. Necesaria cuando se quieran analizar los motivos de ventas, ya que es la tabla que conecta las ventas con los motivos.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\n- sales_reason_key\nTable FOREIGN KEYS (Column name, Reference):\n- (sales_order_number, sales.fact_sales.sales_order_number)\n- (sales_order_line_number, sales.fact_sales.sales_order_line_number)\n- (sales_reason_key, sales.dim_sales_reason.sales_reason_key)',
#     'Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)'],
#    'metadatas': [{'database_name': 'adventure_works_dw',
#      'table_name': 'dim_customer',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f'},
#     {'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'table_name': 'dim_geography',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw'},
#     {'table_name': 'dim_product',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw'},
#     {'table_name': 'dim_promotion',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_reseller',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales'},
#     {'table_id': '36845231-b072-4bcb-9f19-ef298119e2e2',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_sales_person',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'table_id': 'cc03e2fd-d7c4-42c5-bd6c-aa05977ff1e5',
#      'table_name': 'dim_sales_reason'},
#     {'table_id': '61d35dc6-5611-43c7-980f-ce1d3ca443be',
#      'table_name': 'dim_sales_territory',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_id': 'f1053ef3-cef7-4ed9-83f6-912b4f022b1d',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'fact_internet_sales_reason'},
#     {'table_name': 'fact_sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales'}]},
#   {'ids': ['423bb90a-12b8-494a-8820-5650bfb2214b',
#     'c28acb2d-1cdb-4a87-ac0f-1a00f0495c18',
#     'cabbb2d5-aba6-40e4-906b-8c9fc54e7b77',
#     '33df9c66-f890-48de-94d0-c93cb59fce52',
#     'cc8e42d6-adcc-4ef2-9d46-16c625cb9c7f',
#     '31e42ce5-4c35-410b-ade7-3940ab34efd7',
#     '5ff31561-ac7c-4a5c-9336-a2d1e40a86a7',
#     '88a18721-4b33-40a9-89df-a576eca8e921',
#     '90127f9b-ace2-4a10-8be7-71ee1913edcb',
#     'bf98eb49-e76f-4991-8e4c-ef5f265ae568',
#     '60950c74-579f-4b6c-a2b5-1955edc68e2b',
#     'f86ae0a9-9368-48a7-b40b-d7c47d21bcdb',
#     'a586252e-8075-451e-b2b2-2e064815402b',
#     '1373b85b-3712-4adf-b09b-0caf4a079f99',
#     'f32895e7-b3f3-42b6-bcbf-a00882542bed',
#     '66324669-4bd3-4a1c-ac9c-30cf61eebcbc',
#     'ac3e60e2-7e53-45a9-a8b4-18e38ef63da1',
#     'f4a2081b-b4a3-44d9-88b1-253a78053d5c',
#     'de52e693-cfee-4fe3-96f9-206d456fed99',
#     '8dba4eb3-b7a8-4197-a7dc-d4200a916ae1',
#     '2f98109b-d433-4a90-8bad-41a5f0f9b5b6',
#     'bbfe6d47-d491-431a-9666-b78dbf47d6e9',
#     '78680165-75bf-4608-83dc-9f5777207625',
#     '40445bba-1bc8-4198-9149-6c57069dce87',
#     '41bbb80a-40fd-4f97-b328-d9a6a10e8ba4',
#     'a83086ae-9bb2-462c-8504-f8180cfe73b8',
#     '52600ad4-be41-4a0b-acd8-a98e2fcc99ad',
#     'bd2faefb-2023-4c85-9b1f-c47dc9b30dc0',
#     '36afe664-9001-4326-834c-fdf43e958f07',
#     '6aaf7f62-12ab-455a-ac43-be16237ba1f1',
#     '004e6407-1fcf-4348-8dd5-5d8f3a25a926',
#     'fc817a93-36a1-44a9-b31e-e2b37baf0bb9',
#     'a0440705-dafd-4daf-98ca-123ec6270ce4',
#     'd498c8f8-b209-4e33-82e9-453662806d49',
#     '202a80c2-a52e-4a8a-ae09-95e57980555b',
#     'c20a0428-0c95-4d34-98e0-9f13edaf2ba3',
#     '90d44db6-3e45-4aec-a9c5-d4feed3f3923',
#     'cd5aad31-4125-45eb-8b1f-141c68968f32',
#     '97a0b1b7-6512-4805-bb64-6f77d866f8f3',
#     '0448daf8-a94c-4164-8f4f-507c7390654c',
#     '4ebc33df-68c9-435b-a6be-a6d58158d8e7',
#     '7eef40d6-6aa5-41b0-a560-701cd72562d8',
#     '425503b1-aaa5-4508-b511-5553812602fa',
#     '3469bd58-330e-4d7b-bf1d-d8bbe4557264',
#     '480177ab-c497-499f-9cc1-9cb553e0b867',
#     '42df4a9c-4ba3-4d44-95ca-8f4c77ff99e6',
#     '6f5653f1-fc68-4249-bc9b-18150b0e13f1',
#     'b5c6812b-4193-4bd3-a636-0c214861c852',
#     '65b07234-1442-478d-aec4-b5db3633d30d',
#     '78b284e9-abcf-4ecc-a99d-1a6a47cb1bc0',
#     '7159d9ee-14d2-4d28-a3e3-5d3e5b309c69',
#     'b75a8d1f-5a75-4678-91f2-f9861cf3fa01',
#     '0b5114aa-f179-4c2f-b877-5f385b4634ed',
#     '2a719a3a-627c-4e9a-b5eb-878dfd02b939',
#     '5ee212aa-df8e-44ba-8d67-6b4bf691c3d4',
#     'b3a882c2-5c0f-4a2d-bc85-652cc00aa9e7',
#     '3a1fbcd7-a3e0-4e01-91e3-a526dae3ca46',
#     'a8ff44d8-d41c-4162-9636-7167a402a33d',
#     '81a5f8f8-8b2b-462a-a969-634ac133504b',
#     '4b255430-f6f0-4ac0-9d1b-09a26fd8f09b',
#     'd615cad4-7eb6-4c29-a805-bc6386d117a8',
#     '603c8c6a-f59a-4795-853e-516c6c52baae',
#     '2ab11ed5-1526-4d6d-b790-0bb56936acc2',
#     'c2f41e5d-ed09-4b23-9826-3a59cc8d6ebb',
#     'aa14829d-75df-4699-8119-37ff7cd634c5',
#     '3fd4fea8-9e83-43df-8a34-7ef9d35e8287',
#     '6f3bf3fe-ab6e-4a18-b31b-8fa0f47f20f2',
#     '363117ff-56e0-4a77-9606-cddd09ec4dfa',
#     '162dcebf-d7cf-45b2-b679-239a9772efaf',
#     '658566ca-b721-4e02-970a-36756f5aa01a',
#     'be8bad90-c0c9-4f57-911b-81e492aa4d8a',
#     '3ecd4834-b6ff-43ad-ba1f-f6ced123bf43',
#     '75cc2754-fe17-489f-8338-c0554dbca61a',
#     '619b1fec-2903-4263-9260-5f99405452ff',
#     'a5662032-0b44-4505-80f1-72dda28eae3c',
#     'c63e9863-7e58-42e5-bf50-6a950d5b38f9',
#     '7dfe8e4c-8739-4eba-a8b5-a09477bdfd3f',
#     '19f75d97-53fd-4e9e-bda3-7b84ee74dbbc',
#     '3caf47b1-e879-4901-9535-e96397ebfdc0',
#     'b7bca528-63d9-4659-b2da-d89823cf33f6',
#     '9d68409d-4392-4f5b-8304-418605a80409',
#     '2e41193b-0c80-43ca-8db8-8a7285da288a',
#     '855dfdbd-8921-4511-9f89-2a3b19bd75fd',
#     'be63ab51-74a7-45e1-9a11-30eca9b4615d',
#     'd4ac9df5-67e1-4fe5-8d5b-adddbf97116d',
#     'e9724bd2-193f-49ae-a656-1d3d63ce54c1',
#     'bcc77660-2b14-475a-9dc2-c54c7f592a45',
#     '372d41f0-6c30-46da-a69f-5b43f6307666',
#     '6b42e8b4-4833-4e28-9d26-68c6deb0ed75',
#     'ee72a466-3eb3-40bd-a497-19cf8adc060e'],
#    'documents': ['Column name: customer_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del cliente.',
#     'Column name: birth_date\nColumn data type: DATE\nColumn description: Fecha de nacimiento del cliente.',
#     "Column name: marital_status\nColumn data type: BPCHAR(1)\nColumn description: Estado civil del cliente. 'M'=Married(Casada/o), 'S'=Single(Soltera/o)",
#     "Column name: gender\nColumn data type: VARCHAR(1)\nColumn description: Género del cliente. 'F'=Female(Mujer), 'M'=Male(Hombre)",
#     'Column name: yearly_income\nColumn data type: NUMERIC\nColumn description: Ingreso anual del cliente en USD.',
#     'Column name: total_children\nColumn data type: INT2\nColumn description: Cantidad total de hijos del cliente.',
#     'Column name: number_children_at_home\nColumn data type: INT2\nColumn description: Cantidad total de hijos convivientes del cliente.',
#     'Column name: english_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (INGLÉS).',
#     'Column name: spanish_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (ESPAÑOL).',
#     'Column name: english_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (INGLÉS).',
#     'Column name: spanish_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (ESPAÑOL).',
#     "Column name: house_owner\nColumn data type: BOOL\nColumn description: Indicador de si el cliente es propietario. 'True'=Propietario, 'False'=No Propietario",
#     'Column name: number_cars_owned\nColumn data type: INT2\nColumn description: Cantidad de tarjetas de crédito que posee el cliente.',
#     "Column name: commute_distance\nColumn data type: VARCHAR(15)\nColumn description: Distancia entre la casa del cliente y su lugar habitual de trabajo. Segmentado en 5 categorías: ['0-1 Miles', '1-2 Miles', '2-5 Miles', '5-10 Miles', '10+ Miles']",
#     'Column name: city\nColumn data type: VARCHAR(30)\nColumn description: Nombre de la ciudad.',
#     'Column name: state_province_code\nColumn data type: VARCHAR(3)\nColumn description: Código del estado/provincia.',
#     'Column name: state_province_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del estado/provincia.',
#     'Column name: country_region_code\nColumn data type: VARCHAR(3)\nColumn description: Código del país.',
#     'Column name: english_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (INGLÉS).',
#     'Column name: spanish_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (ESPAÑOL).',
#     'Column name: postal_code\nColumn data type: VARCHAR(15)\nColumn description: Código postal',
#     'Column name: weight_unit_measure_code\nColumn data type: BPCHAR(3)\nColumn description: Unidad de medida de peso. Algunos artículos no lo tienen configurado y viene a NULL.',
#     'Column name: size_unit_measure_code\nColumn data type: BPCHAR(3)\nColumn description: Unidad de medida de tamaño. Algunos artículos no lo tienen configurado y viene a NULL.',
#     'Column name: english_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (INGLÉS). NUNCA viene a NULL.',
#     'Column name: spanish_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (ESPAÑOL). Puede venir a NULL.',
#     'Column name: standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar del producto en USD.',
#     "Column name: finished_goods_flag\nColumn data type: BOOL\nColumn description: Indicador de si se trata de un producto final vendible. '0'=El producto no es un artículo vendible, '1'=El producto es vendible.",
#     "Column name: color\nColumn data type: VARCHAR(15)\nColumn description: Color del producto. Para los casos donde no corresponda, se identifica con un 'NA'.",
#     'Column name: safety_stock_level\nColumn data type: INT2\nColumn description: Nivel de stock mínimo del producto.',
#     'Column name: reorder_point\nColumn data type: INT2\nColumn description: Nivel de stock que dispara una orden de compra o una orden de trabajo.',
#     'Column name: list_price\nColumn data type: NUMERIC\nColumn description: Precio de venta del producto en USD.',
#     'Column name: size\nColumn data type: VARCHAR(50)\nColumn description: Talla del producto. Ej. 48, L. Puede venir a NULL.',
#     "Column name: size_range\nColumn data type: VARCHAR(50)\nColumn description: Rango dentro del que entra la talla del producto. Ej.: 48-52 CM, L. En caso de no aplique, se indica un 'NA'. Puede venir a NULL.",
#     'Column name: weight\nColumn data type: FLOAT8\nColumn description: Peso del producto. Puede venir a NULL.',
#     'Column name: days_to_manufacture\nColumn data type: INT4\nColumn description: Número de días necesarios para fabricar el producto.',
#     "Column name: product_line\nColumn data type: BPCHAR(2)\nColumn description: Línea a la que pertence el producto. 'R'=Road(Carretera), 'M'=Mountain(Montaña), 'T'=Touring(Turismo), 'S'=Standard(Estándar). Puede venir a NULL.",
#     'Column name: dealer_price\nColumn data type: NUMERIC\nColumn description: Precio de distribuidor en USD.',
#     "Column name: class\nColumn data type: BPCHAR(2)\nColumn description: Gama a la que pertenece el producto. 'H'=High(Alta), 'M'=Medium(Media), 'L'=Low(Baja). Puede venir a NULL.",
#     "Column name: style\nColumn data type: BPCHAR(2)\nColumn description: Público para el que está pensado el producto. 'W'=Womens(Mujeres), 'M'=Mens(Hombres), 'U'=Universal.  Puede venir a NULL.",
#     'Column name: model_name\nColumn data type: VARCHAR(50)\nColumn description: Modelo al que pertenece el producto. NUNCA será NULL.',
#     'Column name: english_description\nColumn data type: VARCHAR(400)\nColumn description: Descripción detallada del producto (INGLÉS). NUNCA viene a NULL.',
#     'Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto estuvo disponible para la venta.',
#     'Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto dejó de estar disponible para la venta. En caso de que siga disponible, vendrá a NULL.',
#     'Column name: active\nColumn data type: BOOL\nColumn description: Indicador de si el producto sigue disponible para la venta.',
#     "Column name: english_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (INGLÉS). Las categorías son 'Clothing', 'Components', 'Accessories' y 'Bikes'. NUNCA viene a NULL.",
#     "Column name: spanish_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (ESPAÑOL). Las categorías son 'Prenda', 'Componente', 'Accesorio' y 'Bicicleta'  NUNCA viene a NULL.",
#     'Column name: english_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (INGLÉS). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.',
#     'Column name: spanish_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (ESPAÑOL). Cada categoría puede tener múltiples sub-categorías, llegando a tener hasta 150 valores diferentes. NUNCA viene a NULL.',
#     'Column name: english_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (INGLÉS). NUNCA será NULL.',
#     'Column name: spanish_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (ESPAÑOL). NUNCA será NULL.',
#     'Column name: discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicable a la promoción, en decimal. Comprendido entre 0 y 1. NUNCA será NULL. Ej. 0, 0.02, 0.05.',
#     'Column name: english_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (INGLÉS). NUNCA será NULL. Ej. No Discount, Volume Discount, Seasonal Discount.',
#     'Column name: spanish_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (ESPAÑOL). NUNCA será NULL. Ej. Sin descuento, Descuento por volumen, Descuento de temporada.',
#     'Column name: english_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (INGLÉS). NUNCA será NULL. Indica si es aplicable a un distribuidor (Reseller) o a un cliente final (Customer).',
#     'Column name: spanish_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (ESPAÑOL). NUNCA será NULL. Indica si es aplicable a un distribuidor (Distribuidor) o a un cliente final (Cliente).',
#     'Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que comienza a ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.',
#     'Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que deja de ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.',
#     'Column name: min_qty\nColumn data type: INT4\nColumn description: Cantidad mínima necesaria para aplicar la promoción. NUNCA será NULL.',
#     'Column name: max_qty\nColumn data type: INT4\nColumn description: Cantidad máxima a la que será aplicable la promoción. En caso de venir a NULL, significa que no hay límite.',
#     'Column name: business_type\nColumn data type: VARCHAR(20)\nColumn description: Tipo de negocio / tienda del que se trata. Ej. Value Added Reseller, Specialty Bike Shop, Warehouse',
#     'Column name: reseller_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre de la tienda / distribuidor.',
#     'Column name: number_employees\nColumn data type: INT4\nColumn description: Cantidad de empleados de la tienda / distribuidor.',
#     "Column name: order_frequency\nColumn data type: BPCHAR(1)\nColumn description: Frecuencia con la que se espera que compre un distribuidor. 'A'=Anually(Anual), 'S'=Semestrally(Semestral), 'Q'=Quaterlly(Trimestral).",
#     'Column name: first_order_year\nColumn data type: INT4\nColumn description: Año de primera compra del distribuidor. Si viene a NULL es que nunca ha comprado.',
#     'Column name: last_order_year\nColumn data type: INT4\nColumn description: Año de última compra del distribuidor. Si viene a NULL es que nunca ha comprado.',
#     'Column name: product_line\nColumn data type: VARCHAR(50)\nColumn description: Línea de productos en la que se especializa el distribuidor. Ej. Road, Mountain, Touring.',
#     'Column name: year_opened\nColumn data type: NUMERIC\nColumn description: Año de apertura de la tienda / distribuidor.',
#     'Column name: employee_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del vendedor.',
#     'Column name: title\nColumn data type: VARCHAR(50)\nColumn description: Título que ese vendedor tiene dentro de la compañía como empleado.',
#     "Column name: gender\nColumn data type: BPCHAR(1)\nColumn description: Género del vendedor. 'F'=Female(Mujer), 'M'=Male(Hombre)",
#     'Column name: sales_person_flag\nColumn data type: BOOL\nColumn description: Indicador que se trata de un empleado vendedor. SIEMPRE vendrá a true.',
#     'Column name: sales_reason_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del motivo de venta. NUNCA viene a NULL.Ej. Price, On Promotion, Magazine Advertisement.',
#     'Column name: sales_reason_reason_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo del motivo de venta. NUNCA viene a NULL. Ej. Other, Promotion, Marketing.',
#     'Column name: sales_territory_region\nColumn data type: VARCHAR(50)\nColumn description: Región a la que corresponde cada territorio de ventas, contextualizado dentro de cada country. En caso de que no haya región, será el propio country. Ej. Southeast, France.',
#     'Column name: sales_territory_country\nColumn data type: VARCHAR(50)\nColumn description: País al que corresponde cada territorio de ventas. Ej. United States, France.',
#     'Column name: sales_territory_group\nColumn data type: VARCHAR(50)\nColumn description: Agrupación territorial a la que pertenece cada territorio de ventas. Ej. North America, Europe.',
#     'Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.',
#     'Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.',
#     'Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.',
#     'Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.',
#     'Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.',
#     'Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.',
#     'Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.',
#     'Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.',
#     'Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.',
#     'Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.',
#     'Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado.',
#     'Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.',
#     'Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.',
#     "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. 'reseller_sales'=Pedido realizado por un vendedor para una tienda/distribuidor, 'internet_sales'=Pedido realizado en línea por un cliente."],
#    'metadatas': [{'column_data_type': 'TEXT',
#      'table_name': 'dim_customer',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'customer_full_name'},
#     {'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_customer',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'column_data_type': 'DATE',
#      'column_name': 'birth_date'},
#     {'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'BPCHAR(1)',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'column_name': 'marital_status',
#      'table_name': 'dim_customer'},
#     {'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'column_name': 'gender',
#      'column_data_type': 'VARCHAR(1)',
#      'table_name': 'dim_customer',
#      'database_name': 'adventure_works_dw'},
#     {'column_name': 'yearly_income',
#      'database_name': 'adventure_works_dw',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_customer',
#      'column_data_type': 'NUMERIC'},
#     {'column_data_type': 'INT2',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_name': 'total_children',
#      'table_name': 'dim_customer'},
#     {'table_name': 'dim_customer',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_name': 'number_children_at_home',
#      'column_data_type': 'INT2',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'english_education',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_customer',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(40)'},
#     {'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(40)',
#      'column_name': 'spanish_education',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'table_name': 'dim_customer'},
#     {'table_name': 'dim_customer',
#      'column_name': 'english_occupation',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_data_type': 'VARCHAR(100)'},
#     {'database_name': 'adventure_works_dw',
#      'column_data_type': 'VARCHAR(100)',
#      'schema_name': 'sales',
#      'table_name': 'dim_customer',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_name': 'spanish_occupation',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'table_name': 'dim_customer',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'house_owner',
#      'column_data_type': 'BOOL',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'database_name': 'adventure_works_dw',
#      'column_data_type': 'INT2',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_name': 'number_cars_owned',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_name': 'dim_customer'},
#     {'database_name': 'adventure_works_dw',
#      'table_id': '427a1063-be9c-4cbf-a799-6bbc299e311f',
#      'column_name': 'commute_distance',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(15)',
#      'table_name': 'dim_customer',
#      'schema_name': 'sales'},
#     {'schema_name': 'sales',
#      'table_name': 'dim_geography',
#      'column_data_type': 'VARCHAR(30)',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'column_name': 'city'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_geography',
#      'column_name': 'state_province_code',
#      'database_name': 'adventure_works_dw',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'column_data_type': 'VARCHAR(3)',
#      'schema_name': 'sales'},
#     {'database_name': 'adventure_works_dw',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_geography',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales',
#      'column_name': 'state_province_name'},
#     {'column_name': 'country_region_code',
#      'table_name': 'dim_geography',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'column_data_type': 'VARCHAR(3)',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'column_data_type': 'VARCHAR(50)',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'table_name': 'dim_geography',
#      'column_name': 'english_country_region_name'},
#     {'table_name': 'dim_geography',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(50)',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'schema_name': 'sales',
#      'column_name': 'spanish_country_region_name'},
#     {'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(15)',
#      'table_name': 'dim_geography',
#      'table_id': 'ec141c68-7f70-4798-b535-89f210517b27',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'postal_code',
#      'database_name': 'adventure_works_dw'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'BPCHAR(3)',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'weight_unit_measure_code',
#      'schema_name': 'sales'},
#     {'schema_name': 'sales',
#      'column_name': 'size_unit_measure_code',
#      'column_data_type': 'BPCHAR(3)',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_product',
#      'database_name': 'adventure_works_dw',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7'},
#     {'schema_name': 'sales',
#      'column_name': 'english_product_name',
#      'column_data_type': 'VARCHAR(50)',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'spanish_product_name',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'table_name': 'dim_product',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'standard_cost',
#      'schema_name': 'sales',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'NUMERIC'},
#     {'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_name': 'finished_goods_flag',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'BOOL'},
#     {'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'color',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_product',
#      'column_data_type': 'VARCHAR(15)',
#      'schema_name': 'sales'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'safety_stock_level',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_data_type': 'INT2'},
#     {'database_name': 'adventure_works_dw',
#      'column_data_type': 'INT2',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_name': 'reorder_point',
#      'table_name': 'dim_product',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'database_name': 'adventure_works_dw',
#      'table_name': 'dim_product',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'list_price',
#      'column_data_type': 'NUMERIC'},
#     {'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'table_name': 'dim_product',
#      'column_name': 'size',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales'},
#     {'table_name': 'dim_product',
#      'column_name': 'size_range',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_data_type': 'FLOAT8',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'weight',
#      'table_name': 'dim_product'},
#     {'column_name': 'days_to_manufacture',
#      'column_data_type': 'INT4',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_name': 'dim_product'},
#     {'column_data_type': 'BPCHAR(2)',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'product_line',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_product',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7'},
#     {'table_name': 'dim_product',
#      'column_name': 'dealer_price',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'NUMERIC',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'class',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_data_type': 'BPCHAR(2)',
#      'table_name': 'dim_product'},
#     {'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_data_type': 'BPCHAR(2)',
#      'table_name': 'dim_product',
#      'column_name': 'style'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(50)',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'model_name',
#      'table_name': 'dim_product'},
#     {'schema_name': 'sales',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'english_description',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'VARCHAR(400)'},
#     {'table_name': 'dim_product',
#      'column_data_type': 'DATE',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_name': 'start_date',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales'},
#     {'column_name': 'end_date',
#      'column_data_type': 'DATE',
#      'schema_name': 'sales',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'column_data_type': 'BOOL',
#      'column_name': 'active',
#      'table_name': 'dim_product',
#      'schema_name': 'sales',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw'},
#     {'column_name': 'english_product_category_name',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(50)',
#      'table_name': 'dim_product',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales',
#      'table_name': 'dim_product',
#      'column_name': 'spanish_product_category_name',
#      'database_name': 'adventure_works_dw'},
#     {'column_data_type': 'VARCHAR(50)',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'column_name': 'english_product_subcategory_name',
#      'table_name': 'dim_product',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'spanish_product_subcategory_name',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(50)',
#      'table_id': '5f915455-cb64-45ff-8662-59b92e5b79a7',
#      'table_name': 'dim_product'},
#     {'database_name': 'adventure_works_dw',
#      'column_data_type': 'VARCHAR(255)',
#      'column_name': 'english_promotion_name',
#      'table_name': 'dim_promotion',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80'},
#     {'column_name': 'spanish_promotion_name',
#      'table_name': 'dim_promotion',
#      'column_data_type': 'VARCHAR(255)',
#      'schema_name': 'sales',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'column_data_type': 'FLOAT8',
#      'table_name': 'dim_promotion',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'column_name': 'discount_pct',
#      'database_name': 'adventure_works_dw'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'english_promotion_type',
#      'table_name': 'dim_promotion',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw'},
#     {'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_name': 'dim_promotion',
#      'column_data_type': 'VARCHAR(50)',
#      'column_name': 'spanish_promotion_type',
#      'database_name': 'adventure_works_dw'},
#     {'column_data_type': 'VARCHAR(50)',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'schema_name': 'sales',
#      'column_name': 'english_promotion_category',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_promotion',
#      'database_name': 'adventure_works_dw'},
#     {'table_name': 'dim_promotion',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(50)',
#      'column_name': 'spanish_promotion_category',
#      'database_name': 'adventure_works_dw',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80'},
#     {'column_data_type': 'DATE',
#      'table_name': 'dim_promotion',
#      'column_name': 'start_date',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw'},
#     {'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'DATE',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_promotion',
#      'column_name': 'end_date',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80'},
#     {'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80',
#      'column_data_type': 'INT4',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'min_qty',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_promotion'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'INT4',
#      'table_name': 'dim_promotion',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'max_qty',
#      'schema_name': 'sales',
#      'table_id': '3ded2fe5-7a89-4e82-86ca-9f677c13bd80'},
#     {'column_name': 'business_type',
#      'table_name': 'dim_reseller',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(20)',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw'},
#     {'table_name': 'dim_reseller',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'column_name': 'reseller_name',
#      'column_data_type': 'VARCHAR(50)',
#      'database_name': 'adventure_works_dw'},
#     {'column_data_type': 'INT4',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'schema_name': 'sales',
#      'column_name': 'number_employees',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_reseller',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'database_name': 'adventure_works_dw',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'column_name': 'order_frequency',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'BPCHAR(1)',
#      'table_name': 'dim_reseller',
#      'schema_name': 'sales'},
#     {'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'column_data_type': 'INT4',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'first_order_year',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'dim_reseller'},
#     {'column_data_type': 'INT4',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_reseller',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'column_name': 'last_order_year'},
#     {'column_data_type': 'VARCHAR(50)',
#      'column_name': 'product_line',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'dim_reseller',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'schema_name': 'sales'},
#     {'column_name': 'year_opened',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'NUMERIC',
#      'table_name': 'dim_reseller',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': 'df28f29d-594b-485e-91e8-84f0ed2405e4',
#      'schema_name': 'sales'},
#     {'table_id': '36845231-b072-4bcb-9f19-ef298119e2e2',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'TEXT',
#      'column_name': 'employee_full_name',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_name': 'dim_sales_person'},
#     {'table_id': '36845231-b072-4bcb-9f19-ef298119e2e2',
#      'column_data_type': 'VARCHAR(50)',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'title',
#      'table_name': 'dim_sales_person'},
#     {'schema_name': 'sales',
#      'table_id': '36845231-b072-4bcb-9f19-ef298119e2e2',
#      'table_name': 'dim_sales_person',
#      'column_data_type': 'BPCHAR(1)',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'gender',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'table_id': '36845231-b072-4bcb-9f19-ef298119e2e2',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'sales_person_flag',
#      'table_name': 'dim_sales_person',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'column_data_type': 'BOOL'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(50)',
#      'table_name': 'dim_sales_reason',
#      'database_name': 'adventure_works_dw',
#      'table_id': 'cc03e2fd-d7c4-42c5-bd6c-aa05977ff1e5',
#      'column_name': 'sales_reason_name'},
#     {'table_name': 'dim_sales_reason',
#      'column_data_type': 'VARCHAR(50)',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': 'cc03e2fd-d7c4-42c5-bd6c-aa05977ff1e5',
#      'column_name': 'sales_reason_reason_type'},
#     {'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'table_id': '61d35dc6-5611-43c7-980f-ce1d3ca443be',
#      'table_name': 'dim_sales_territory',
#      'column_data_type': 'VARCHAR(50)',
#      'column_name': 'sales_territory_region'},
#     {'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'sales_territory_country',
#      'table_id': '61d35dc6-5611-43c7-980f-ce1d3ca443be',
#      'table_name': 'dim_sales_territory',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'VARCHAR(50)'},
#     {'column_name': 'sales_territory_group',
#      'table_name': 'dim_sales_territory',
#      'table_id': '61d35dc6-5611-43c7-980f-ce1d3ca443be',
#      'schema_name': 'sales',
#      'column_data_type': 'VARCHAR(50)',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'database_name': 'adventure_works_dw'},
#     {'database_name': 'adventure_works_dw',
#      'column_name': 'order_quantity',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'schema_name': 'sales',
#      'table_name': 'fact_sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'INT2'},
#     {'database_name': 'adventure_works_dw',
#      'column_data_type': 'NUMERIC',
#      'schema_name': 'sales',
#      'table_name': 'fact_sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'column_name': 'unit_price'},
#     {'column_data_type': 'NUMERIC',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'schema_name': 'sales',
#      'column_name': 'extended_amount',
#      'table_name': 'fact_sales',
#      'database_name': 'adventure_works_dw'},
#     {'column_name': 'unit_price_discount_pct',
#      'schema_name': 'sales',
#      'column_data_type': 'FLOAT8',
#      'table_name': 'fact_sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'database_name': 'adventure_works_dw'},
#     {'database_name': 'adventure_works_dw',
#      'column_name': 'discount_amount',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_name': 'fact_sales',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'schema_name': 'sales',
#      'column_data_type': 'FLOAT8'},
#     {'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'column_name': 'product_standard_cost',
#      'column_data_type': 'NUMERIC',
#      'schema_name': 'sales',
#      'table_name': 'fact_sales'},
#     {'column_name': 'total_product_cost',
#      'schema_name': 'sales',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'column_data_type': 'NUMERIC',
#      'table_name': 'fact_sales'},
#     {'column_data_type': 'NUMERIC',
#      'column_name': 'sales_amount',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'database_name': 'adventure_works_dw',
#      'table_name': 'fact_sales',
#      'schema_name': 'sales'},
#     {'schema_name': 'sales',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'table_name': 'fact_sales',
#      'database_name': 'adventure_works_dw',
#      'column_data_type': 'NUMERIC',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_name': 'tax_amt'},
#     {'column_data_type': 'NUMERIC',
#      'schema_name': 'sales',
#      'column_name': 'freight',
#      'table_name': 'fact_sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'database_name': 'adventure_works_dw'},
#     {'table_name': 'fact_sales',
#      'column_data_type': 'DATE',
#      'database_name': 'adventure_works_dw',
#      'schema_name': 'sales',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'column_name': 'order_date'},
#     {'database_name': 'adventure_works_dw',
#      'column_name': 'due_date',
#      'schema_name': 'sales',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'table_name': 'fact_sales',
#      'column_data_type': 'DATE',
#      'file_name': 'MDL_adventure_works_dw.yaml'},
#     {'schema_name': 'sales',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf',
#      'database_name': 'adventure_works_dw',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'column_data_type': 'DATE',
#      'column_name': 'ship_date',
#      'table_name': 'fact_sales'},
#     {'column_data_type': 'TEXT',
#      'file_name': 'MDL_adventure_works_dw.yaml',
#      'schema_name': 'sales',
#      'table_name': 'fact_sales',
#      'database_name': 'adventure_works_dw',
#      'column_name': 'sale_source',
#      'table_id': '6653bb58-4980-405e-9054-4e454af25fdf'}]}),
#  (['8f442e80-6240-4071-88d5-ae9925d729df',
#    '568d6995-778e-4a28-911a-67e997c878d2',
#    '82a8ade4-8109-4f39-8315-5170ff29ad68',
#    '053ca97b-75d2-485f-9c59-b31066329272',
#    'a4f08a0d-fbca-4c3d-8dbe-5369c85b6ac6',
#    'c6bf463a-b903-45af-a89a-39774dc76778',
#    'cf1459a1-09df-4a26-b677-9cc387cd86d9',
#    '314cc945-bd9f-4e63-9d72-90fc3bdf267d',
#    'c85424e7-834c-48ec-9eac-2d21ae76685d',
#    '85e28078-2e08-4019-8ce9-3f4bf4438e1c'],
#   ['01fc4477-7d83-4e0c-9b48-7c98eb1bc731',
#    '8791f4eb-04c8-49ee-91b1-22e47273e7b8',
#    '6a9f379f-9fe1-4d65-acd0-9a33387a6215',
#    'ca91c76f-0cf2-4034-aa89-d588416c6a57',
#    'ff213c1d-0e4b-44d9-9e28-1cce7120de56',
#    '1b12b55e-e44d-4c27-8966-cf5af29b56be',
#    'eb665c0f-2515-4467-9c29-a7cb3e020b0b',
#    'eaa49833-121b-42bc-8de6-6a1673fe7eae',
#    '2ac88db1-c46f-4714-b78f-ee3e08ffb56b',
#    '725a2d3d-8893-44e0-9ee5-27805af17889',
#    '8f7c3ca5-7394-495d-bdef-d1d229d88a40',
#    '7ab12d07-8de2-463e-a778-b1eb58e22f1e',
#    '57cd72f1-2e71-4920-b2e7-76620b3739f9',
#    '8a67ca44-833c-47ef-a42b-6386a0512687',
#    '143b1fda-5887-4de3-83db-b5f4be969d96',
#    '8b635f7e-7a7e-459d-897f-65b1b05f847d',
#    '460921cf-4008-44e4-8e24-cd1a7d5553f7',
#    'e0847fdf-c572-4858-8082-8810e399560f',
#    '1c0a09a7-51b7-423b-ab77-cf8d6211ac9a',
#    'ac8e2f4a-f67e-42c8-858d-6b9296a83530',
#    'e49fb8f5-b874-4290-8652-a4673e7930de',
#    'c65f25cb-9725-4abf-83a0-6991b55ef956',
#    'c10d13e0-a844-4db3-a587-fdb0281f7ab3',
#    'c68c473e-e195-4e83-886e-4b170621031b',
#    'f087db95-d0a5-4599-b3e6-2ba274b1f4c6',
#    '34ad30ae-87a4-4e93-b35b-859fbbe41cc2',
#    '9fc37951-8732-4e67-bf91-f3c4292f7199',
#    'be0308f8-605f-4133-988b-491b7fb85b45',
#    '9315a14e-11d0-45b5-a5e4-714123e32c5e',
#    '3f6eb285-1811-4195-99c2-a9994e130ce6',
#    '043eeab9-d4f6-491a-840d-6d574e055046',
#    'f19fa7d1-ff68-44f6-9947-6096f48ebc5c',
#    '34745f2a-a758-4918-950f-4dca618090d0',
#    '93d1bf75-54a8-43df-815c-490f48592b5f',
#    '584b8c21-3ccf-44c9-b094-356e18d14171',
#    '3406851a-d535-4359-a0fd-1da0680cd5b0',
#    '1392c4ad-7cda-46cb-ae5c-05ac63c972ae',
#    '36cb5608-d02c-446c-ab0a-20d2dd5f0f7d',
#    'ae1ff820-bf5f-4533-86f8-ebdcded4fb9f',
#    '5c6beb40-e745-42ae-8ccf-196277e43291',
#    '4e4eb24a-d20c-412b-a917-38854836d955',
#    '334b5f01-a4be-4255-a0f0-8a2331b3dc68',
#    '03e95dca-c01f-4a7c-a9b9-15f270d7074e',
#    'e2281cfb-5f57-444e-b5e8-e44199a8dcae',
#    '1b34de47-5653-49ab-98fe-6023269d518f',
#    '25d9faa1-9123-44ca-bb2f-8525a3c4eaa6',
#    'fb7d95ce-a75d-4a18-80a6-ca02c6c012af',
#    '9a09bd34-1f3b-43ad-9eaa-e1960355d8e0',
#    '990c5ea3-65b7-4995-8dee-05c047fff1a4',
#    'd1708a72-a52b-48da-9db4-0c7a483eea7e',
#    '826f7bc6-2c58-4508-8748-4fcb8dddf320',
#    '9c222a9f-e9a8-43cb-a5ab-b5717f29a18d',
#    '05707b43-c73b-4977-90a3-4454a04508c1',
#    'f094dacc-f4f2-4602-8596-34de14ffe5f5',
#    'c07360ea-dda5-44ff-8b95-c3f1a4550630',
#    '95498a5a-c21e-4d77-8eed-e0e72efdfc91',
#    'd8e5f96e-7ebd-43b9-bdeb-c2962545bd0d',
#    '7e023ea6-cbfb-4d34-b286-5d5632202f91',
#    'dcf63147-0438-4a11-97f7-775620a1a9ca',
#    '51cafdab-cfc4-4416-a55f-04af7d9a0d75',
#    '14680578-c735-4475-a166-5e6ef98a7cf7',
#    '5cbaf4b3-9bcb-48c9-a372-49f220b9f4bf',
#    '79c7c867-d129-42d0-8a49-95c7e7b70912',
#    '0ef7bd61-8bb2-4ac3-9468-dc7ccb8f2df7',
#    'f48b69e5-97ef-4742-a940-b60e107a42a4',
#    '56b1ebf0-7c2c-4b0a-9021-02d04d00efd7',
#    '6d90fe9b-2225-42c7-80fb-aa19fa3b7d7a',
#    'bbe5c477-ea6c-4977-9bbc-0ef871cf79f6',
#    '210b3c52-989e-481e-aca1-5a7c1cd95f8b',
#    '52220d5e-109c-4f38-9da0-9dbb1de3c6ae',
#    'e42de227-963c-4178-a8f8-a80fd2cdadaf',
#    'f52d329d-59a5-41fd-9513-861e07afe697',
#    '432c7947-0e4a-46da-9e19-0731a7d4f292',
#    '46bf1602-0cb3-45dd-b055-ea2ecb3d7c71',
#    '8025cde0-4b67-421f-bc11-ef70570785f7',
#    'e28ac989-e4d7-4efd-82c2-a974f3c585af',
#    'ef8a2fbd-202c-4e86-acad-7f95c7ad9ec6',
#    'de73919e-1a2c-4536-a8de-6c5b8368c284',
#    '78e5532c-c955-4100-8acb-42b3f0ba3237',
#    'ec2be366-b365-4473-8954-7d4e21c89483',
#    '89f832e6-69d3-4b08-9896-e0cf6417d6c1',
#    'b617b4b0-196d-4a85-98d1-2e20b6d892ff',
#    '69fce216-2078-4378-a256-08ba816cda5a',
#    'b63d42c1-d730-42fb-9b84-13673e2351d9',
#    '45675f81-6651-45c0-84cd-d3611aec9146',
#    'cdd78528-bbdf-49cd-ad83-6673a77efb05',
#    '06044300-5bb5-4460-bd0e-93aadb821d18',
#    'fd291d5e-f81d-44ca-8981-6d364e136be2',
#    '364e244e-df0f-440d-8c64-30f7ffd4c5e9',
#    '4b7e3a98-a953-47db-8f54-09ca4f0309a9']))

# %% [markdown]
# ---
#
# ## Fichero MarkDown con Reglas de Negocio
#
# El objetivo de esta sección es procesar un fichero MarkDown que contien lógica de negocio. Para esto, debemos cargarlo, generar los chunks de una manera que sean semánticamente relevantes, generar su metadata si creemos que corresponde, y, finalmente generar sus embeddings y almacenarlos en una colescción de nuestra base de datos vectorial ChromaDB.
#
# Como primer paso, procedemos a cargar el fichero y a ver un poco de su aspecto:

# %% [markdown]
# ### Chunking
#
# Ahora definimos algunas funciones que nos permitirán actualizar el contenido MarkDown de nuestro fichero, y de sus chunks. Esto es necesario debido a que la clase nativa de LangChain `MarkdownHeaderTextSplitter` no solo que no "limpia" el contenido del MarkDown, si no que también internamente durante su procesamiento utiliza `.strip()` sobre las líneas que conforman el texto MarkDown, lo que hace que se pierda la jerarquía del mismo.

# %% [markdown]
# Utilizaremos como primer método de chunking un `MarkdownHeaderTextSplitter`, para luego aplicar un `RecursiveCharacterTextSplitter` que nos permita llevar los chunks al tamaño deseado. Finalmente, añadiremos en la metadata de cada chunk un `id` que lo identifique de forma única dentro de la combinación de headers que presente en la metadata.

# %%
md_splitter = ExtendedMarkdownSplitter(
    chunk_size= BUSINESS_RULES_CHUNK_SIZE,
    chunk_overlap= BUSINESS_RULES_CHUNK_OVERLAP
)

md_text = md_splitter._load_md_text(BUSINESS_RULES_PATH, encoding='utf-8')
Markdown(md_text[500:2000])
# Out:
#  y la operacionalización de la inteligencia de negocio.
#
# ## 1. Representación de Entidades y Preferencias Lingüísticas
#
# Cuando se solicita conceptualmente una entidad, como "productos", "clientes", "promociones" o "revendedores", se establece como principio operativo priorizar los campos que finalizan en `_name` para su adecuada representación en las salidas de las consultas SQL. Adicionalmente, se procurará mantener la coherencia con el idioma en que la consulta original fue formulada.
#
# - **Principio Operativo:** Para la visualización de entidades en los resultados de consultas, se debe seleccionar el campo `_name` que mejor represente la entidad. En el caso de campos bilingües donde la versión en español (`spanish_..._name`, `spanish_..._description`) pueda ser nula y la consulta se realice en español, se utilizará la versión en inglés como alternativa (`fallback`) para asegurar la disponibilidad del dato y mantener la representación de la entidad.
# - **Lógica SQL (Ejemplo para `dim_product`):**
#
#     ```sql
#     -- Selección del nombre del producto en español o, si es NULL, en inglés, para su representación
#     SELECT
#         product_key,
#         COALESCE(spanish_product_name, english_product_name) AS producto_nombre,
#         COALESCE(spanish_product_category_name, english_product_category_name) AS producto_category,
#         COALESCE(spanish_product_subcategory_name, english_product_subcategory_name) AS producto_subcategoria
#     FROM
#         sales.dim_product;
#     ```
#
#     Es

# %% [markdown]
# Veamos ahora cuántos chunks genera nuestro splitter, y el aspecto de estos:

# %%
business_logic_chunks = md_splitter.split_documents(BUSINESS_RULES_PATH, encoding='utf-8')

print(f'{len(business_logic_chunks)=}')
print('-'*100)
print(business_logic_chunks)
# Out:
# len(business_logic_chunks)=24
# ----------------------------------------------------------------------------------------------------
# [Document(id='030ab2a7-edb6-4c81-997e-18b1960c5721', metadata={'2_subtitle': '1. Representación de Entidades y Preferencias Lingüísticas', 'file_name': 'business_rules.md', '3_section': 'N/A', 'headers_chunk_id': 0, 'headers_comb_total': 2, 'chunk_overlap': 300}, page_content='1. Representación de Entidades y Preferencias Lingüísticas\n\nCuando se solicita conceptualmente una entidad, como "productos", "clientes", "promociones" o "revendedores", se establece como principio operativo priorizar los campos que finalizan en `_name` para su adecuada representación en las salidas de las consultas SQL. Adicionalmente, se procurará mantener la coherencia con el idioma en que la consulta original fue formulada.\n\n- Principio Operativo: Para la visualización de entidades en los resultados de consultas, se debe seleccionar el campo `_name` que mejor represente la entidad. En el caso de campos bilingües donde la versión en español (`spanish_...name`, `spanish..._description`) pueda ser nula y la consulta se realice en español, se utilizará la versión en inglés como alternativa (`fallback`) para asegurar la disponibilidad del dato y mantener la representación de la entidad.\n- Lógica SQL (Ejemplo para `dim_product`):\n\n    ```sql\n    -- Selección del nombre del producto en español o, si es NULL, en inglés, para su representación\n    SELECT\n        product_key,\n        COALESCE(spanish_product_name, english_product_name) AS producto_nombre,\n        COALESCE(spanish_product_category_name, english_product_category_name) AS producto_category,\n        COALESCE(spanish_product_subcategory_name, english_product_subcategory_name) AS producto_subcategoria\n    FROM\n        sales.dim_product;'), Document(id='6dc3ee3c-8d6d-4fee-bb9b-c2f80e18330f', metadata={'2_subtitle': '1. Representación de Entidades y Preferencias Lingüísticas', 'file_name': 'business_rules.md', '3_section': 'N/A', 'headers_chunk_id': 1, 'headers_comb_total': 2, 'chunk_overlap': 300}, page_content='```\n\n    Este enfoque se aplicaría de manera similar a la representación de nombres de entidades en `dim_promotion`, `dim_customer`, `dim_reseller`, `dim_sales_person`, `dim_sales_reason`, `dim_sales_territory` y `dim_geography`, siempre privilegiando los campos `_name` relevantes y aplicando la lógica de `fallback` para el idioma.\n\nCuando se trata de campos como `product_line`, `class` y `style` de la tabla `dim_product`, los cuales pueden contener valores `NULL`, se establece como principio operativo completar los valores faltantes con una etiqueta que indique la ausencia de información, respetando el idioma de la consulta del usuario.\n\n- Principio Operativo: Para la visualización de atributos de productos que puedan ser nulos, se debe reemplazar el valor faltante por un placeholder que indique "no registrado", manteniendo la coherencia con el idioma de la consulta. Por ejemplo, se usará `\'|| No registrado ||\'` para consultas en español y `\'|| Not registered ||\'` para consultas en inglés.\n- Lógica SQL (Ejemplo para `dim_product`):\n\n    ```sql\n    -- Completar valores nulos en atributos de producto según el idioma de la consulta\n    SELECT\n        product_key,\n        COALESCE(product_line, \'|| No registrado ||\') AS producto_linea,\n        COALESCE(class, \'|| No registrado ||\') AS producto_clase,\n        COALESCE(style, \'|| No registrado ||\') AS producto_estilo\n    FROM\n        sales.dim_product;\n    ```'), Document(id='48c9f944-8a1e-463a-bd8d-40889d094fc2', metadata={'2_subtitle': '2. Cálculos Basados en Fechas', 'file_name': 'business_rules.md', '3_section': 'N/A', 'headers_chunk_id': 0, 'headers_comb_total': 1, 'chunk_overlap': 300}, page_content='2. Cálculos Basados en Fechas\n\nLas fechas en `fact_sales` permiten derivar métricas de tiempo cruciales para el análisis de la eficiencia de la cadena de suministro y la experiencia del cliente.'), Document(id='45d10bdc-1c48-47ae-8d24-d626e50695d1', metadata={'2_subtitle': '2. Cálculos Basados en Fech ...

# %% [markdown]
# ### LangChain: ChromaDB + Google GenAI Embeddings
#
# Ahora sí, procedemos a generar los embeddings de cada chunk y a almacenarlos en nuestra base de datos vectorial de `ChromaDB`. Esta vez, siguiendo la línea de las conclusiones obtenidas en el apartado anterior, utilizaremos un modelo de embeddings de Google Gemini a través de Gemini API, pero trabajando con VertexAI de fondo, lo que nos permite asegurar que los datos permanezcan en la region / location deseada.
#
# Dado que la clase implementada por LangChain para utilizar embeddings de Gemini API no soporta usar VertexAI por detrás, nuevamente, utilizaremos la clase `GenAIExtendedEmbeddingFunction` creada anteriormente.
#
# Generamos una instancia de la clase y verificamos que los parámetros son los esperados:

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(model= GENAI_EMBEDDING_MODEL)
print(f'VertexAI: {genai_embeddings.genai_client._api_client.vertexai}')
print(f'Project: {genai_embeddings.genai_client._api_client.project}')
print(f'Location: {genai_embeddings.genai_client._api_client.location}')
print(f'Auth Tokens: {genai_embeddings.genai_client.auth_tokens}')
# Out:
# VertexAI: True
# Project: gen-lang-client-0151767776
# Location: europe-west1
# Auth Tokens: <google.genai.tokens.Tokens object at 0x00000255BD5D6290>

# %% [markdown]
# El próximo paso es crear un cliente persistente de ChromaDB, e inicializar la colección correspondiente con la lógica de negocio. Al inicializar la colección, nuevamente, especificaremos que queremos usar como métrica de distancia la distancia de Coseno.

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)

business_logic_collection = ContextEnricherChromaCollection(
    persist_directory= CHROMA_DB_PATH,
    collection_name= BUSINESS_LOGIC_COLLECTION_NAME,
    create_collection_if_not_exists= True,
    embedding_function= genai_embeddings,
    collection_configuration= {'hnsw': {'space': 'cosine'}}
)

business_logic_collection.upsert_documents(documents= business_logic_chunks)
# Out:
# ({'ids': ['75a462d9-a1ac-43fb-ba1f-8c848077b6fd',
#    'fd623479-33b2-4908-9fd6-323968ae0268',
#    'b6b81056-8610-48a2-a3a0-0b17a105e5e3',
#    '6d8cadb4-11ca-49c4-a0fd-b458af90cab2',
#    '625d5069-97bc-4bc9-89af-cc62eea5778c',
#    'd0aafb3e-8f80-4d41-b3cb-5c850935e8c7',
#    '094ddbf6-caa0-4bdf-9782-6e6476a64074',
#    '6439c1dc-8dcd-4dd6-a4ee-3e72f2c4a071',
#    '3cc5c632-d34c-41d6-bb76-28c321c247a4',
#    'aa59d3e2-e477-4e48-b277-967c2c608d65',
#    '59e63199-43b2-4f3e-ad33-92f054131f6e',
#    '640a7784-ea71-4198-b117-baf8bc7b1941',
#    'c65290cd-0676-45ef-8fba-060baf8a54c2',
#    '79358930-da9e-42c8-a47d-aa2c96ac766f',
#    'f8cd7f72-7944-474f-8703-5f8848dedf42',
#    '84cd4872-e782-43ab-a11d-45eaa67cf125',
#    '25ac0626-f0bf-49ed-a5cf-6ae651e1a82d',
#    'e9f2d6f6-fbe7-40d6-a423-ed05d95a4863',
#    '81ec14cb-2a53-4777-b9b3-aae50d03dbc1',
#    '0b81ca82-a5cb-4e97-aebd-00a7f8c3a03d',
#    'fa28a269-f5d3-4b01-bf3a-7d5f248a154b',
#    '7248eb44-b763-484e-9fdb-74cb057d6877',
#    'bc9ad748-6077-49e7-856d-e7b449f41eb2',
#    'd444d1d7-45b3-4abe-9d8b-2c3a5d35847e'],
#   'documents': ['1. Representación de Entidades y Preferencias Lingüísticas\n\nCuando se solicita conceptualmente una entidad, como "productos", "clientes", "promociones" o "revendedores", se establece como principio operativo priorizar los campos que finalizan en `_name` para su adecuada representación en las salidas de las consultas SQL. Adicionalmente, se procurará mantener la coherencia con el idioma en que la consulta original fue formulada.\n\n- Principio Operativo: Para la visualización de entidades en los resultados de consultas, se debe seleccionar el campo `_name` que mejor represente la entidad. En el caso de campos bilingües donde la versión en español (`spanish_...name`, `spanish..._description`) pueda ser nula y la consulta se realice en español, se utilizará la versión en inglés como alternativa (`fallback`) para asegurar la disponibilidad del dato y mantener la representación de la entidad.\n- Lógica SQL (Ejemplo para `dim_product`):\n\n    ```sql\n    -- Selección del nombre del producto en español o, si es NULL, en inglés, para su representación\n    SELECT\n        product_key,\n        COALESCE(spanish_product_name, english_product_name) AS producto_nombre,\n        COALESCE(spanish_product_category_name, english_product_category_name) AS producto_category,\n        COALESCE(spanish_product_subcategory_name, english_product_subcategory_name) AS producto_subcategoria\n    FROM\n        sales.dim_product;',
#    '```\n\n    Este enfoque se aplicaría de manera similar a la representación de nombres de entidades en `dim_promotion`, `dim_customer`, `dim_reseller`, `dim_sales_person`, `dim_sales_reason`, `dim_sales_territory` y `dim_geography`, siempre privilegiando los campos `_name` relevantes y aplicando la lógica de `fallback` para el idioma.\n\nCuando se trata de campos como `product_line`, `class` y `style` de la tabla `dim_product`, los cuales pueden contener valores `NULL`, se establece como principio operativo completar los valores faltantes con una etiqueta que indique la ausencia de información, respetando el idioma de la consulta del usuario.\n\n- Principio Operativo: Para la visualización de atributos de productos que puedan ser nulos, se debe reemplazar el valor faltante por un placeholder que indique "no registrado", manteniendo la coherencia con el idioma de la consulta. Por ejemplo, se usará `\'|| No registrado ||\'` para consultas en español y `\'|| Not registered ||\'` para consultas en inglés.\n- Lógica SQL (Ejemplo para `dim_product`):\n\n    ```sql\n    -- Completar valores nulos en atributos de producto según el idioma de la consulta\n    SELECT\n        product_key,\n        COALESCE(product_line, \'|| No registrado ||\') AS producto_linea,\n        COALESCE(class, \'|| No registrado ||\') AS producto_clase,\n        COALESCE(style, \'|| No registrado ||\') AS producto_estilo\n    FROM\n        sales.dim_product;\n    ```',
#    '2. Cálculos Basados en Fechas\n\nLas fechas en `fact_sales` permiten derivar métricas de tiempo cruciales para el análisis de la eficiencia de la cadena de suministro y la experiencia del cliente.',
#    "2.1 Métricas de Tiempo de Entrega y Envío\n\n- Regla de Negocio: En caso de que se quiera hacer un análisis referido a los tiempos asociados a las ventas, se deben calcular los siguientes indicadores de tiempo:\n  - Tiempo de Envío (Shipping Time): Días transcurridos desde que se creó el pedido (`order_date`) hasta que se envió (`ship_date`).\n  - Tiempo de Entrega (Delivery Time): Días transcurridos desde que se envió el pedido (`ship_date`) hasta que se entregó al cliente (`due_date`).\n  - Tiempo Total de Procesamiento del Pedido (Order Processing Time): Días transcurridos desde que se creó el pedido (`order_date`) hasta su entrega final (`due_date`).\n- Lógica SQL (Ejemplo para `fact_sales`):\n\n    ```sql\n    SELECT\n        sales_order_number AS pedido_numero,\n        sales_order_line_number AS pedido_numero_linea,\n        order_date AS fecha_pedido,\n        ship_date AS fecha_envio,\n        due_date AS fecha_entrega,\n        -- Tiempo de Envío / Shipping Time (en días)\n        DATE_PART('day', ship_date::TIMESTAMP - order_date::TIMESTAMP) AS tiempo_envio,\n        -- Tiempo de Entrega / Delivery Time (en días)\n        DATE_PART('day', due_date::TIMESTAMP - ship_date::TIMESTAMP) AS tiempo_entrega,\n        -- Tiempo Total de Procesamiento del Pedido / Order Processing Time (en días)\n        DATE_PART('day', due_date::TIMESTAMP - order_date::TIMESTAMP) AS tiempo_total_procesamiento\n    FROM\n        sales.fact_sales;\n    ```\n\n    Nota: En Postgres, para que la resta de fechas `(fecha_final - fecha_inicial)` devuelve un tipo `INTERVAL`, se debe forzar a que cada fecha sea considerada como tipo `TIMESTAMP`, y `DATE_PART('day', interval)` extrae el número de días de ese intervalo.",
#    '2.2 Desglose por Períodos Temporales Comunes\n\nPara los informes de ventas, muchas veces es fundamental poder filtrar y agregar datos por períodos estándar asociados a términos como "Este Año", "Año Pasado", "Acumulado del Año (YTD)" y la comparación "Año Actual vs. Año Pasado".\n\n- Definiciones de Períodos Agregados:\n  - Trimestre: Período de tres meses. Un año natural se compone de cuatro trimestres (Q1: Ene-Mar, Q2: Abr-Jun, Q3: Jul-Sep, Q4: Oct-Dic).\n  - Semestre: Período de seis meses. Un año natural se compone de dos semestres (H1: Ene-Jun, H2: Jul-Dic).\n\n- Lógica SQL:',
#    "```sql\n    -- Ventas de 'Este Año' (basado en order_date)\n    SELECT *\n    FROM sales.fact_sales\n    WHERE EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE);\n\n    -- Ventas de 'El Año Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1;\n\n    -- Ventas 'YTD' (Year To Date) del año actual\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('year', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Ventas Mes en Curso\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('year', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Comparativa 'Año Actual vs. Año Pasado' (Same Period Last Year) con ejemplos de dimensiones\n    SELECT\n        customer_key,\n        reseller_key,\n        product_key,\n        SUM(\n            CASE\n            WHEN EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE) THEN sales_amount\n            ELSE 0\n            END\n        ) AS current_year,\n        SUM(\n            CASE\n            WHEN EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1 THEN sales_amount\n            ELSE 0\n            END\n        ) AS last_year\n    FROM sales.fact_sales\n    WHERE\n        EXTRACT(YEAR FROM order_date) BETWEEN EXTRACT(YEAR FROM CURRENT_DATE) -1 AND EXTRACT(YEAR FROM CURRENT_DATE)\n        -- Filtro adicional para periodo (ejemplo, 2do trimestre del año)\n        AND EXTRACT(QUARTER FROM order_date) = 1\n    GROUP BY\n        customer_key, reseller_key, product_key;\n\n    -- Ventas del 'Segundo trimestre del año pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '3 months'\n        AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'",
#    ";\n\n    -- Ventas del 'Trimestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Ventas del 'Trimestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';\n\n    -- Ventas del 'Primer semestre del año pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n        AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months';;\n\n    -- Ventas del 'Semestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN CURRENT_DATE\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );\n\n    -- Ventas del 'Semestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );",
#    "```\n\n    Nota: Para extraer partes de fechas, PostgreSQL soporta `EXTRACT(part FROM date_expression)` además de `DATE_PART`. `DATE_TRUNC('quarter', date)` es una función útil en PostgreSQL para truncar fechas al inicio del trimestre. `INTERVAL` se utiliza para operaciones de resta de tiempo.",
#    '3. Métricas Clásicas del Retail y su Interpretación\n\nEs crucial entender cómo se miden las diferentes métricas en el contexto de negocio.',
#    '- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".\n- Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.\n- Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.\n- En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.\n- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'internet_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.',
#    "- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `'internet_sales'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.\n- Ventas B2B (Business-to-Business): Estas ventas se refieren a transacciones entre empresas, como las realizadas con distribuidores o tiendas minoristas. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `'reseller_sales'`. Puede identificarse también como la unidad de negocio encargada del comercio mayorista.",
#    '3.1 Ventas Netas (`Net Sales`)\n\n- Definición: El total de dinero obtenido de las ventas después de haber restado todos los descuentos.\n- Principio Operativo: Este indicador se correlaciona directamente con el campo `sales_amount` de la tabla `fact_sales`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(sales_amount) AS importe_ventas\n    ```',
#    '3.2 Volumen de Unidades Comercializadas (`Quantity Sold`)\n\n- Definición: La cantidad total de productos que han sido vendidos.\n- Principio Operativo: Este indicador se corresponde con el campo `order_quantity` de la tabla `fact_sales`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(order_quantity) AS cantidad_vendida\n    ```',
#    '3.3 Precio Medio del Producto (`Average Product Price`)\n\n- Definición: El valor promedio al que se vendió cada unidad de producto, calculado dividiendo las ventas netas por el número de unidades vendidas.\n- Principio Operativo: Este indicador se calcula dividiendo el `sales_amount` por el `order_quantity` en la tabla `fact_sales`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(fs.sales_amount) / NULLIF(SUM(fs.order_quantity), 0) AS precio_medio\n    ```',
#    '3.4 Coste de la Mercancía Vendida (`COGS - Cost of Goods Sold`)\n\n- Definición: El coste total de los productos que la empresa ha vendido, ya sea por comprarlos o por fabricarlos.\n- Principio Operativo: Este indicador se corresponde con el campo `total_product_cost` de la tabla `fact_sales`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(total_product_cost) AS coste_mercancia\n    ```',
#    '3.5 Margen Bruto (`Gross Margin / Gross Profit`)\n\n- Definición: La ganancia directa que se obtiene de las ventas, calculada al restar el costo de los productos vendidos del total de las ventas netas.\n- Principio Operativo: El `Gross Margin` se calcula como `sales_amount - total_product_cost`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(sales_amount - total_product_cost) AS margen_bruto\n    ```',
#    '3.6 Porcentaje de Margen Bruto (`Gross Margin Percentage`)\n\n- Definición: El porcentaje de las ventas netas que representa el margen bruto, indicando qué parte de cada venta es ganancia directa.\n- Principio Operativo: El `Gross Margin Percentage` se computa como `(Gross Margin / sales_amount) * 100`.\n- Implementación Lógica SQL:\n\n    ```sql\n    (SUM(sales_amount - total_product_cost) / NULLIF(SUM(sales_amount), 0)) * 100 AS gross_margin_percentagemargen_bruto_pct\n    ```',
#    '3.7 Valor Promedio por Orden (`AOV - Average Order Value`) / `Valor Ticket Medio`\n\n- Definición: El importe promedio de cada pedido o "ticket" de compra. Mide cuánto gasta, en promedio, un cliente en cada transacción.\n- Principio Operativo: El cálculo de este valor se efectúa mediante la división del sumatorio total de `sales_amount` (cifra de negocio neta) entre el recuento distintivo de `sales_order_number` (órdenes de compra).\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(sales_amount) / COUNT(DISTINCT sales_order_number) AS valor_ticket_medio\n    ```',
#    '3.8 Tasa de Descuento Promedio (`Average Discount Rate`)\n\n- Definición: El porcentaje medio de rebaja aplicado a los precios en todas las transacciones de venta.\n- Principio Operativo: El cálculo se realiza mediante la división del sumatorio total de `discount_amount` entre el sumatorio total de `extended_amount` (el precio original previo a la aplicación del descuento).\n- Implementación Lógica SQL:\n\n    ```sql\n    (SUM(discount_amount) / NULLIF(SUM(extended_amount), 0)) * 100 AS tasa_descuento_promedio_pct\n    ```',
#    "3.9 Volumen de Ventas por Cliente / Distribuidor (`Sales per Customer / Reseller`)\n\n- Definición: El total de ventas (en dinero) que ha generado cada cliente (para ventas en línea - B2C) o cada distribuidor (para ventas a tiendas/distribuidores - B2B).\n- Principio Operativo: Se procederá a la agregación del `sales_amount` por `customer_key` (B2C) o por `reseller_key` (B2B).\n- Implementación Lógica SQL (Ejemplo para clientes en línea / mercado minorista - B2C):\n\n    ```sql\n    SELECT\n        fs.customer_key,\n        dc.customer_full_name AS cliente,\n        SUM(fs.sales_amount) AS importe_ventas_por_cliente\n    FROM sales.fact_sales fs\n    JOIN sales.dim_customer dc ON fs.customer_key = dc.customer_key\n    WHERE fs.sale_source = 'internet_sales'\n    GROUP BY fs.customer_key, dc.customer_full_name\n    ORDER BY importe_ventas_por_cliente DESC;\n    ```",
#    "3.10 Volumen de Ventas por Agente Comercial (`Sales per Sales Person`)\n\n- Definición: El total de ventas (en dinero) que ha generado cada vendedor.\n- Principio Operativo: Se agregará el `sales_amount` por `employee_key` de la tabla `dim_sales_person` específicamente para las `reseller_sales` (B2B).\n- Implementación Lógica SQL:\n\n    ```sql\n    SELECT\n        fs.employee_key,\n        dsp.employee_full_name AS empleado,\n        SUM(fs.sales_amount) AS importe_ventas_por_empleado\n    FROM sales.fact_sales fs\n    JOIN sales.dim_sales_person dsp ON fs.employee_key = dsp.employee_key\n    WHERE fs.sale_source = 'reseller_sales' -- La atribución a agentes comerciales se circunscribe a las ventas a distribuidores / mayoristas (B2B)\n    GROUP BY fs.employee_key, dsp.employee_full_name\n    ORDER BY importe_ventas_por_empleado DESC;\n    ```",
#    '4. Derivación de Indicadores y Segmentación\n\nLa creación de nuevas dimensiones o indicadores es factible a partir de las propiedades preexistentes de las entidades.',
#    "4.1 Segmentación de Clientes Conforme a Ingresos y Patrones Comportamentales\n\n- Principio Operativo: La clasificación de los clientes en categorías segmentadas, fundamentadas en su ingreso anual y en atributos como la condición de `house_owner` y el `number_children_at_home`, se impone para la ejecución de análisis en el ámbito de marketing y ventas.\n- Implementación Lógica SQL (Ejemplo para `dim_customer`):\n\n    ```sql\n    SELECT\n        customer_key,\n        customer_full_name AS cliente,\n        yearly_income AS ingreso_anual,\n        house_owner AS propietarios,\n        number_children_at_home AS hijos_en_casa,\n        CASE\n            WHEN yearly_income >= 100000 THEN 'Alto Valor'\n            WHEN yearly_income >= 50000 AND yearly_income < 100000 THEN 'Valor Medio'\n            ELSE 'Valor Básico'\n        END AS segmento_ingresos,\n        CASE\n            WHEN house_owner = TRUE AND number_children_at_home > 0 THEN 'Familia Propietaria'\n            WHEN house_owner = TRUE AND number_children_at_home = 0 THEN 'Propietario Sin Hijos'\n            WHEN house_owner = FALSE AND number_children_at_home > 0 THEN 'Familia Inquilina'\n            ELSE 'Inquilino Sin Hijos'\n        END AS segmento_estilo_vida\n    FROM\n        sales.dim_customer;\n    ```",
#    '4.2 Clasificación de Productos por Rango de Precios\n\n- Principio Operativo: La categorización de los productos en distintas gamas de precio (e.g., "Premium", "Estándar", "Económico") se llevará a cabo basándose en el atributo `list_price`.\n- Implementación Lógica SQL (Ejemplo para `dim_product`):\n\n    ```sql\n    SELECT\n        product_key,\n        COALESCE(spanish_product_name, english_product_name) AS product_name,\n        list_price,\n        CASE\n            WHEN list_price >= 1000 THEN \'Premium\'\n            WHEN list_price >= 200 AND list_price < 1000 THEN \'Estándar\'\n            ELSE \'Económico\'\n        END AS product_price_tier\n    FROM\n        sales.dim_product;\n    ```'],
#   'metadatas': [{'2_subtitle': '1. Representación de Entidades y Preferencias Lingüísticas',
#     'headers_comb_total': 2,
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300,
#     '3_section': 'N/A',
#     'file_name': 'business_rules.md'},
#    {'chunk_overlap': 300,
#     '2_subtitle': '1. Representación de Entidades y Preferencias Lingüísticas',
#     'headers_comb_total': 2,
#     'file_name': 'business_rules.md',
#     'headers_chunk_id': 1,
#     '3_section': 'N/A'},
#    {'headers_comb_total': 1,
#     'chunk_overlap': 300,
#     'headers_chunk_id': 0,
#     '2_subtitle': '2. Cálculos Basados en Fechas',
#     '3_section': 'N/A',
#     'file_name': 'business_rules.md'},
#    {'3_section': '2.1 Métricas de Tiempo de Entrega y Envío',
#     'headers_chunk_id': 0,
#     'headers_comb_total': 1,
#     'file_name': 'business_rules.md',
#     '2_subtitle': '2. Cálculos Basados en Fechas',
#     'chunk_overlap': 300},
#    {'file_name': 'business_rules.md',
#     '2_subtitle': '2. Cálculos Basados en Fechas',
#     'chunk_overlap': 300,
#     'headers_chunk_id': 0,
#     'headers_comb_total': 4,
#     '3_section': '2.2 Desglose por Períodos Temporales Comunes'},
#    {'file_name': 'business_rules.md',
#     '3_section': '2.2 Desglose por Períodos Temporales Comunes',
#     'headers_chunk_id': 1,
#     '2_subtitle': '2. Cálculos Basados en Fechas',
#     'headers_comb_total': 4,
#     'chunk_overlap': 300},
#    {'headers_chunk_id': 2,
#     'headers_comb_total': 4,
#     '3_section': '2.2 Desglose por Períodos Temporales Comunes',
#     'file_name': 'business_rules.md',
#     'chunk_overlap': 300,
#     '2_subtitle': '2. Cálculos Basados en Fechas'},
#    {'2_subtitle': '2. Cálculos Basados en Fechas',
#     'headers_chunk_id': 3,
#     'headers_comb_total': 4,
#     '3_section': '2.2 Desglose por Períodos Temporales Comunes',
#     'chunk_overlap': 300,
#     'file_name': 'business_rules.md'},
#    {'file_name': 'business_rules.md',
#     'chunk_overlap': 300,
#     'headers_comb_total': 3,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     '3_section': 'N/A',
#     'headers_chunk_id': 0},
#    {'file_name': 'business_rules.md',
#     '3_section': 'N/A',
#     'chunk_overlap': 300,
#     'headers_comb_total': 3,
#     'headers_chunk_id': 1,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'},
#    {'2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_chunk_id': 2,
#     'headers_comb_total': 3,
#     'chunk_overlap': 300,
#     'file_name': 'business_rules.md',
#     '3_section': 'N/A'},
#    {'headers_comb_total': 1,
#     'chunk_overlap': 300,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_chunk_id': 0,
#     'file_name': 'business_rules.md',
#     '3_section': '3.1 Ventas Netas (`Net Sales`)'},
#    {'headers_chunk_id': 0,
#     '3_section': '3.2 Volumen de Unidades Comercializadas (`Quantity Sold`)',
#     'chunk_overlap': 300,
#     'file_name': 'business_rules.md',
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_comb_total': 1},
#    {'file_name': 'business_rules.md',
#     'chunk_overlap': 300,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_chunk_id': 0,
#     '3_section': '3.3 Precio Medio del Producto (`Average Product Price`)',
#     'headers_comb_total': 1},
#    {'file_name': 'business_rules.md',
#     'headers_comb_total': 1,
#     '3_section': '3.4 Coste de la Mercancía Vendida (`COGS - Cost of Goods Sold`)',
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'},
#    {'chunk_overlap': 300,
#     'headers_comb_total': 1,
#     '3_section': '3.5 Margen Bruto (`Gross Margin / Gross Profit`)',
#     'file_name': 'business_rules.md',
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_chunk_id': 0},
#    {'2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_comb_total': 1,
#     '3_section': '3.6 Porcentaje de Margen Bruto (`Gross Margin Percentage`)',
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300,
#     'file_name': 'business_rules.md'},
#    {'headers_comb_total': 1,
#     '3_section': '3.7 Valor Promedio por Orden (`AOV - Average Order Value`) / `Valor Ticket Medio`',
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300,
#     'file_name': 'business_rules.md',
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'},
#    {'2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'file_name': 'business_rules.md',
#     '3_section': '3.8 Tasa de Descuento Promedio (`Average Discount Rate`)',
#     'headers_comb_total': 1,
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300},
#    {'headers_chunk_id': 0,
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     '3_section': '3.9 Volumen de Ventas por Cliente / Distribuidor (`Sales per Customer / Reseller`)',
#     'file_name': 'business_rules.md',
#     'chunk_overlap': 300,
#     'headers_comb_total': 1},
#    {'chunk_overlap': 300,
#     'file_name': 'business_rules.md',
#     '3_section': '3.10 Volumen de Ventas por Agente Comercial (`Sales per Sales Person`)',
#     '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación',
#     'headers_comb_total': 1,
#     'headers_chunk_id': 0},
#    {'3_section': 'N/A',
#     'headers_chunk_id': 0,
#     'chunk_overlap': 300,
#     'headers_comb_total': 1,
#     'file_name': 'business_rules.md',
#     '2_subtitle': '4. Derivación de Indicadores y Segmentación'},
#    {'3_section': '4.1 Segmentación de Clientes Conforme a Ingresos y Patrones Comportamentales',
#     'headers_comb_total': 1,
#     'file_name': 'business_rules.md',
#     '2_subtitle': '4. Derivación de Indicadores y Segmentación',
#     'chunk_overlap': 300,
#     'headers_chunk_id': 0},
#    {'3_section': '4.2 Clasificación de Productos por Rango de Precios',
#     'file_name': 'business_rules.md',
#     'chunk_overlap': 300,
#     '2_subtitle': '4. Derivación de Indicadores y Segmentación',
#     'headers_comb_total': 1,
#     'headers_chunk_id': 0}]},
#  ['030ab2a7-edb6-4c81-997e-18b1960c5721',
#   '6dc3ee3c-8d6d-4fee-bb9b-c2f80e18330f',
#   '48c9f944-8a1e-463a-bd8d-40889d094fc2',
#   '45d10bdc-1c48-47ae-8d24-d626e50695d1',
#   '3152d6fa-b9ea-407b-9264-e432a150c8a3',
#   'ab34b752-381f-4bd1-ba71-66606b4a85b2',
#   '8dc161ca-dbd3-46b5-9aee-cabe1eacbdd1',
#   'f4b114f5-c731-4907-ad31-93c564469536',
#   '87895a4c-8969-411d-a6f3-95eba965d9ef',
#   '0a9216f9-aca3-4242-80af-3c38f849da07',
#   'd16b308b-1482-4a74-852e-c515399be2be',
#   '7385b5e6-848e-47c2-9d97-dfa123c684a8',
#   'b8e33c19-44a8-41c2-b76e-d21f72b76788',
#   'b9647aba-e5e4-4195-84ed-1808bd449584',
#   '5d87060b-d3ad-4bff-be08-1942e2549aef',
#   'ede41676-953a-4bd2-a87d-6ca9e3554485',
#   'c2ab1479-3fd9-481c-8368-ed49143ff816',
#   'e55e5ed0-ab20-4ba2-86d1-346f7d770785',
#   '42e97a83-f9b7-4709-97da-1207302552ff',
#   '7a0aa807-3e04-4a53-9b02-b1b7c0ea90b0',
#   '27d923bb-4589-4029-9f2d-5f1f8f57bb97',
#   '5b6f7993-146d-48de-869e-dcd53accf555',
#   'b47ac807-1dc6-487d-b794-6ef08e217229',
#   '61d1f53a-9bfb-4c66-a60e-1aadb271841d'])

# %% [markdown]
# Ahora lanzaremos una consulta a la colección creada, para ver que los resultados obtenidos muestren cierto nivel de relevancia. Para esto, como ya hemos hecho en el apartado anterior, utilizaremoscomo métrica personalizada de `relevance_score` la función `cosine_distance_relevance_score_fn`.

# %%
QUERY = 'Los 10 artículos más comprados.'

# %%
business_logic_score_results = business_logic_collection.search(
    queries= QUERY,
    search_type= 'similarity_score_threshold',
    k= 5,
    score_threshold= 0.8
)

business_logic_score_results
# Out:
# [(Document(id='0a9216f9-aca3-4242-80af-3c38f849da07', metadata={'headers_chunk_id': 1, 'file_name': 'business_rules.md', 'headers_comb_total': 3, 'chunk_overlap': 300, '3_section': 'N/A', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'}, page_content='- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".\n- Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.\n- Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.\n- En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.\n- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'internet_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.'),
#   0.8428164124488831),
#  (Document(id='87895a4c-8969-411d-a6f3-95eba965d9ef', metadata={'headers_comb_total': 3, 'file_name': 'business_rules.md', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación', 'headers_chunk_id': 0, '3_section': 'N/A', 'chunk_overlap': 300}, page_content='3. Métricas Clásicas del Retail y su Interpretación\n\nEs crucial entender cómo se miden las diferentes métricas en el contexto de negocio.'),
#   0.8303163051605225),
#  (Document(id='8dc161ca-dbd3-46b5-9aee-cabe1eacbdd1', metadata={'file_name': 'business_rules.md', 'headers_chunk_id': 2, '2_subtitle': '2. Cálculos Basados en Fechas', '3_section': '2.2 Desglose por Períodos Temporales Comunes', 'chunk_overlap': 300, 'headers_comb_total': 4}, page_content=";\n\n    -- Ventas del 'Trimestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Ventas del 'Trimestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';\n\n    -- Ventas del 'Primer semestre del año pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n        AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months';;\n\n    -- Ventas del 'Semestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN CURRENT_DATE\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );\n\n    -- Ventas del 'Semestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );"),
#   0.8302729725837708),
#  (Document(id='7a0aa807-3e04-4a53-9b02-b1b7c0ea90b0', metadata={'headers_chunk_id': 0, 'headers_comb_total': 1, 'chunk_overlap': 300, '3_section': '3.9 Volumen de Ventas por Cliente / Distribuidor (`Sales per Customer / Reseller`)', 'file_name': 'business_rules.md', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'}, page_content="3.9 Volumen de Ventas por Cliente / Distribuidor (`Sales per Customer / Reseller`)\n\n- Definición: El total de ventas (en dinero) que ha generado cada cliente (para ventas en línea - B2C) o cada distribuidor (para ventas a tiendas/distribuidores - B2B).\n- Principio Operativo: Se procederá a la agregación del `sales_amount` por `customer_key` (B2C) o por `reseller_key` (B2B).\n- Implementación Lógica SQL (Ejemplo para clientes en línea / mercado minorista - B2C):\n\n    ```sql\n    SELECT\n        fs.customer_key,\n        dc.customer_full_name AS cliente,\n        SUM(fs.sales_amount) AS importe_ventas_por_cliente\n    FROM sales.fact_sales fs\n    JOIN sales.dim_customer dc ON fs.customer_key = dc.customer_key\n    WHERE fs.sale_source = 'internet_sales'\n    GROUP BY fs.customer_key, dc.customer_full_name\n    ORDER BY importe_ventas_por_cliente DESC;\n    ```"),
#   0.8246618509292603),
#  (Document(id='b8e33c19-44a8-41c2-b76e-d21f72b76788', metadata={'3_section': '3.2 Volumen de Unidades Comercializadas (`Quantity Sold`)', 'headers_chunk_id': 0, '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación', 'file_name': 'business_rules.md', 'chunk_overlap': 300, 'headers_comb_total': 1}, page_content='3.2 Volumen de Unidades Comercializadas (`Quantity Sold`)\n\n- Definición: La cantidad total de productos que han sido vendidos.\n- Principio Operativo: Este indicador se corresponde con el campo `order_quantity` de la tabla `fact_sales`.\n- Implementación Lógica SQL:\n\n    ```sql\n    SUM(order_quantity) AS cantidad_vendida\n    ```'),
#   0.8246617317199707)]

# %%
business_logic_score_results[1][0]
# Out:
# Document(id='87895a4c-8969-411d-a6f3-95eba965d9ef', metadata={'headers_comb_total': 3, 'file_name': 'business_rules.md', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación', 'headers_chunk_id': 0, '3_section': 'N/A', 'chunk_overlap': 300}, page_content='3. Métricas Clásicas del Retail y su Interpretación\n\nEs crucial entender cómo se miden las diferentes métricas en el contexto de negocio.')

# %%
business_logic_score_results[0][0]
# Out:
# Document(id='0a9216f9-aca3-4242-80af-3c38f849da07', metadata={'headers_chunk_id': 1, 'file_name': 'business_rules.md', 'headers_comb_total': 3, 'chunk_overlap': 300, '3_section': 'N/A', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'}, page_content='- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".\n- Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.\n- Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.\n- En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.\n- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'internet_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.')

# %% [markdown]
# #### Maximal Marginal Relevance (MMR)
#
# Como podemos ver, los resultados obtenidos muestran valores altos de relevancia, por lo que a priori parece funcionar correctamente. Dado que para este caso, a diferencia del anterior, estamos trabajando con chunks que presentan overlapping, corremos el riesgo de que nuestros resultados sean redundantes, como se muestra en las 2 celdas anteriores. Ante esta situación, parece una buena idea utilizar `max_marginal_relevance_search`.
#
# Esta búsqueda aplica la técnica de [***Maximal Marginal Relevance (MMR)***](https://aclanthology.org/X98-1025/), mediante la que se intenta reducir la redundancia en los resultados mientras, al mismo tiempo, se mantiene la relevancia de los mismos. Es decir, un documento presentará una alta Relevancia Marginal si es a la vez relevante para la query y presenta una similitud reducida con los documentos previamente seleccionados.

# %%
business_logic_mmr_results = business_logic_collection.search(
    queries= QUERY,
    search_type= 'mmr',
    k= 5,
    fetch_k= 25,
    lambda_mult= 0.5
)

business_logic_mmr_results
# Out:
# [Document(id='0a9216f9-aca3-4242-80af-3c38f849da07', metadata={'headers_comb_total': 3, 'chunk_overlap': 300, 'file_name': 'business_rules.md', 'headers_chunk_id': 1, '3_section': 'N/A', '2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación'}, page_content='- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".\n- Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.\n- Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.\n- En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.\n- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'internet_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.'),
#  Document(id='87895a4c-8969-411d-a6f3-95eba965d9ef', metadata={'2_subtitle': '3. Métricas Clásicas del Retail y su Interpretación', 'file_name': 'business_rules.md', 'chunk_overlap': 300, 'headers_comb_total': 3, 'headers_chunk_id': 0, '3_section': 'N/A'}, page_content='3. Métricas Clásicas del Retail y su Interpretación\n\nEs crucial entender cómo se miden las diferentes métricas en el contexto de negocio.'),
#  Document(id='8dc161ca-dbd3-46b5-9aee-cabe1eacbdd1', metadata={'2_subtitle': '2. Cálculos Basados en Fechas', '3_section': '2.2 Desglose por Períodos Temporales Comunes', 'chunk_overlap': 300, 'headers_comb_total': 4, 'headers_chunk_id': 2, 'file_name': 'business_rules.md'}, page_content=";\n\n    -- Ventas del 'Trimestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Ventas del 'Trimestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';\n\n    -- Ventas del 'Primer semestre del año pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n        AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months';;\n\n    -- Ventas del 'Semestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN CURRENT_DATE\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );\n\n    -- Ventas del 'Semestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );"),
#  Document(id='f4b114f5-c731-4907-ad31-93c564469536', metadata={'3_section': '2.2 Desglose por Períodos Temporales Comunes', 'headers_chunk_id': 3, 'file_name': 'business_rules.md', 'chunk_overlap': 300, 'headers_comb_total': 4, '2_subtitle': '2. Cálculos Basados en Fechas'}, page_content="```\n\n    Nota: Para extraer partes de fechas, PostgreSQL soporta `EXTRACT(part FROM date_expression)` además de `DATE_PART`. `DATE_TRUNC('quarter', date)` es una función útil en PostgreSQL para truncar fechas al inicio del trimestre. `INTERVAL` se utiliza para operaciones de resta de tiempo."),
#  Document(id='5b6f7993-146d-48de-869e-dcd53accf555', metadata={'chunk_overlap': 300, 'file_name': 'business_rules.md', '2_subtitle': '4. Derivación de Indicadores y Segmentación', '3_section': 'N/A', 'headers_chunk_id': 0, 'headers_comb_total': 1}, page_content='4. Derivación de Indicadores y Segmentación\n\nLa creación de nuevas dimensiones o indicadores es factible a partir de las propiedades preexistentes de las entidades.')]

# %% [markdown]
# #### Context Enrichment Window
#
# Como podemos observar en el resultado anterior, Parece ser que los 5 chunks que hemos obtenido, a diferencia de lo que ocurría antes, ninguno pertenece a la misma jerarquía (mismo `2_subtitle` y `3_section`), por lo que parece estar funcionando mejor. Utilizaremos entonces esta técnica, y la combinaremos con una técnica de [**RAG de contexto eriquecido**](https://github.com/NirDiamant/RAG_Techniques/blob/main/all_rag_techniques/context_enrichment_window_around_chunk.ipynb), lo que nos permitirá ampliar el contexto que circunda a los chunks obtenidos.
#
# Para lograr esto, hemos implementado una clase personalizada que contine toda la lógica necesaria para generar un contexto enriquecido. Está definida en la sección `Clases personalizadas`, bajo el nombre `DocumentContextEnricher`.

# %%
business_logic_enriched_context_results = business_logic_collection.enriched_context_search(
    queries= QUERY,
    merge_results= True,
    context_window_size= 3,
    search_type= 'mmr',
    k= 10,
    fetch_k= 25,
    lambda_mult= 0.5
)

print(business_logic_enriched_context_results[0])
# Out:
# 3. Métricas Clásicas del Retail y su Interpretación
#
# Es crucial entender cómo se miden las diferentes métricas en el contexto de negocio.- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".
# - Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.
# - Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.
# - En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.
# - Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `'internet_sales'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.
# - Ventas B2B (Business-to-Business): Estas ventas se refieren a transacciones entre empresas, como las realizadas con distribuidores o tiendas minoristas. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `'reseller_sales'`. Puede identificarse también como la unidad de negocio encargada del comercio mayorista.

# %%
print(business_logic_enriched_context_results)
# Out:
# ['3. Métricas Clásicas del Retail y su Interpretación\n\nEs crucial entender cómo se miden las diferentes métricas en el contexto de negocio.- Cuando se habla de productos "más vendidos", sin especificar más, generalmente nos referimos a la cantidad de unidades (`order_quantity`) vendidas. También puede ser relevante medir esto por el importe facturado (`sales_amount`) para identificar productos que, aunque se vendan en menor volumen, generan más ingresos. Pero, en este último caso se especificarán términos como "de mayor facturación".\n- Cuando se refiere a clientes, tiendas/distribuidores o vendedores que "más compran/venden", esto se mide por el importe facturado (`sales_amount`) o `net sales`. Adicionalmente, se puede considerar la frecuencia de compra (para clientes y distribuidores) o el número de pedidos gestionados (para vendedores) como métricas complementarias.\n- Para el análisis de rentabilidad, la métrica clave es el margen bruto (`gross margin`) o el porcentaje de margen bruto (`gross margin percentage`), lo cual permite comprender la contribución real de cada venta o producto a las ganancias, más allá del volumen o ingreso total. Este enfoque es vital para evaluar la eficiencia operativa.\n- En el contexto de la gestión de promociones, el éxito no solo se mide por el discount_amount o average_discount_rate, sino también por el incremento en `order_quantity` o `sales_amount` directamente atribuible a la promoción. Es fundamental analizar la rentabilidad general del período promocional para determinar su efectividad.\n- Ventas B2C (Business-to-Consumer): Estas ventas se refieren a transacciones directas con el consumidor final. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'internet_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio minorista.\n- Ventas B2B (Business-to-Business): Estas ventas se refieren a transacciones entre empresas, como las realizadas con distribuidores o tiendas minoristas. En el modelo, corresponden a los pedidos donde `sale_source` es igual a `\'reseller_sales\'`. Puede identificarse también como la unidad de negocio encargada del comercio mayorista.', ";\n\n    -- Ventas del 'Trimestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE) AND CURRENT_DATE;\n\n    -- Ventas del 'Trimestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';\n\n    -- Ventas del 'Primer semestre del año pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n        AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months';;\n\n    -- Ventas del 'Semestre en Curso'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN CURRENT_DATE\n                ELSE DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n            END\n        );\n\n    -- Ventas del 'Semestre Pasado'\n    SELECT *\n    FROM sales.fact_sales\n    WHERE\n        order_date >= (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) > 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n            END\n        )\n        AND order_date < (\n            CASE\n                WHEN EXTRACT(MONTH FROM CURRENT_DATE) <= 6 THEN DATE_TRUNC('year', CURRENT_DATE)\n                ELSE DATE_TRUNC('year', CURRENT_DATE) +  ...

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0.25)

SYSTEM_PROMPT = """
You are a context summarizer that receives retrieval documents.
Your role is to:

1. Analyze the given retrieval documents, which contain business logic information.
2. Identify and extract only the business logic rules and definitions relevant to the user's question. This includes metrics, calculations, entity definitions, and specific operational principles.
3. Summarize these business logics into a clear, concise, and easy-to-understand text.
4. Exclude any irrelevant details like table or column names, keys, or direct SQL query examples.
5. Ensure factual accuracy; do not fabricate information.
6. The summary should be in plain text, exclusively focused on explaining the business rules. Do not mention any technical or database-related details.
7. Match the language of the summary to the user's query.

Input:
- Retrieval documents: {retrieval_documents}

Output:
- A concise summary of the business logic relevant to the user's query. The summary should be focused on explaining the business rules and definitions in a non-technical manner.
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': business_logic_enriched_context_results
})

Markdown(contexto_resumido)
# Out:
# Para identificar los 10 artículos más comprados, se considera la cantidad de unidades vendidas como la métrica principal. Esta métrica se refiere al total de unidades de cada producto que han sido adquiridas por los clientes. También es relevante medir el importe facturado, que indica los productos que, aunque tengan un menor volumen de ventas, generan mayores ingresos. En este caso, se utilizaría el término "de mayor facturación" para referirse a estos productos.
#
# Por lo tanto, la clasificación de los artículos más comprados se puede realizar en función de la cantidad de unidades vendidas y, si se desea, complementarla con el análisis del importe total de ventas para obtener una visión más completa del rendimiento de cada producto.

# %% [markdown]
# ---
#
# ## Fichero JSON con Ejemplos de Consultas
#
# El objetivo de esta sección es procesar un fichero JSON que contien ejemplos variados, en los que se indica la pregunta del usuario, bien en español o bien en inglés, y una query que respondería a la consulta del usuario.
#
# Para esto, nos valdremos de las clases personalizadas que hemos creado. Utilizaremos `JsonExamplesSplitter` para cargar los datos del fichero y generar los chunks con su correspondiente metadata, y `ExtendedChromaCollection` para gestionar la colección correspondiente de Chroma DB donde almacenaremos y consultaremos estos chunks.
#
# ### Chunking
#
# En este caso, a diferencia de los anteriores, los "documentos" de los que debemos generar los embeddings son las consultas del usuario, mientras que en la metadata almacenaremos la query que responde a dicha consulta, como también el idioma original de la consulta, por si deseamos filtrar.

# %%
examples_splitter = JsonExamplesSplitter(page_content_key= 'user_query')

examples_chunks = examples_splitter.split_documents(EXAMPLES_PATH, encoding= 'utf-8')

print(f'{len(examples_chunks)=}')
print('-'*100)
print(examples_chunks)
# Out:
# len(examples_chunks)=21
# ----------------------------------------------------------------------------------------------------
# [Document(id='c59325ef-a9d5-470b-8a59-5138b0715e02', metadata={'file_name': 'query_examples.json', 'sql_query': "SELECT\n  COALESCE(spanish_product_name, english_product_name) AS producto,\n  list_price AS precio_de_lista,\n  standard_cost AS coste_estandar,\n  spanish_product_category_name AS categoria,\n  spanish_product_subcategory_name AS subcategoria,\n  CASE\n    WHEN list_price >= 1000 THEN 'Premium'\n    WHEN list_price >= 200 AND list_price < 1000 THEN 'Estándar'\n    ELSE 'Económico'\n  END AS escala_precios\nFROM\n  sales.dim_product\nORDER BY\n  product_category,\n  product_subcategory;", 'language': 'ES'}, page_content='Necesito saber para cada producto su nombre, su precio de lista, su coste, su categoría y subcategoría, y escala de precios al que pertenece, ordenado por categoría y subcategoría.'), Document(id='6fa826c3-5a9b-4165-b45b-2654602e878b', metadata={'file_name': 'query_examples.json', 'sql_query': "SELECT\n  COALESCE(dp.spanish_product_category_name, dp.english_product_category_name) AS categoria_producto,\n  SUM(fs.sales_amount) AS total_ventas_netas,\n  SUM(fs.sales_amount - fs.total_product_cost) AS margen_bruto,\n  (SUM(fs.sales_amount - fs.total_product_cost) / NULLIF(SUM(fs.sales_amount), 0)) * 100 AS margen_bruto_procentaje\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE)\n  AND fs.sale_source = 'internet_sales'\nGROUP BY\n  categoria_producto\nORDER BY\n  total_ventas_netas DESC;", 'language': 'ES'}, page_content='Dame el importe de ventas de cada categoría de producto para la unidad de negocio B2C del año actual. Añade el margen bruto y el porcentaje de margen bruto de cada categoría.'), Document(id='0da4f16c-8faa-4f89-90de-c247fdd3b0ba', metadata={'file_name': 'query_examples.json', 'sql_query': "SELECT\n  EXTRACT(MONTH FROM order_date) AS mes,\n  SUM(sales_amount) / COUNT(DISTINCT sales_order_number) AS ticket_medio\nFROM\n  sales.fact_sales\nWHERE\n  sale_source = 'reseller_sales'\n  AND order_date BETWEEN DATE_TRUNC('year', CURRENT_DATE) AND CURRENT_DATE\nGROUP BY\n  EXTRACT(MONTH FROM order_date);", 'language': 'ES'}, page_content='Muéstrame el valor de ticket medio mensual para las ventas a distribuidores en lo que va del año.'), Document(id='4124a5cf-ed6e-4778-84fc-2a8ab8560251', metadata={'file_name': 'query_examples.json', 'sql_query': "SELECT\n  (SUM(discount_amount) / NULLIF(SUM(extended_amount), 0)) * 100 AS descuento_medio_pct\nFROM\n  sales.fact_sales\nWHERE\n  sale_source = 'reseller_sales'\n  AND (\n    (\n      EXTRACT(MONTH FROM CURRENT_DATE) > 6\n      AND EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE)\n      AND EXTRACT(MONTH FROM order_date) BETWEEN 1 AND 6\n    )\n    OR\n    (\n      EXTRACT(MONTH FROM CURRENT_DATE) <= 6\n      AND EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1\n      AND EXTRACT(MONTH FROM order_date) BETWEEN 7 AND 12\n    )\n  );", 'language': 'ES'}, page_content='Quiero saber el descuento medio aplicado en las ventas mayoristas del semestre pasado, expresado en porcentaje.'), Document(id='3ae201f6-28e3-4344-b113-91cbaf511e90', metadata={'file_name': 'query_examples.json', 'sql_query': 'SELECT\n  COALESCE(dp.spanish_product_name, dp.english_product_name) AS producto,\n  dp.spanish_product_category_name AS categoria,\n  dp.spanish_product_subcategory_name AS subcategoria,\n  SUM(fs.sales_amount) AS importe,\n  SUM(fs.order_quantity) AS cantidad,\n  SUM(fs.sales_amount) / NULLIF(SUM(fs.order_quantity), 0) AS precio_medio\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1\nGROUP BY\n  producto, categoria, subcategoria\nORDER BY\n  cantidad DESC\nLIMIT 10;', 'language': 'ES'}, page_content='Enumera los 10 productos más vendidos en el último año. Muestra el nombre del producto, su ...

# %% [markdown]
# Veamos un ejemplo en español y uno en inglés:

# %%
first_spanish_chunk = next((chunk for chunk in examples_chunks if chunk.metadata.get('language') == 'ES'), None)

title = 'id:'
print(title)
print('-' * (len(title)+1))
print(first_spanish_chunk.id, end= '\n'*2)

title = 'page_content:'
print(title)
print('-' * (len(title)+1))
print(first_spanish_chunk.page_content, end= '\n'*2)

title = 'query:'
print(title)
print('-' * (len(title)+1))
print(first_spanish_chunk.metadata.get('sql_query'))
# Out:
# id:
# ----
# c59325ef-a9d5-470b-8a59-5138b0715e02
#
# page_content:
# --------------
# Necesito saber para cada producto su nombre, su precio de lista, su coste, su categoría y subcategoría, y escala de precios al que pertenece, ordenado por categoría y subcategoría.
#
# query:
# -------
# SELECT
#   COALESCE(spanish_product_name, english_product_name) AS producto,
#   list_price AS precio_de_lista,
#   standard_cost AS coste_estandar,
#   spanish_product_category_name AS categoria,
#   spanish_product_subcategory_name AS subcategoria,
#   CASE
#     WHEN list_price >= 1000 THEN 'Premium'
#     WHEN list_price >= 200 AND list_price < 1000 THEN 'Estándar'
#     ELSE 'Económico'
#   END AS escala_precios
# FROM
#   sales.dim_product
# ORDER BY
#   product_category,
#   product_subcategory;

# %%
first_english_chunk = next((chunk for chunk in examples_chunks if chunk.metadata.get('language') == 'EN'), None)

title = 'id:'
print(title)
print('-' * (len(title)+1))
print(first_english_chunk.id, end= '\n'*2)

title = 'page_content:'
print(title)
print('-' * (len(title)+1))
print(first_english_chunk.page_content, end= '\n'*2)

title = 'query:'
print(title)
print('-' * (len(title)+1))
print(first_english_chunk.metadata.get('sql_query'))
# Out:
# id:
# ----
# 088c7621-c200-4d74-861a-2abab9d67db4
#
# page_content:
# --------------
# Show me the average shipping time, delivery time, and total order processing time in days for the last quarter.
#
# query:
# -------
# SELECT
#   AVG(DATE_PART('day', ship_date::TIMESTAMP - order_date::TIMESTAMP)) AS avg_shipping_time_days,
#   AVG(DATE_PART('day', due_date::TIMESTAMP - ship_date::TIMESTAMP)) AS avg_delivery_time_days,
#   AVG(DATE_PART('day', due_date::TIMESTAMP - order_date::TIMESTAMP)) AS avg_total_order_processing_time_days
# FROM
#   sales.fact_sales
# WHERE
#   order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';

# %% [markdown]
# ### LangChain: ChromaDB + Google GenAI Embeddings
#
# Ahora sí, procedemos a generar los embeddings de cada chunk y a almacenarlos en nuestra base de datos vectorial de `ChromaDB`. Siguiendo la línea de apartados anteriores, utilizaremos nuevamente el modelo de embeddings de Google Gemini a través de Gemini API, siempre trabajando con VertexAI de fondo, lo que nos permite asegurar que los datos permanezcan en la region / location deseada.
#
# Dado que la clase implementada por LangChain para utilizar embeddings de Gemini API no soporta usar VertexAI por detrás, nuevamente, utilizaremos la clase `GenAIExtendedEmbeddingFunction` creada anteriormente.
#
# Generamos una instancia de la clase y verificamos que los parámetros son los esperados:

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(model= GENAI_EMBEDDING_MODEL)
print(f'VertexAI: {genai_embeddings.genai_client._api_client.vertexai}')
print(f'Project: {genai_embeddings.genai_client._api_client.project}')
print(f'Location: {genai_embeddings.genai_client._api_client.location}')
print(f'Auth Tokens: {genai_embeddings.genai_client.auth_tokens}')
# Out:
# VertexAI: True
# Project: gen-lang-client-0151767776
# Location: europe-west1
# Auth Tokens: <google.genai.tokens.Tokens object at 0x00000255BE5DB090>

# %% [markdown]
# El próximo paso es crear un cliente persistente de ChromaDB, e inicializar la colección correspondiente con ejemplos de queries. Al inicializar la colección, nuevamente, especificaremos que queremos usar como métrica de distancia la distancia de Coseno.

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)

examples_collection = ExamplesChromaCollection(
    persist_directory= CHROMA_DB_PATH,
    collection_name= EXAMPLES_COLLECTION_NAME,
    create_collection_if_not_exists= True,
    embedding_function= genai_embeddings,
    collection_configuration= {'hnsw': {'space': 'cosine'}}
)

examples_collection.upsert_documents(documents= examples_chunks)
# Out:
# ({'ids': ['d8fce838-4457-4b9b-8984-21ab3d74e756',
#    '67ff5cbf-f93a-4436-8434-f24525ce30d8',
#    '28e85081-2738-440d-aa64-424227971e4b',
#    '991cac17-1d9e-402e-be10-9ab834dcd88f',
#    'c3154e54-b358-4ff5-acad-ddf2839b5ec7',
#    '45cc7247-46dd-44c2-8baa-aab5bda6bd88',
#    '8be6862c-2c70-4d58-b7fd-8120c456f121',
#    '136adf47-62dd-4a68-95cb-5f9a0fb53570',
#    'e374f5e9-48d7-4e07-bbf4-5509749ccd55',
#    '00e54ab4-fb49-4f1b-8c20-9662a100fadf',
#    'd9deafaa-5842-4212-964a-00b624b66467',
#    '618499d8-a97c-47b3-b5db-882d6223f07d',
#    'ad617cff-6972-4b6d-997d-911a02886422',
#    'ab0a6c3f-3e0e-4102-a16a-c651763b42dc',
#    '1dbac876-218f-4db5-91e4-c15404151868',
#    'a1f97722-b208-488a-b8fe-045c95681efc',
#    '65ae6760-2ebd-4fb6-a760-a8f137f9acb2',
#    '47a63d33-b4db-48ae-a0a6-d03aaddce256',
#    '3b383017-7a31-4aed-b275-72e401fa07b5',
#    'c3e941b7-c326-4d89-905e-42ee1b4041f4',
#    'aa3d2d97-2339-4294-b5d8-eeb9076643c4'],
#   'documents': ['Necesito saber para cada producto su nombre, su precio de lista, su coste, su categoría y subcategoría, y escala de precios al que pertenece, ordenado por categoría y subcategoría.',
#    'Dame el importe de ventas de cada categoría de producto para la unidad de negocio B2C del año actual. Añade el margen bruto y el porcentaje de margen bruto de cada categoría.',
#    'Muéstrame el valor de ticket medio mensual para las ventas a distribuidores en lo que va del año.',
#    'Quiero saber el descuento medio aplicado en las ventas mayoristas del semestre pasado, expresado en porcentaje.',
#    'Enumera los 10 productos más vendidos en el último año. Muestra el nombre del producto, su categoría y subcategoría, el importe de las ventas, la cantidad vendida, y el precio medio por unidad.',
#    'Muestra un listado de los últimos 20 clientes que han comprado y su segmento de ingresos y de estilo de vida.',
#    'Calcula el importe comprado por cada uno de los clientes con altos ingresos en lo que va del mes.',
#    'Para cada categoría de producto, compara las ventas del primer semestre de este año con las del año anterior. Muestrame un detalle mes a mes, indicando los valores, y la diferencia porcentual.',
#    'Hazme un ranking de los 3 motivos de venta más comunes para las ventas minoristas.',
#    'Para cada promoción, calcula la cantidad de unidades vendidas y el importe de descuento sobre las ventas del segundo trimestre de este año. Muestra la promoción, su tipo y categoría. ',
#    'Muéstrame los 10 productos más vendidos para el B2B en el último trimestre, excluyendo los Accesorios. Mes a mes indica cuántas unidades se vendieron, y muestra también a qué categoría y subcategoría pertenecen.',
#    'Show me the average shipping time, delivery time, and total order processing time in days for the last quarter.',
#    'Calculate the total quantity sold for road and mountain product lines.',
#    'Show the sales amount for each reseller during the first half of this year, along with their business type and compare it with the same period of the last year. Include only resellers whose sales this year were lower than the last year.',
#    "Calculate the gross margin and gross margin percentage for sales in the 'North America' sales territory group this quarter in course.",
#    'List the top 5 sales persons by total sales amount for B2B sales for the last half, detailed month by month.',
#    'List all products that have a list price between 500 and 700. Show their name, category, subcategory and list price.',
#    'Calculate the sales amount, quantity sold, and cost of goods for the current year-to-date period, and same period last year comparission.',
#    'Calculate the total quantity sold for each product line and product price tier for the second quarter of last year.',
#    'Shows a list of the last 20 customers who made a purchase, along with their income and lifestyle segments.',
#    'Show me the top 10 best-selling products for the B2C segment over the last 6 months, excluding Accessories. Break down the sales amount month by month, and also include the category and subcategory each product belongs to.'],
#   'metadatas': [{'sql_query': "SELECT\n  COALESCE(spanish_product_name, english_product_name) AS producto,\n  list_price AS precio_de_lista,\n  standard_cost AS coste_estandar,\n  spanish_product_category_name AS categoria,\n  spanish_product_subcategory_name AS subcategoria,\n  CASE\n    WHEN list_price >= 1000 THEN 'Premium'\n    WHEN list_price >= 200 AND list_price < 1000 THEN 'Estándar'\n    ELSE 'Económico'\n  END AS escala_precios\nFROM\n  sales.dim_product\nORDER BY\n  product_category,\n  product_subcategory;",
#     'file_name': 'query_examples.json',
#     'language': 'ES'},
#    {'file_name': 'query_examples.json',
#     'sql_query': "SELECT\n  COALESCE(dp.spanish_product_category_name, dp.english_product_category_name) AS categoria_producto,\n  SUM(fs.sales_amount) AS total_ventas_netas,\n  SUM(fs.sales_amount - fs.total_product_cost) AS margen_bruto,\n  (SUM(fs.sales_amount - fs.total_product_cost) / NULLIF(SUM(fs.sales_amount), 0)) * 100 AS margen_bruto_procentaje\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE)\n  AND fs.sale_source = 'internet_sales'\nGROUP BY\n  categoria_producto\nORDER BY\n  total_ventas_netas DESC;",
#     'language': 'ES'},
#    {'language': 'ES',
#     'file_name': 'query_examples.json',
#     'sql_query': "SELECT\n  EXTRACT(MONTH FROM order_date) AS mes,\n  SUM(sales_amount) / COUNT(DISTINCT sales_order_number) AS ticket_medio\nFROM\n  sales.fact_sales\nWHERE\n  sale_source = 'reseller_sales'\n  AND order_date BETWEEN DATE_TRUNC('year', CURRENT_DATE) AND CURRENT_DATE\nGROUP BY\n  EXTRACT(MONTH FROM order_date);"},
#    {'language': 'ES',
#     'sql_query': "SELECT\n  (SUM(discount_amount) / NULLIF(SUM(extended_amount), 0)) * 100 AS descuento_medio_pct\nFROM\n  sales.fact_sales\nWHERE\n  sale_source = 'reseller_sales'\n  AND (\n    (\n      EXTRACT(MONTH FROM CURRENT_DATE) > 6\n      AND EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE)\n      AND EXTRACT(MONTH FROM order_date) BETWEEN 1 AND 6\n    )\n    OR\n    (\n      EXTRACT(MONTH FROM CURRENT_DATE) <= 6\n      AND EXTRACT(YEAR FROM order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1\n      AND EXTRACT(MONTH FROM order_date) BETWEEN 7 AND 12\n    )\n  );",
#     'file_name': 'query_examples.json'},
#    {'sql_query': 'SELECT\n  COALESCE(dp.spanish_product_name, dp.english_product_name) AS producto,\n  dp.spanish_product_category_name AS categoria,\n  dp.spanish_product_subcategory_name AS subcategoria,\n  SUM(fs.sales_amount) AS importe,\n  SUM(fs.order_quantity) AS cantidad,\n  SUM(fs.sales_amount) / NULLIF(SUM(fs.order_quantity), 0) AS precio_medio\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1\nGROUP BY\n  producto, categoria, subcategoria\nORDER BY\n  cantidad DESC\nLIMIT 10;',
#     'language': 'ES',
#     'file_name': 'query_examples.json'},
#    {'language': 'ES',
#     'sql_query': "WITH\n  customer_last_order AS (\n    SELECT\n      customer_key,\n      MAX(sales_order_number) AS bigger_sales_order_number,\n      MAX(order_date) AS last_order_date\n    FROM\n      sales.fact_sales\n    WHERE\n      order_date <= CURRENT_DATE\n    GROUP BY\n      customer_key\n  )\n\nSELECT\n  dc.customer_full_name AS cliente,\n  dc.yearly_income AS ingresos_anuales,\n  dc.house_owner AS propiertarios,\n  dc.number_children_at_home AS hijos_viviendo_en_casa,\n  CASE\n    WHEN dc.yearly_income >= 100000 THEN 'Alto Valor'\n    WHEN dc.yearly_income >= 50000 AND dc.yearly_income < 100000 THEN 'Valor Medio'\n    ELSE 'Valor Básico'\n  END AS segmento_ingresos,\n  CASE\n    WHEN dc.house_owner = TRUE AND dc.number_children_at_home > 0 THEN 'Familia Propietaria'\n    WHEN dc.house_owner = TRUE AND dc.number_children_at_home = 0 THEN 'Propietario Sin Hijos'\n    WHEN dc.house_owner = FALSE AND dc.number_children_at_home > 0 THEN 'Familia Inquilina'\n    ELSE 'Inquilino Sin Hijos'\n  END AS segmento_estilo_vida\nFROM\n  sales.dim_customer dc\n  JOIN customer_last_order clo ON dc.customer_key = clo.customer_key\nORDER BY\n  clo.last_order_date, clo.bigger_sales_order_number DESC\nLIMIT 20;",
#     'file_name': 'query_examples.json'},
#    {'file_name': 'query_examples.json',
#     'sql_query': "SELECT\n  dc.customer_full_name AS cliente,\n  SUM(fs.sales_amount) AS importe\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_customer dc ON fs.customer_key = dc.customer_key\nWHERE\n  fs.sale_source = 'internet_sales'\n  AND dc.yearly_income >= 100000\n  AND order_date BETWEEN DATE_TRUNC('month', CURRENT_DATE) AND CURRENT_DATE\nGROUP BY\n  cliente\nORDER BY\n  importe DESC;",
#     'language': 'ES'},
#    {'sql_query': "WITH \n  sales_current AS (\n    SELECT\n      dp.spanish_product_category_name AS category_name,\n      date_trunc('month', fs.order_date) AS month,\n      SUM(fs.sales_amount) AS total_sales\n    FROM\n      sales.fact_sales fs\n      JOIN sales.dim_product dp ON fs.product_key = dp.product_key\n    WHERE \n      fs.order_date >= date_trunc('year', CURRENT_DATE)\n      AND fs.order_date < date_trunc('year', CURRENT_DATE) + interval '6 months'\n    GROUP BY\n      category_name, month\n  ),\n  sales_last AS (\n    SELECT\n      dp.spanish_product_category_name AS category_name,\n      date_trunc('month', fs.order_date) AS month,\n      SUM(fs.sales_amount) AS total_sales\n    FROM\n      sales.fact_sales fs\n      JOIN sales.dim_product dp ON fs.product_key = dp.product_key\n    WHERE\n      fs.order_date >= date_trunc('year', CURRENT_DATE - interval '1 year')\n      AND fs.order_date < date_trunc('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n    GROUP BY\n      category_name, month\n  )\n\nSELECT\n  COALESCE(sc.category_name, sl.category_name) AS categoria,\n  TO_CHAR(CURRENT_DATE, 'YYYY-') || TO_CHAR(COALESCE(sc.month, sl.month), 'MM') AS año_mes,\n  COALESCE(sc.total_sales, 0) AS año_en_curso_S1,\n  COALESCE(sl.total_sales, 0) AS año_pasado_H1,\n  ROUND(100 * (COALESCE(sc.total_sales, 0) - sl.total_sales) / NULLIF(sl.total_sales, 0), 2) AS dif_pct\nFROM\n  sales_current sc\n  FULL OUTER JOIN sales_last sl ON \n    sc.category_name = sl.category_name\n    AND EXTRACT(MONTH FROM sc.month) = EXTRACT(MONTH FROM sl.month)\nORDER BY\n  categoria, año_mes;",
#     'language': 'ES',
#     'file_name': 'query_examples.json'},
#    {'sql_query': "SELECT\n  RANK() OVER (ORDER BY COUNT(fisr.sales_reason_key) DESC) AS rank,\n  dsr.sales_reason_name,\n  COUNT(fisr.sales_reason_key) AS reason_count\nFROM\n  sales.fact_internet_sales_reason fisr\n  JOIN sales.dim_sales_reason dsr ON fisr.sales_reason_key = dsr.sales_reason_key\n  JOIN sales.fact_sales fs ON fisr.sales_order_number = fs.sales_order_number AND fisr.sales_order_line_number = fs.sales_order_line_number\nWHERE\n  fs.sale_source = 'internet_sales'\nGROUP BY\n  dsr.sales_reason_name\nORDER BY\n  reason_count DESC\nLIMIT 3;",
#     'language': 'ES',
#     'file_name': 'query_examples.json'},
#    {'language': 'ES',
#     'sql_query': "SELECT\n  dp.spanish_promotion_name AS promocion_nombre,\n  dp.spanish_promotion_type AS promocion_tipo,\n  dp.spanish_promotion_category AS promocion_categoria,\n  SUM(fs.order_quantity) AS cantidad_vendida,\n  SUM(fs.discount_amount) AS descuento_realizado\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_promotion dp ON fs.promotion_key = dp.promotion_key\nWHERE\n  COALESCE(dp.discount_pct, 0) > 0\n  AND order_date >= DATE_TRUNC('year', CURRENT_DATE) + interval '3 months'\n  AND order_date < DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\nGROUP BY\n  dp.spanish_promotion_name, dp.spanish_promotion_type, dp.spanish_promotion_category\nORDER BY\n  descuento_realizado DESC;",
#     'file_name': 'query_examples.json'},
#    {'language': 'ES',
#     'sql_query': "WITH \n  last_quarter AS (\n    SELECT\n      fs.product_key,\n      COALESCE(dp.spanish_product_name, dp.english_product_name) AS product_name,\n      dp.spanish_product_category_name,\n      dp.spanish_product_subcategory_name,\n      EXTRACT(MONTH FROM fs.order_date) AS month_in_quarter,\n      fs.order_quantity\n    FROM\n      sales.fact_sales fs\n      JOIN sales.dim_product dp ON fs.product_key = dp.product_key\n    WHERE\n      fs.sale_source = 'reseller_sales'\n      AND dp.spanish_product_category_name <> 'Accesorio'\n      AND fs.order_date >= date_trunc('quarter', CURRENT_DATE - interval '3 months')\n      AND fs.order_date < date_trunc('quarter', CURRENT_DATE)\n  ),\n  top_products AS (\n    SELECT\n      product_key,\n      product_name,\n      spanish_product_category_name,\n      spanish_product_subcategory_name,\n      SUM(order_quantity) AS total_qty\n    FROM\n      last_quarter\n    GROUP BY\n      product_key, product_name, spanish_product_category_name, spanish_product_subcategory_name\n    ORDER BY\n      total_qty DESC\n    LIMIT 10\n  )\n\nSELECT\n  tp.product_name AS producto,\n  tp.spanish_product_category_name AS categoria,\n  tp.spanish_product_subcategory_name AS subcategoria,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months'))) AS primer_mes,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '1 month')) AS segundo_mes,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '2 month')) AS tercer_mes,\n  SUM(lq.order_quantity) AS total\nFROM\n  top_products tp\n  LEFT JOIN last_quarter lq ON tp.product_key = lq.product_key\nGROUP BY\n  producto, categoria, subcategoria\nORDER BY\n  total DESC;",
#     'file_name': 'query_examples.json'},
#    {'language': 'EN',
#     'file_name': 'query_examples.json',
#     'sql_query': "SELECT\n  AVG(DATE_PART('day', ship_date::TIMESTAMP - order_date::TIMESTAMP)) AS avg_shipping_time_days,\n  AVG(DATE_PART('day', due_date::TIMESTAMP - ship_date::TIMESTAMP)) AS avg_delivery_time_days,\n  AVG(DATE_PART('day', due_date::TIMESTAMP - order_date::TIMESTAMP)) AS avg_total_order_processing_time_days\nFROM\n  sales.fact_sales\nWHERE\n  order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE - INTERVAL '3 months') AND DATE_TRUNC('quarter', CURRENT_DATE) - INTERVAL '1 day';"},
#    {'file_name': 'query_examples.json',
#     'language': 'EN',
#     'sql_query': "SELECT\n  dp.product_line,\n  SUM(fs.order_quantity) AS total_quantity_sold\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  dp.product_line IN ('R', 'M')\nGROUP BY\n  dp.product_line\nORDER BY\n  total_quantity_sold DESC;"},
#    {'language': 'EN',
#     'sql_query': "SELECT\n  dr.reseller_name,\n  dr.business_type,\n  SUM(\n    CASE \n      WHEN fs.order_date >= DATE_TRUNC('year', CURRENT_DATE)\n          AND fs.order_date < DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n      THEN fs.sales_amount\n      ELSE 0\n    END\n  ) AS total_sales_current_year_H1,\n  SUM(\n    CASE\n      WHEN fs.order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n          AND fs.order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n      THEN fs.sales_amount\n      ELSE 0\n    END\n  ) AS total_sales_last_year_H1\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_reseller dr ON fs.reseller_key = dr.reseller_key\nWHERE\n  fs.sale_source = 'reseller_sales'\n  AND order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n  AND fs.order_date < DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\nGROUP BY\n  dr.reseller_name, dr.business_type\nHAVING\n  SUM(\n    CASE \n      WHEN fs.order_date >= DATE_TRUNC('year', CURRENT_DATE)\n          AND fs.order_date < DATE_TRUNC('year', CURRENT_DATE) + interval '6 months'\n      THEN fs.sales_amount\n      ELSE 0\n    END\n  ) \n  < SUM(\n    CASE\n      WHEN fs.order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year')\n          AND fs.order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n      THEN fs.sales_amount\n      ELSE 0\n    END\n  )\nORDER BY\n  total_sales_current_year_H1 DESC;",
#     'file_name': 'query_examples.json'},
#    {'language': 'EN',
#     'file_name': 'query_examples.json',
#     'sql_query': "SELECT\n  SUM(fs.sales_amount - fs.total_product_cost) AS gross_margin,\n  (SUM(fs.sales_amount - fs.total_product_cost) / NULLIF(SUM(fs.sales_amount), 0)) * 100 AS gross_margin_percentage\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_sales_territory dst ON fs.sales_territory_key = dst.sales_territory_key\nWHERE\n  dst.sales_territory_group = 'North America'\n  AND order_date BETWEEN DATE_TRUNC('quarter', CURRENT_DATE) AND CURRENT_DATE;"},
#    {'file_name': 'query_examples.json',
#     'language': 'EN',
#     'sql_query': "WITH\n  sales_last_half AS (\n    SELECT\n      dsp.employee_full_name AS employee,\n      TO_CHAR(fs.order_date, 'YYYY-MM') AS year_month,\n      SUM(fs.sales_amount) AS total_sales\n    FROM sales.fact_sales fs\n    JOIN sales.dim_sales_person dsp ON fs.employee_key = dsp.employee_key\n    WHERE fs.sale_source = 'reseller_sales'\n      AND (\n        (EXTRACT(MONTH FROM CURRENT_DATE) <= 6\n          AND fs.order_date >= date_trunc('year', CURRENT_DATE - interval '1 year') + interval '6 months'\n          AND fs.order_date < date_trunc('year', CURRENT_DATE)\n        )\n        OR\n        (EXTRACT(MONTH FROM CURRENT_DATE) > 6\n          AND fs.order_date >= date_trunc('year', CURRENT_DATE)\n          AND fs.order_date < date_trunc('year', CURRENT_DATE) + interval '6 months'\n        )\n      )\n    GROUP BY dsp.employee_full_name, year_month\n  ),\n  total_per_employee AS (\n    SELECT\n      employee,\n      SUM(total_sales) AS total_sales_semester\n    FROM sales_last_half\n    GROUP BY employee\n    ORDER BY total_sales_semester DESC\n    LIMIT 5\n  )\n\nSELECT\n  slh.employee,\n  slh.year_month,\n  slh.total_sales\nFROM\n  sales_last_half slh\n  JOIN total_per_employee tpe ON slh.employee = tpe.employee\nORDER BY\n  employee, year_month ASC;"},
#    {'language': 'EN',
#     'sql_query': 'SELECT\n  english_product_name AS product_name,\n  english_product_category_name AS category,\n  english_product_subcategory_name AS subcategory,\n  list_price\nFROM\n  sales.dim_product\nWHERE\n  list_price BETWEEN 500 AND 700;',
#     'file_name': 'query_examples.json'},
#    {'language': 'EN',
#     'sql_query': "SELECT\n  'Net Sales' AS metric,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE) AND order_date <= CURRENT_DATE\n      THEN sales_amount\n      ELSE 0\n    END\n  ) AS current_year_ytd,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE - interval '1 year') AND order_date <= (CURRENT_DATE - interval '1 year')\n      THEN sales_amount\n      ELSE 0\n    END\n  ) AS last_year_ytd\nFROM sales.fact_sales\n\nUNION ALL\n\nSELECT\n  'Quantity Sold' AS metric,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE) AND order_date <= CURRENT_DATE\n      THEN order_quantity\n      ELSE 0\n    END\n  ) AS current_year_ytd,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE - interval '1 year') AND order_date <= (CURRENT_DATE - interval '1 year')\n      THEN order_quantity\n      ELSE 0\n    END\n  ) AS last_year_ytd\nFROM sales.fact_sales\n\nUNION ALL\n\nSELECT\n  'COGS' AS metric,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE) AND order_date <= CURRENT_DATE\n      THEN total_product_cost\n      ELSE 0\n    END\n  ) AS current_year_ytd,\n  SUM(\n    CASE\n      WHEN order_date >= date_trunc('year', CURRENT_DATE - interval '1 year') AND order_date <= (CURRENT_DATE - interval '1 year')\n      THEN total_product_cost\n      ELSE 0\n    END\n  ) AS last_year_ytd\nFROM sales.fact_sales;",
#     'file_name': 'query_examples.json'},
#    {'sql_query': "SELECT\n  COALESCE(dp.product_line, '|| Not registered ||') AS product_line,\n  CASE\n    WHEN list_price >= 1000 THEN 'Premium'\n    WHEN list_price >= 200 AND list_price < 1000 THEN 'Standard'\n    ELSE 'Economic'\n  END AS product_price_tier,\n  SUM(fs.order_quantity) AS total_quantity_sold\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  order_date >= DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '3 months'\n  AND order_date < DATE_TRUNC('year', CURRENT_DATE - interval '1 year') + interval '6 months'\nGROUP BY\n  product_line, product_price_tier\nORDER BY\n  product_line, total_quantity_sold DESC;",
#     'file_name': 'query_examples.json',
#     'language': 'EN'},
#    {'language': 'EN',
#     'sql_query': "WITH\n  customer_last_order AS (\n    SELECT\n      customer_key,\n      MAX(sales_order_number) AS bigger_sales_order_number,\n      MAX(order_date) AS last_order_date\n    FROM\n      sales.fact_sales\n    WHERE\n      order_date <= CURRENT_DATE\n    GROUP BY\n      customer_key\n  )\n\nSELECT\n  dc.customer_full_name AS customer,\n  dc.yearly_income,\n  dc.house_owner,\n  dc.number_children_at_home,\n  CASE\n    WHEN dc.yearly_income >= 100000 THEN 'High Value'\n    WHEN dc.yearly_income >= 50000 AND dc.yearly_income < 100000 THEN 'Medium Value'\n    ELSE 'Basic Value'\n  END AS customer_income_segment,\n  CASE\n    WHEN dc.house_owner = TRUE AND dc.number_children_at_home > 0 THEN 'Owner Family'\n    WHEN dc.house_owner = TRUE AND dc.number_children_at_home = 0 THEN 'Owner No Childs'\n    WHEN dc.house_owner = FALSE AND dc.number_children_at_home > 0 THEN 'Tenant Family'\n    ELSE 'Tenant No Childs'\n  END AS customer_lifestyle_segment\nFROM\n  sales.dim_customer dc\n  JOIN customer_last_order clo ON dc.customer_key = clo.customer_key\nORDER BY\n  clo.last_order_date, clo.bigger_sales_order_number DESC\nLIMIT 20;",
#     'file_name': 'query_examples.json'},
#    {'file_name': 'query_examples.json',
#     'language': 'EN',
#     'sql_query': "WITH \n  last_6_months AS (\n    SELECT\n      fs.product_key,\n      dp.english_product_name AS product_name,\n      dp.english_product_category_name AS category,\n      dp.english_product_subcategory_name AS subcategory,\n      EXTRACT(MONTH FROM fs.order_date) AS month_in_period,\n      fs.sales_amount\n    FROM\n      sales.fact_sales fs\n      JOIN sales.dim_product dp ON fs.product_key = dp.product_key\n    WHERE\n      fs.sale_source = 'internet_sales'\n      AND dp.english_product_category_name <> 'Accessories'\n      AND fs.order_date >= date_trunc('month', CURRENT_DATE) - interval '6 months'\n      AND fs.order_date < date_trunc('month', CURRENT_DATE)\n  ),\n  top_products AS (\n    SELECT\n      product_key,\n      product_name,\n      category,\n      subcategory,\n      SUM(sales_amount) AS total_sales\n    FROM\n      last_6_months\n    GROUP BY\n      product_key, product_name, category, subcategory\n    ORDER BY\n      total_sales DESC\n    LIMIT 10\n  )\n\nSELECT\n  tp.product_name AS product,\n  tp.category,\n  tp.subcategory,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '6 months')\n  ) AS first_month,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '5 months')\n  ) AS second_month,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '4 months')\n  ) AS third_month,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '3 months')\n  ) AS fourth_month,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '2 month')\n  ) AS fifth_month,\n  SUM(lq.sales_amount) FILTER (\n      WHERE lq.month_in_period = EXTRACT(MONTH FROM date_trunc('month', CURRENT_DATE) - interval '1 month')\n  ) AS sixth_month,\n  SUM(lq.sales_amount) AS total_sales\nFROM\n  top_products tp\n  LEFT JOIN last_6_months lq ON tp.product_key = lq.product_key\nGROUP BY\n  tp.product_name, tp.category, tp.subcategory\nORDER BY\n  total_sales DESC;"}]},
#  ['c59325ef-a9d5-470b-8a59-5138b0715e02',
#   '6fa826c3-5a9b-4165-b45b-2654602e878b',
#   '0da4f16c-8faa-4f89-90de-c247fdd3b0ba',
#   '4124a5cf-ed6e-4778-84fc-2a8ab8560251',
#   '3ae201f6-28e3-4344-b113-91cbaf511e90',
#   '76af0b9e-9e60-48eb-95f6-774cb823cdbd',
#   '88146f86-a3c8-4220-91cc-344e9e7291ce',
#   'a70b7cf9-4d50-47a1-b52c-b91cb857541b',
#   'd2bab528-e788-4047-be1c-2ca9ae67e856',
#   '85c923dc-1bfa-4ae9-8975-8332271f8fbd',
#   '1f1af88b-0381-451d-8247-2e8982f416e3',
#   '088c7621-c200-4d74-861a-2abab9d67db4',
#   '9003f6af-dc3d-435a-838e-784521c34665',
#   '54a02966-522c-40c0-9048-2bec50876945',
#   '294aedb7-79f0-47a3-b892-01856a4b8782',
#   'd5d1884e-4ac0-4287-b9bc-16885df29d66',
#   '8f8d9c7c-b581-4d9a-85ab-99d221b8a095',
#   'bde44adc-dd49-49f4-9e5d-19f0af531941',
#   'c817050f-dff4-43bb-bc7f-093c10c223f1',
#   '05ab0c30-80f9-4c44-be2c-390e771063b9',
#   '74136f54-8e2a-4402-b304-cb9696f1e050'])

# %% [markdown]
# Dado que actualmente tenemos una cantidad reducida de ejemplos en nuestra base de datos, parece adecuado utilizar una búsqueda por score de relevancia.
#
# En caso de que luego se habilite la carga de una cantidad mayor de ejemplos, podríamos correr el riesgo de que tengamos muchas consultas similares. En ese caso, parecería una buena idea utilizar `max_marginal_relevance_search`.
#
# Como ya comentamos anteriormente, esta búsqueda aplica la técnica de [***Maximal Marginal Relevance (MMR)***](https://aclanthology.org/X98-1025/), mediante la que se intenta reducir la redundancia en los resultados mientras, al mismo tiempo, se mantiene la relevancia de los mismos. Es decir, un documento presentará una alta Relevancia Marginal si es a la vez relevante para la query y presenta una similitud reducida con los documentos previamente seleccionados.

# %%
QUERY = 'Los 10 artículos más comprados.'

examples_results = examples_collection.search(
    queries= QUERY,
    search_type= 'similarity_score_threshold',
    k = 2
)

examples_results
# Out:
# [(Document(id='3ae201f6-28e3-4344-b113-91cbaf511e90', metadata={'sql_query': 'SELECT\n  COALESCE(dp.spanish_product_name, dp.english_product_name) AS producto,\n  dp.spanish_product_category_name AS categoria,\n  dp.spanish_product_subcategory_name AS subcategoria,\n  SUM(fs.sales_amount) AS importe,\n  SUM(fs.order_quantity) AS cantidad,\n  SUM(fs.sales_amount) / NULLIF(SUM(fs.order_quantity), 0) AS precio_medio\nFROM\n  sales.fact_sales fs\n  JOIN sales.dim_product dp ON fs.product_key = dp.product_key\nWHERE\n  EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1\nGROUP BY\n  producto, categoria, subcategoria\nORDER BY\n  cantidad DESC\nLIMIT 10;', 'language': 'ES', 'file_name': 'query_examples.json'}, page_content='Enumera los 10 productos más vendidos en el último año. Muestra el nombre del producto, su categoría y subcategoría, el importe de las ventas, la cantidad vendida, y el precio medio por unidad.'),
#   0.8890863955020905),
#  (Document(id='1f1af88b-0381-451d-8247-2e8982f416e3', metadata={'language': 'ES', 'sql_query': "WITH \n  last_quarter AS (\n    SELECT\n      fs.product_key,\n      COALESCE(dp.spanish_product_name, dp.english_product_name) AS product_name,\n      dp.spanish_product_category_name,\n      dp.spanish_product_subcategory_name,\n      EXTRACT(MONTH FROM fs.order_date) AS month_in_quarter,\n      fs.order_quantity\n    FROM\n      sales.fact_sales fs\n      JOIN sales.dim_product dp ON fs.product_key = dp.product_key\n    WHERE\n      fs.sale_source = 'reseller_sales'\n      AND dp.spanish_product_category_name <> 'Accesorio'\n      AND fs.order_date >= date_trunc('quarter', CURRENT_DATE - interval '3 months')\n      AND fs.order_date < date_trunc('quarter', CURRENT_DATE)\n  ),\n  top_products AS (\n    SELECT\n      product_key,\n      product_name,\n      spanish_product_category_name,\n      spanish_product_subcategory_name,\n      SUM(order_quantity) AS total_qty\n    FROM\n      last_quarter\n    GROUP BY\n      product_key, product_name, spanish_product_category_name, spanish_product_subcategory_name\n    ORDER BY\n      total_qty DESC\n    LIMIT 10\n  )\n\nSELECT\n  tp.product_name AS producto,\n  tp.spanish_product_category_name AS categoria,\n  tp.spanish_product_subcategory_name AS subcategoria,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months'))) AS primer_mes,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '1 month')) AS segundo_mes,\n  SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '2 month')) AS tercer_mes,\n  SUM(lq.order_quantity) AS total\nFROM\n  top_products tp\n  LEFT JOIN last_quarter lq ON tp.product_key = lq.product_key\nGROUP BY\n  producto, categoria, subcategoria\nORDER BY\n  total DESC;", 'file_name': 'query_examples.json'}, page_content='Muéstrame los 10 productos más vendidos para el B2B en el último trimestre, excluyendo los Accesorios. Mes a mes indica cuántas unidades se vendieron, y muestra también a qué categoría y subcategoría pertenecen.'),
#   0.8772459626197815)]

# %%
first_result = examples_results[0][0]
score = examples_results[0][1]

title = 'id:'
print(title)
print('-' * (len(title)+1))
print(first_result.id, end= '\n'*2)

title = 'score:'
print(title)
print('-' * (len(title)+1))
print(score, end= '\n'*2)

title = 'page_content:'
print(title)
print('-' * (len(title)+1))
print(first_result.page_content, end= '\n'*2)

title = 'query:'
print(title)
print('-' * (len(title)+1))
print(first_result.metadata.get('sql_query'))
# Out:
# id:
# ----
# 3ae201f6-28e3-4344-b113-91cbaf511e90
#
# score:
# -------
# 0.8890863955020905
#
# page_content:
# --------------
# Enumera los 10 productos más vendidos en el último año. Muestra el nombre del producto, su categoría y subcategoría, el importe de las ventas, la cantidad vendida, y el precio medio por unidad.
#
# query:
# -------
# SELECT
#   COALESCE(dp.spanish_product_name, dp.english_product_name) AS producto,
#   dp.spanish_product_category_name AS categoria,
#   dp.spanish_product_subcategory_name AS subcategoria,
#   SUM(fs.sales_amount) AS importe,
#   SUM(fs.order_quantity) AS cantidad,
#   SUM(fs.sales_amount) / NULLIF(SUM(fs.order_quantity), 0) AS precio_medio
# FROM
#   sales.fact_sales fs
#   JOIN sales.dim_product dp ON fs.product_key = dp.product_key
# WHERE
#   EXTRACT(YEAR FROM fs.order_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1
# GROUP BY
#   producto, categoria, subcategoria
# ORDER BY
#   cantidad DESC
# LIMIT 10;

# %%
second_result = examples_results[1][0]
score = examples_results[1][1]

title = 'id:'
print(title)
print('-' * (len(title)+1))
print(second_result.id, end= '\n'*2)

title = 'score:'
print(title)
print('-' * (len(title)+1))
print(score, end= '\n'*2)

title = 'page_content:'
print(title)
print('-' * (len(title)+1))
print(second_result.page_content, end= '\n'*2)

title = 'query:'
print(title)
print('-' * (len(title)+1))
print(second_result.metadata.get('sql_query'))
# Out:
# id:
# ----
# 1f1af88b-0381-451d-8247-2e8982f416e3
#
# score:
# -------
# 0.8772459626197815
#
# page_content:
# --------------
# Muéstrame los 10 productos más vendidos para el B2B en el último trimestre, excluyendo los Accesorios. Mes a mes indica cuántas unidades se vendieron, y muestra también a qué categoría y subcategoría pertenecen.
#
# query:
# -------
# WITH
#   last_quarter AS (
#     SELECT
#       fs.product_key,
#       COALESCE(dp.spanish_product_name, dp.english_product_name) AS product_name,
#       dp.spanish_product_category_name,
#       dp.spanish_product_subcategory_name,
#       EXTRACT(MONTH FROM fs.order_date) AS month_in_quarter,
#       fs.order_quantity
#     FROM
#       sales.fact_sales fs
#       JOIN sales.dim_product dp ON fs.product_key = dp.product_key
#     WHERE
#       fs.sale_source = 'reseller_sales'
#       AND dp.spanish_product_category_name <> 'Accesorio'
#       AND fs.order_date >= date_trunc('quarter', CURRENT_DATE - interval '3 months')
#       AND fs.order_date < date_trunc('quarter', CURRENT_DATE)
#   ),
#   top_products AS (
#     SELECT
#       product_key,
#       product_name,
#       spanish_product_category_name,
#       spanish_product_subcategory_name,
#       SUM(order_quantity) AS total_qty
#     FROM
#       last_quarter
#     GROUP BY
#       product_key, product_name, spanish_product_category_name, spanish_product_subcategory_name
#     ORDER BY
#       total_qty DESC
#     LIMIT 10
#   )
#
# SELECT
#   tp.product_name AS producto,
#   tp.spanish_product_category_name AS categoria,
#   tp.spanish_product_subcategory_name AS subcategoria,
#   SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months'))) AS primer_mes,
#   SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '1 month')) AS segundo_mes,
#   SUM(lq.order_quantity) FILTER (WHERE lq.month_in_quarter = EXTRACT(MONTH FROM date_trunc('quarter', CURRENT_DATE - interval '3 months') + interval '2 month')) AS tercer_mes,
#   SUM(lq.order_quantity) AS total
# FROM
#   top_products tp
#   LEFT JOIN last_quarter lq ON tp.product_key = lq.product_key
# GROUP BY
#   producto, categoria, subcategoria
# ORDER BY
#   total DESC;

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0.25)

SYSTEM_PROMPT = """
You are a query generator that recibes an user input.
Use the following examples to create a valid Postgres SQL query that responds the user query.

User input:
<user_query>
{user_query}
</user_query

Examples:
<examples>
{retrieval_documents}
</examples>

Output:
- Only the Postgres SQL Query in plain text. DON'T USE FORMAT IN THE OUTPUT.
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': json.dumps(
        ExamplesChromaCollection.format_for_llm(examples_results),
        indent=2,
        ensure_ascii=False
    )
})

print(contexto_resumido.replace('\\n', '\n'))
# Out:
# SELECT
#   COALESCE(dp.spanish_product_name, dp.english_product_name) AS producto,
#   SUM(fs.order_quantity) AS cantidad
# FROM
#   sales.fact_sales fs
#   JOIN sales.dim_product dp ON fs.product_key = dp.product_key
# GROUP BY
#   producto
# ORDER BY
#   cantidad DESC
# LIMIT 10;
