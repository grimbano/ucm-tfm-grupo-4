# %% [markdown]
# # Creación y Almacenamiento de Embeddings en Chroma DB
#
# En el presente Notebook se crearán la documentación base del esquema reducido con el que trabajaremos, basada en el `information_schema` correspondiente, que luego se nutrirá por fuera con mayor información relevante para negocio.
#
# Adicionalmente, por fuera del Notebook, se confeccionará documentación adicional, como reglas de negocio y few-shot examples para, finalmente, obtener chunks de todos estos documentos y crear y almacenar los mismos, con su metadata asociada, en una base de datos vectorial de Chroma DB.

# %% [markdown]
# ## Inicialización

# %% [markdown]
# ### Librerías

# %%
import os
import sys
from pathlib import Path
from dotenv import load_dotenv
import yaml
import json
from IPython.display import Markdown

from enum import Enum
from collections import defaultdict, OrderedDict
import pandas as pd

import uuid
import chromadb
from google import genai

from langchain.embeddings.base import Embeddings as LangchainEmbeddings
from langchain_chroma import Chroma

from langchain.schema import StrOutputParser
from langchain.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI

load_dotenv('../.env')
pd.set_option('display.max_columns', None)
yaml.add_representer(OrderedDict, lambda dumper, data: dumper.represent_dict(data.items()))

notebook_dir = os.getcwd() 
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(project_root)

from src.pg_sql import execute_query

# %% [markdown]
# ### Constantes

# %%
DATABASE = 'database'
SCHEMAS = 'schemas'
TABLES = 'tables'
COLUMNS = 'columns'
DESCRIPTION = 'description'
NAME = 'name'
DATA_TYPE = 'data_type'
PRIMARY_KEY = 'is_primary_key'
FOREIGN_KEY = 'is_foreign_key'
REFERENCE = 'reference'
TO_DO = '[To be completed ...]'

OUTPUT_PATH = '../data/embeddings/auxs'
MDL_PATH = '../data/embeddings/documents/MDL_adventure_works_dw.yaml'

CHROMA_DB_PATH = '../data/embeddings/chroma'
TABLES_SUMMARY_COLLECTION_NAME = 'mdl_tables_summary'
COLUMNS_COLLECTION_NAME = 'mdl_columns'

AZURE_OPENAI_EMBEDDING_MODEL = 'text-embedding-3-large'
GENAI_EMBEDDING_MODEL = 'gemini-embedding-001'

# %% [markdown]
# ### Clase personalizadas

# %%
class GenaiEmbedConfigTaskType(Enum):
    """
    Enum representing the different task types for GenAI embeddings.
    The value of each member is the same as its name.
    """
    CLASSIFICATION = 'CLASSIFICATION'
    CLUSTERING = 'CLUSTERING'
    RETRIEVAL_DOCUMENT = 'RETRIEVAL_DOCUMENT'
    RETRIEVAL_QUERY = 'RETRIEVAL_QUERY'
    QUESTION_ANSWERING = 'QUESTION_ANSWERING'
    FACT_VERIFICATION = 'FACT_VERIFICATION'
    CODE_RETRIEVAL_QUERY = 'CODE_RETRIEVAL_QUERY'
    SEMANTIC_SIMILARITY = 'SEMANTIC_SIMILARITY'



class GenAIExtendedEmbeddingFunction(LangchainEmbeddings):
    def __init__(self, model: str):
        """
        Initializes the class with the Gemini model.
        
        Args:
            model (str): The name of the Gemini model.
        """
        self.model = model
        self.genai_client = genai.Client()
    
    def _get_genai_embeddings(self, contents: list[str], task_type: GenaiEmbedConfigTaskType | None = None) -> list[list[float]]:
        """
        Internal method to get embeddings from the GenAI API.
        """
        embed_config = genai.types.EmbedContentConfig(task_type=task_type.value) if task_type else None
        
        response = self.genai_client.models.embed_content(
            model= self.model,
            contents= contents,
            config= embed_config
        )
        
        return [embed.values for embed in response.embeddings]
        
    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        """
        Generates embeddings for a list of documents.
        """
        return self._get_genai_embeddings(
            contents= texts,
            task_type= GenaiEmbedConfigTaskType.RETRIEVAL_DOCUMENT
        )

    def embed_query(self, text: str) -> list[float]:
        """
        Generates an embedding for a single query string.
        """
        return self._get_genai_embeddings(
            contents= [text],
            task_type= GenaiEmbedConfigTaskType.RETRIEVAL_QUERY
        )[0]

# %% [markdown]
# ### Funciones aplicables a todos los documentos

# %%
def add_docs_to_chroma_col(chunks: list[dict], collection: Chroma) -> list[str]:
    """
    Store a list of document chunks into a ChromaDB collection using langchain.

    Each chunk is expected to be a dictionary containing 'content' (text of the chunk)
    and 'metadata' (associated metadata) keys. The function generates unique IDs and, if required,
    computes embeddings for each document chunk before adding them to the collection.

    Args:
        chunks (list[dict]): A list of dictionaries, each with keys:
                             - 'content' (str): The text content of the chunk.
                             - 'metadata' (dict): Metadata associated with the chunk.
        collection (langchain_chroma.Chroma): The target ChromaDB collection by langchain to store the data in.

    Returns:
        ids[list[str]]
    """

    ids = [str(uuid.uuid4()) for _ in chunks]

    collection.add_documents(
        ids = ids,
        documents= chunks
    )



def cosine_distance_relevance_score_fn(distance: float) -> float:
    """Normalize the distance [0, 2] to a score on a scale [0, 1]."""
    return 1.0 - distance / 2

# %% [markdown]
# ## Fichero YAML con MDL del esquema de interés

# %% [markdown]
# ### Obtener fichero base desde `information_schema`
#
# Primero obtendremos un fichero base construido utilizando la query `/data/embeddings/auxs/get_information_schema.sql`, sobre el que luego se añadirá metadata extra. Para esto, definimos algunas funciones que nos serán de utilidad:

# %%
def get_information_schema(query_path: str, db_names_list: list[str], schema_names_list: list[str]) -> str:
    """
    Reads an SQL query from a file and replaces placeholder lists with formatted strings.

    This function is designed to work with SQL queries that have specific placeholders
    for database and schema names. It reads the query from the given file path, 
    formats the input lists of names into a single quoted, comma-separated string, 
    and replaces the placeholders in the query.

    Args:
        query_path (str): The file path to the SQL query. The query should
                          contain the placeholders `[db_names_list]` and
                          `[schema_names_list]`.
        db_names_list (list[str]): A list of database names to be formatted
                                   and inserted into the query.
        schema_names_list (list[str]): A list of schema names to be formatted
                                       and inserted into the query.

    Returns:
        str: The complete SQL query with the placeholders replaced by
             the formatted database and schema names.

    Raises:
        FileNotFoundError: If the specified query_path does not exist.
        
    Example:
        >>> from pathlib import Path
        >>> # Assume 'my_query.sql' contains:
        >>> # SELECT * FROM information_schema.tables WHERE table_schema IN ([schema_names_list])
        >>> # And we create a dummy file for the example:
        >>> Path('my_query.sql').write_text("SELECT * FROM information_schema.tables WHERE table_schema IN ([schema_names_list])")
        >>> db_list = ['db1', 'db2']
        >>> schema_list = ['schema_a', 'schema_b']
        >>> get_information_schema('my_query.sql', db_list, schema_list)
        "SELECT * FROM information_schema.tables WHERE table_schema IN ('schema_a', 'schema_b')"
    """
    query = Path(query_path).read_text()

    db_names = "'" + "', '".join(db_names_list) + "'"
    schema_names = "'" + "', '".join(schema_names_list) + "'"

    return query.replace('[db_names_list]', db_names).replace('[schema_names_list]', schema_names)



def format_yaml(yaml_str: str) -> str:
    """
    Formats a YAML string by adding a blank line before each list item
    that isn't preceded by a list key.
    """
    last_line = ''
    last_line_list_init = False
    last_line_empty = False

    lines = list()

    for line in yaml_str.split('\n'):
        if line.strip().startswith('-') and not last_line_list_init and not last_line_empty:
            last_line += '\n'

        lines.append(last_line)
        last_line = line
        last_line_list_init = last_line.strip().endswith(':')
        last_line_empty = last_line.strip()==''

    lines.append(line)

    return '\n'.join(lines)

# %%
GET_INFORMATION_SCHEMA_SQL = '../data/embeddings/auxs/get_information_schema.sql'
DB_NAME = 'adventure_works_dw'
SCHEMA_NAME = 'sales'


information_schema_data = execute_query(get_information_schema(
    query_path= GET_INFORMATION_SCHEMA_SQL,
    db_names_list= [DB_NAME],
    schema_names_list= [SCHEMA_NAME]
))

# %% [markdown]
# Veamos el aspecto que tienen los resultados de nuestra query:

# %%
information_schema_data
# Out:
# [{'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'customer_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'geography_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_geography.geography_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'customer_full_name',
#   'column_type': 'TEXT',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'birth_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'marital_status',
#   'column_type': 'BPCHAR(1)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'gender',
#   'column_type': 'VARCHAR(1)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'yearly_income',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'total_children',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'number_children_at_home',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'english_education',
#   'column_type': 'VARCHAR(40)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'spanish_education',
#   'column_type': 'VARCHAR(40)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'english_occupation',
#   'column_type': 'VARCHAR(100)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'spanish_occupation',
#   'column_type': 'VARCHAR(100)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'house_owner',
#   'column_type': 'BOOL',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'number_cars_owned',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_customer',
#   'column_name': 'commute_distance',
#   'column_type': 'VARCHAR(15)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'geography_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'city',
#   'column_type': 'VARCHAR(30)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'state_province_code',
#   'column_type': 'VARCHAR(3)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'state_province_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'country_region_code',
#   'column_type': 'VARCHAR(3)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'english_country_region_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'spanish_country_region_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'postal_code',
#   'column_type': 'VARCHAR(15)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_geography',
#   'column_name': 'sales_territory_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_sales_territory.sales_territory_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'product_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'weight_unit_measure_code',
#   'column_type': 'BPCHAR(3)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'size_unit_measure_code',
#   'column_type': 'BPCHAR(3)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'english_product_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'spanish_product_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'standard_cost',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'finished_goods_flag',
#   'column_type': 'BOOL',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'color',
#   'column_type': 'VARCHAR(15)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'safety_stock_level',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'reorder_point',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'list_price',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'size',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'size_range',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'weight',
#   'column_type': 'FLOAT8',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'days_to_manufacture',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'product_line',
#   'column_type': 'BPCHAR(2)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'dealer_price',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'class',
#   'column_type': 'BPCHAR(2)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'style',
#   'column_type': 'BPCHAR(2)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'model_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'english_description',
#   'column_type': 'VARCHAR(400)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'start_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'end_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'active',
#   'column_type': 'BOOL',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'english_product_subcategory_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'spanish_product_subcategory_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'english_product_category_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_product',
#   'column_name': 'spanish_product_category_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'promotion_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'english_promotion_name',
#   'column_type': 'VARCHAR(255)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'spanish_promotion_name',
#   'column_type': 'VARCHAR(255)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'discount_pct',
#   'column_type': 'FLOAT8',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'english_promotion_type',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'spanish_promotion_type',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'english_promotion_category',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'spanish_promotion_category',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'start_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'end_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'min_qty',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_promotion',
#   'column_name': 'max_qty',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'reseller_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'geography_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_geography.geography_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'business_type',
#   'column_type': 'VARCHAR(20)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'reseller_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'number_employees',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'order_frequency',
#   'column_type': 'BPCHAR(1)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'first_order_year',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'last_order_year',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'product_line',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_reseller',
#   'column_name': 'year_opened',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_person',
#   'column_name': 'employee_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_person',
#   'column_name': 'employee_full_name',
#   'column_type': 'TEXT',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_person',
#   'column_name': 'title',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_person',
#   'column_name': 'gender',
#   'column_type': 'BPCHAR(1)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_person',
#   'column_name': 'sales_person_flag',
#   'column_type': 'BOOL',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_reason',
#   'column_name': 'sales_reason_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_reason',
#   'column_name': 'sales_reason_name',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_reason',
#   'column_name': 'sales_reason_reason_type',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_territory',
#   'column_name': 'sales_territory_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_territory',
#   'column_name': 'sales_territory_region',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_territory',
#   'column_name': 'sales_territory_country',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'dim_sales_territory',
#   'column_name': 'sales_territory_group',
#   'column_type': 'VARCHAR(50)',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_internet_sales_reason',
#   'column_name': 'sales_order_number',
#   'column_type': 'VARCHAR(20)',
#   'primary_key': True,
#   'foreign_key': True,
#   'target': 'sales.fact_sales.sales_order_number'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_internet_sales_reason',
#   'column_name': 'sales_order_line_number',
#   'column_type': 'INT2',
#   'primary_key': True,
#   'foreign_key': True,
#   'target': 'sales.fact_sales.sales_order_line_number'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_internet_sales_reason',
#   'column_name': 'sales_reason_key',
#   'column_type': 'INT4',
#   'primary_key': True,
#   'foreign_key': True,
#   'target': 'sales.dim_sales_reason.sales_reason_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'product_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_product.product_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'reseller_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_reseller.reseller_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'employee_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_sales_person.employee_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'customer_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_customer.customer_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'promotion_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_promotion.promotion_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'sales_territory_key',
#   'column_type': 'INT4',
#   'primary_key': False,
#   'foreign_key': True,
#   'target': 'sales.dim_sales_territory.sales_territory_key'},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'sales_order_number',
#   'column_type': 'VARCHAR(20)',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'sales_order_line_number',
#   'column_type': 'INT2',
#   'primary_key': True,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'order_quantity',
#   'column_type': 'INT2',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'unit_price',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'extended_amount',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'unit_price_discount_pct',
#   'column_type': 'FLOAT8',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'discount_amount',
#   'column_type': 'FLOAT8',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'product_standard_cost',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'total_product_cost',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'sales_amount',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'tax_amt',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'freight',
#   'column_type': 'NUMERIC',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'order_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'due_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'ship_date',
#   'column_type': 'DATE',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None},
#  {'db_name': 'adventure_works_dw',
#   'schema_name': 'sales',
#   'table_name': 'fact_sales',
#   'column_name': 'sale_source',
#   'column_type': 'TEXT',
#   'primary_key': False,
#   'foreign_key': False,
#   'target': None}]

# %% [markdown]
# Lo convertimos en un Data Frame de Pandas para que sea más vistoso:

# %%
pd.DataFrame(information_schema_data)
# Out:
#                 db_name schema_name    table_name         column_name  \
# 0    adventure_works_dw       sales  dim_customer        customer_key
# 1    adventure_works_dw       sales  dim_customer       geography_key
# 2    adventure_works_dw       sales  dim_customer  customer_full_name
# 3    adventure_works_dw       sales  dim_customer          birth_date
# 4    adventure_works_dw       sales  dim_customer      marital_status
# ..                  ...         ...           ...                 ...
# 107  adventure_works_dw       sales    fact_sales             freight
# 108  adventure_works_dw       sales    fact_sales          order_date
# 109  adventure_works_dw       sales    fact_sales            due_date
# 110  adventure_works_dw       sales    fact_sales           ship_date
# 111  adventure_works_dw       sales    fact_sales         sale_source
#
#     column_type  primary_key  foreign_key                             target
# 0          INT4         True        False                               None
# 1          INT4        False         True  sales.dim_geography.geography_key
# 2          TEXT        False        False                               None
# 3          DATE        False        False                               None
# 4     BPCHAR(1)        False        False                               None
# ..          ...          ...          ...                                ...
# 107     NUMERIC        False        False                               None
# 108        DATE        False        False                               None
# 109        DATE        False        False                               None
# 110        DATE        False        False                               None
# 111        TEXT        False        False                               None
#
# [112 rows x 8 columns]

# %% [markdown]
# Ahora procederemos a crear el YAML base con el MDL de nuestro esquema, que podremos tomar como punto de partida para luego añadirle metadata extra manualmente:

# %%
dbs_data = defaultdict(lambda: defaultdict(lambda: defaultdict(list)))

for row in information_schema_data:
    db_name = row.get('db_name')
    schema_name = row.get('schema_name')
    table_name = row.get('table_name')
    
    dbs_data[db_name][schema_name][table_name].append(row)

for db_name, schemas_data in dbs_data.items():
    db = OrderedDict()
    db[DATABASE] = db_name
    db[DESCRIPTION] = TO_DO

    schemas = list()
    for schema_name, tables_data in schemas_data.items():
        schema = OrderedDict()
        schema[NAME] = schema_name
        schema[DESCRIPTION] = TO_DO

        tables = list()
        for table_name, columns_data in tables_data.items():
            table = OrderedDict()
            table[NAME] = table_name
            table[DESCRIPTION] = TO_DO

            columns = list()
            for column_data in columns_data:
                column = OrderedDict()
                column[NAME] = column_data.get('column_name')
                column[DESCRIPTION] = TO_DO
                column[DATA_TYPE] = column_data.get('column_type')
                
                if column_data.get('primary_key'):
                    column[PRIMARY_KEY] = True

                if column_data.get('foreign_key'):
                    column[FOREIGN_KEY] = True
                    column[REFERENCE] = column_data.get('target')

                columns.append(column)

            table[COLUMNS] = columns
            tables.append(table)
        
        schema[TABLES] = tables
        schemas.append(schema)
    
    db[SCHEMAS] = schemas

    mdl_file_path = f'{OUTPUT_PATH}/MDL_{db_name}.yaml'
    with open(mdl_file_path, 'w') as mdl:
        mdl.write(format_yaml(yaml.dump(db)))

    print(f'>  Fichero MDL base almacenado en {mdl_file_path}')
# Out:
# >  Fichero MDL base almacenado en ../data/embeddings/auxs/MDL_adventure_works_dw.yaml

# %% [markdown]
# ### Creación de embeddings
#
# #### Chunking
#
# Tomando como base el fichero obtenido en el apartado anterior, se ha creado un fichero que del MDL de nuestro esquema de interés que ha sido nutrido con metadata adicional, como descripciones para cada tabla y campo. Este fichero se encuentra en la ruta `/data/embeddings/documents/MDL_adventure_works_dw.yaml`.
#
# Procederemos ahora a procesar este fichero para crear chunks de la información de cada una de las tablas y almacenar sus embeddings en nuestra base de datos vectorial de `chroma_db`, persistida en la ruta `/data/embeddings/chroma_db/`.
#
# Procedemos ahora a definir funciones que nos permitirán chunkear el documento mdl desde un enfoque más integral a nivel de tablas, como también a un enfoque más granular a nivel de columnas:

# %%
def chunk_mdl_by_table_summary(mdl_data: dict) -> list[Document]:
    """
    Chunks a Model-Driven Library (MDL) data structure into a list of Documents,
    with each document representing a summary of a single table.

    Each Document's page_content contains a summary of the table, including its
    database, schema, table name, description, primary keys, and foreign keys.
    The Document's metadata includes the database, schema, and table name for
    easy lookup and filtering.

    Args:
        mdl_data: A dictionary representing the MDL data structure. It is expected
                  to contain keys for 'database', 'schemas', 'tables', 'columns',
                  and other relevant metadata.

    Returns:
        A list of Document objects, where each object holds a table summary chunk
        from the input MDL data.
    """

    chunks = []

    database_name = mdl_data[DATABASE]

    for schema in mdl_data[SCHEMAS]:
        schema_name = schema[NAME]

        for table in schema[TABLES]:
            table_name = table[NAME]
            table_description = table[DESCRIPTION]
            table_columns = table[COLUMNS]
            
            chunk_content_list = [
                f'Database: {database_name}',
                f'Schema: {schema_name}',
                f'Table: {table_name}',
                f'Table description: {table_description}'
            ]

            table_primary_key = [col[NAME] for col in table_columns if col.get(PRIMARY_KEY)]
            if table_primary_key:
                chunk_content_list.append('Table PRIMARY KEY:')
                for pk in table_primary_key:
                    chunk_content_list.append(f'- {pk}')

            table_foreign_keys = [{'column_name': col[NAME], 'reference': col[REFERENCE]} for col in table_columns if col.get(FOREIGN_KEY)]
            if table_foreign_keys:
                chunk_content_list.append('Table FOREIGN KEYS (Column name, Reference):')
                for fk in table_foreign_keys:
                    chunk_content_list.append(f'- ({fk["column_name"]}, {fk["reference"]})')

            chunk_content = '\n'.join(chunk_content_list)

            metadata = {
                'database_name': database_name,
                'schema_name': schema_name,
                'table_name': table_name
            }

            chunks.append(Document(page_content= chunk_content, metadata= metadata))

    return chunks



def chunk_mdl_by_column(mdl_data: dict) -> list[Document]:
    """
    Chunks a Model-Driven Library (MDL) data structure into a list of Documents,
    with each document representing a single column.

    This function iterates through the schemas, tables, and columns of the MDL
    data. For each non-key column (excluding primary and foreign keys), it
    creates a Document. The Document's page_content contains the column's
    name, data type, and description. The Document's metadata includes
    the database, schema, table, and column details for easy retrieval and
    filtering.

    Args:
        mdl_data: A dictionary representing the MDL data structure. It is expected
                  to contain keys for 'database', 'schemas', 'tables', 'columns',
                  and other relevant metadata.

    Returns:
        A list of Document objects, where each object holds a chunk of data
        for a non-key column from the input MDL data.
    """
    chunks = []

    database_name = mdl_data[DATABASE]

    for schema in mdl_data[SCHEMAS]:
        schema_name = schema[NAME]

        for table in schema[TABLES]:
            table_name = table[NAME]
            table_columns = table[COLUMNS]

            for col in table_columns:
                chunk_content_list = list()

                if col.get(PRIMARY_KEY) or col.get(FOREIGN_KEY):
                    continue

                column_name = col[NAME]
                column_data_type = col[DATA_TYPE]
                column_description = col[DESCRIPTION]

                chunk_content_list.append(f'Column name: {column_name}')
                chunk_content_list.append(f'Column data type: {column_data_type}')
                chunk_content_list.append(f'Column description: {column_description}')

                chunk_content = '\n'.join(chunk_content_list)

                metadata = {
                    'database_name': database_name,
                    'schema_name': schema_name,
                    'table_name': table_name,
                    'column_name': column_name,
                    'column_data_type': column_data_type
                }

                chunks.append(Document(page_content= chunk_content, metadata= metadata))

    return chunks

# %% [markdown]
# Veamos ahora el aspecto que tiene, por ejemplo, el chunk de mayor tamaño para cada uno de los tipos:

# %%
with open(MDL_PATH, 'r', encoding='utf-8') as mdl_file:
    mdl_data = yaml.safe_load(mdl_file)

chunks = chunk_mdl_by_table_summary(mdl_data)

max_len = max([len(c.page_content) for c in chunks])
print(f'{max_len=}')
print()
print([c.page_content for c in chunks if len(c.page_content) == max_len][0])
print()
print([c.metadata for c in chunks if len(c.page_content) == max_len][0])
# Out:
# max_len=1020
#
# Database: adventure_works_dw
# Schema: sales
# Table: fact_sales
# Table description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.
# Table PRIMARY KEY:
# - sales_order_number
# - sales_order_line_number
# Table FOREIGN KEYS (Column name, Reference):
# - (product_key, sales.dim_product.product_key)
# - (reseller_key, sales.dim_reseller.reseller_key)
# - (employee_key, sales.dim_sales_person.employee_key)
# - (customer_key, sales.dim_customer.customer_key)
# - (promotion_key, sales.dim_promotion.promotion_key)
# - (sales_territory_key, sales.dim_sales_territory.sales_territory_key)
#
# {'database_name': 'adventure_works_dw', 'schema_name': 'sales', 'table_name': 'fact_sales'}

# %%
with open(MDL_PATH, 'r', encoding='utf-8') as mdl_file:
    mdl_data = yaml.safe_load(mdl_file)

chunks = chunk_mdl_by_column(mdl_data)

max_len = max([len(c.page_content) for c in chunks])
print(f'{max_len=}')
print()
print([c.page_content for c in chunks if len(c.page_content) == max_len][0])
print()
print([c.metadata for c in chunks if len(c.page_content) == max_len][0])
# Out:
# max_len=265
#
# Column name: sale_source
# Column data type: TEXT
# Column description: Indicador de la fuente por la que ha sido realizado el pedido. reseller_sales=Pedido realizado por un vendedor para una tienda/distribuidor, internet_sales=Pedido realizado en línea por un cliente.
#
# {'database_name': 'adventure_works_dw', 'schema_name': 'sales', 'table_name': 'fact_sales', 'column_name': 'sale_source', 'column_data_type': 'TEXT'}

# %% [markdown]
# #### LangChain: Chroma DB + Azure OpenAI Embeddings
#
# Ahora haremos una primera implementación de prueba de Chroma valiéndonos de funcionalidades de la librería LangChain, usando un modelo de embeddings de OpenAI a través de Azure AI Foundry.
#
# El primer paso es crear un cliente persistente de Chroma DB, e inicializar las colecciones tanto a nivel de tablas como de columnas. Al inicializar las colecciones, especificaremos que queremos usar como métrica de distancia la distancia de Coseno, que se calcula de la siguiente manera:
#
# $$Distancia = 1 - \frac{A \cdot B}{\|A\| \|B\|}$$
#
# Donde:
# * $A \cdot B$ es el producto punto (producto escalar) de los vectores $A$ y $B$.
# * $∥A∥$ y $∥B∥$ son las magnitudes (o normas euclidianas) de los vectores $A$ y $B$, respectivamente.
# ​
#
# La métrica **Distancia del Coseno** mide solo el ángulo entre vectores, lo que lo hace ideal para embeddings de texto, y particularmente para modelos de embeddings como los de [OpenAI cuyos valores vienen normalizados](https://help.openai.com/en/articles/8984345-which-distance-function-should-i-use).
#
# Como es fácil ver en su expresión, esta métrica de distancia devuelve valores en el rango $[0, 2]$. Cuanto más cerca de 0, más similares serán los vectores $A$ y $B$. Esto nos deja en la necesidad de definir una métrica de `relevance_score` personalizada, que nos permita reescalar los resultados en valores comprendidos entre $[0, 1]$, siendo los valores más cercanos a 1 indicativo de mayor similitud entre los vectores. Esta métrica la hemos definido en la función `cosine_distance_relevance_score_fn` de la siguiente manera:
#
# $$R_{score} = 1 - \frac{Distancia}{2}$$

# %%
test_openai_embeddings_path = '../data/embeddings/tests/openai'
chroma_client = chromadb.PersistentClient(path= test_openai_embeddings_path)
openai_embeddings = AzureOpenAIEmbeddings(model=AZURE_OPENAI_EMBEDDING_MODEL)


with open(MDL_PATH, 'r', encoding='utf-8') as mdl_file:
    mdl_data = yaml.safe_load(mdl_file)


tables_summary_chunks = chunk_mdl_by_table_summary(mdl_data)
if tables_summary_chunks:
    try:
        chroma_client.delete_collection(TABLES_SUMMARY_COLLECTION_NAME)
    except:
        pass

    tables_summary_collection = Chroma(
        client= chroma_client,
        collection_name= TABLES_SUMMARY_COLLECTION_NAME,
        embedding_function= openai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(tables_summary_chunks, tables_summary_collection)


columns_chunks = chunk_mdl_by_column(mdl_data)
if columns_chunks:
    try:
        chroma_client.delete_collection(COLUMNS_COLLECTION_NAME)
    except:
        pass

    columns_collection = Chroma(
        client= chroma_client,
        collection_name= COLUMNS_COLLECTION_NAME,
        embedding_function= openai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(columns_chunks, columns_collection)

# %% [markdown]
# Lanzamos ahora una consulta a cada una de las colecciones creadas:

# %%
test_openai_embeddings_path = '../data/embeddings/tests/openai'
chroma_client = chromadb.PersistentClient(path= test_openai_embeddings_path)
openai_embeddings = AzureOpenAIEmbeddings(model=AZURE_OPENAI_EMBEDDING_MODEL)

tables_summary_collection = Chroma(
    client= chroma_client,
    collection_name= TABLES_SUMMARY_COLLECTION_NAME,
    embedding_function= openai_embeddings,
    relevance_score_fn= cosine_distance_relevance_score_fn,
    create_collection_if_not_exists= False
)

columns_collection = Chroma(
    client= chroma_client,
    collection_name= COLUMNS_COLLECTION_NAME,
    embedding_function= openai_embeddings,
    relevance_score_fn= cosine_distance_relevance_score_fn,
    create_collection_if_not_exists= False
)

# %%
QUERY = 'Los 10 artículos más comprados.'

# %%
tables_summary_results = tables_summary_collection.similarity_search_with_relevance_scores(
    query= QUERY,
    k= 10,
    score_threshold= 0.20
)

relevant_columns = []
for table_result in tables_summary_results:
    database_name = table_result[0].metadata['database_name']
    schema_name = table_result[0].metadata['schema_name']
    table_name = table_result[0].metadata['table_name']

    table_filter = {
        "$and": [
            {"database_name": {"$eq": database_name}},
            {"schema_name": {"$eq": schema_name}},
            {"table_name": {"$eq": table_name}}
        ]
    }

    columns_results = columns_collection.similarity_search_with_relevance_scores(
        query= QUERY,
        k= 15,
        filter=table_filter,
        score_threshold= 0.15
    )

    if columns_results:
        relevant_columns.append({
            'table_summary': {
                'content': table_result[0].page_content,
                'relevance_score': table_result[1]
            },
            'columns': [{'content': col[0].page_content, 'relevance_score': col[1]} for col in columns_results]
        })

if not relevant_columns:
    relevant_columns = [f'No docs retrieved for the query "{QUERY}"']

print(json.dumps(relevant_columns, indent=2, ensure_ascii=False))
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.15
# [
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#       "relevance_score": 0.6411375403404236
#     },
#     "columns": [
#       {
#         "content": "Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.",
#         "relevance_score": 0.6759496331214905
#       },
#       {
#         "content": "Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.",
#         "relevance_score": 0.6552140712738037
#       },
#       {
#         "content": "Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.",
#         "relevance_score": 0.6396479904651642
#       },
#       {
#         "content": "Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.",
#         "relevance_score": 0.6371793448925018
#       },
#       {
#         "content": "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. reseller_sales=Pedido realizado por un vendedor para una tienda/distribuidor, internet_sales=Pedido realizado en línea por un cliente.",
#         "relevance_score": 0.6369858980178833
#       },
#       {
#         "content": "Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.",
#         "relevance_score": 0.6300035417079926
#       },
#       {
#         "content": "Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.",
#         "relevance_score": 0.6297131776809692
#       },
#       {
#         "content": "Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado.",
#         "relevance_score": 0.6289900541305542
#       },
#       {
#         "content": "Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.",
#         "relevance_score": 0.6257866024971008
#       },
#       {
#         "content": "Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.",
#         "relevance_score": 0.623193085193634
#       },
#       {
#         "content": "Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.",
#         "relevance_score": 0.6226969361305237
#       },
#       {
#         "content": "Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.",
#         "relevance_score": 0.6190215349197388
#       },
#       {
#         "content": "Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#         "relevance_score": 0.6076865196228027
#       },
#       {
#         "content": "Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#         "relevance_score": 0.6055112481117249
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_product\nTable description: Tabla de dimensión que almacena la información detallada de cada producto que alguna vez haya sido vendido. Relevante para cualquier consulta en la que se nos pida listar productos por su nombre.\nTable PRIMARY KEY:\n- product_key",
#       "relevance_score": 0.63812655210495
#     },
#     "columns": [
#       {
#         "content": "Column name: list_price\nColumn data type: NUMERIC\nColumn description: Precio de venta del producto en USD.",
#         "relevance_score": 0.6599270105361938
#       },
#       {
#         "content": "Column name: finished_goods_flag\nColumn data type: BOOL\nColumn description: Indicador de si se trata de un producto final vendible. 0 = El producto no es un artículo vendible, 1 = El producto es vendible.",
#         "relevance_score": 0.6478825509548187
#       },
#       {
#         "content": "Column name: english_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.646866112947464
#       },
#       {
#         "content": "Column name: reorder_point\nColumn data type: INT2\nColumn description: Nivel de stock que dispara una orden de compra o una orden de trabajo.",
#         "relevance_score": 0.6394508481025696
#       },
#       {
#         "content": "Column name: english_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.6390998661518097
#       },
#       {
#         "content": "Column name: safety_stock_level\nColumn data type: INT2\nColumn description: Nivel de stock mínimo del producto.",
#         "relevance_score": 0.6353709101676941
#       },
#       {
#         "content": "Column name: spanish_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (ESPAÑOL). NUNCA viene a NULL.",
#         "relevance_score": 0.6334809958934784
#       },
#       {
#         "content": "Column name: english_description\nColumn data type: VARCHAR(400)\nColumn description: Descripción detallada del producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.6331214308738708
#       },
#       {
#         "content": "Column name: active\nColumn data type: BOOL\nColumn description: Indicador de si el producto sigue disponible para la venta.",
#         "relevance_score": 0.6318128705024719
#       },
#       {
#         "content": "Column name: english_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.6311166286468506
#       },
#       {
#         "content": "Column name: standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar del producto en USD.",
#         "relevance_score": 0.6308408677577972
#       },
#       {
#         "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto estuvo disponible para la venta.",
#         "relevance_score": 0.6287546753883362
#       },
#       {
#         "content": "Column name: style\nColumn data type: BPCHAR(2)\nColumn description: Público para el que está pensado el producto. W=Womens(Mujeres), M=Mens(Hombres), U=Universal.  Puede venir a NULL.",
#         "relevance_score": 0.6285305023193359
#       },
#       {
#         "content": "Column name: size\nColumn data type: VARCHAR(50)\nColumn description: Talla del producto. Ej. 48, L. Puede venir a NULL.",
#         "relevance_score": 0.6284976303577423
#       },
#       {
#         "content": "Column name: spanish_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (ESPAÑOL). NUNCA viene a NULL.",
#         "relevance_score": 0.626615047454834
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_reason\nTable description: Tabla de dimensión que almacena la información detallada de cada motivo de venta. Relevante cuando se busca comprender los principales motivos por los que se han logrado las ventas.\nTable PRIMARY KEY:\n- sales_reason_key",
#       "relevance_score": 0.6086737513542175
#     },
#     "columns": [
#       {
#         "content": "Column name: sales_reason_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del motivo de venta. NUNCA viene a NULL.Ej. Price, On Promotion, Magazine Advertisement.",
#         "relevance_score": 0.6247309148311615
#       },
#       {
#         "content": "Column name: sales_reason_reason_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo del motivo de venta. NUNCA viene a NULL. Ej. Other, Promotion, Marketing.",
#         "relevance_score": 0.6223631501197815
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_promotion\nTable description: Tabla de dimensión que almacena la información detallada de las diferentes promociones / descuentos que pueden aplicarse a las ventas. Relevante cuando se quiere segmentar las promociones que han sido aplicadas en las ventas.\nTable PRIMARY KEY:\n- promotion_key",
#       "relevance_score": 0.6084896922111511
#     },
#     "columns": [
#       {
#         "content": "Column name: max_qty\nColumn data type: INT4\nColumn description: Cantidad máxima a la que será aplicable la promoción. En caso de venir a NULL, significa que no hay límite.",
#         "relevance_score": 0.6358386278152466
#       },
#       {
#         "content": "Column name: english_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (INGLÉS). NUNCA será NULL. Ej. No Discount, Volume Discount, Seasonal Discount.",
#         "relevance_score": 0.6292128562927246
#       },
#       {
#         "content": "Column name: spanish_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (ESPAÑOL). NUNCA será NULL. Ej. Sin descuento, Descuento por volumen, Descuento de temporada.",
#         "relevance_score": 0.6287905871868134
#       },
#       {
#         "content": "Column name: min_qty\nColumn data type: INT4\nColumn description: Cantidad mínima necesaria para aplicar la promoción. NUNCA será NULL.",
#         "relevance_score": 0.6253530979156494
#       },
#       {
#         "content": "Column name: english_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (INGLÉS). NUNCA será NULL. Indica si es aplicable a un distribuidor (Reseller) o a un cliente final (Customer).",
#         "relevance_score": 0.6215106248855591
#       },
#       {
#         "content": "Column name: english_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (INGLÉS). NUNCA será NULL.",
#         "relevance_score": 0.6152471303939819
#       },
#       {
#         "content": "Column name: spanish_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (ESPAÑOL). NUNCA será NULL. Indica si es aplicable a un distribuidor (Distribuidor) o a un cliente final (Cliente).",
#         "relevance_score": 0.61419278383255
#       },
#       {
#         "content": "Column name: discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicable a la promoción, en decimal. Comprendido entre 0 y 1. NUNCA será NULL. Ej. 0, 0.02, 0.05.",
#         "relevance_score": 0.6117531657218933
#       },
#       {
#         "content": "Column name: spanish_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (ESPAÑOL). NUNCA será NULL.",
#         "relevance_score": 0.6092495620250702
#       },
#       {
#         "content": "Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que deja de ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#         "relevance_score": 0.5864622592926025
#       },
#       {
#         "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que comienza a ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#         "relevance_score": 0.5830130577087402
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_reseller\nTable description: Tabla de dimensión que almacena la información detallada de cada tienda/distribuidor. Relevante siempre que se pida obtener listado con datos de tiendas/distribuidores porque en esta tabla se almacenan sus nombres.\nTable PRIMARY KEY:\n- reseller_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#       "relevance_score": 0.6082528233528137
#     },
#     "columns": [
#       {
#         "content": "Column name: last_order_year\nColumn data type: INT4\nColumn description: Año de última compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#         "relevance_score": 0.6362386345863342
#       },
#       {
#         "content": "Column name: reseller_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre de la tienda / distribuidor.",
#         "relevance_score": 0.6332874000072479
#       },
#       {
#         "content": "Column name: business_type\nColumn data type: VARCHAR(20)\nColumn description: Tipo de negocio / tienda del que se trata. Ej. Value Added Reseller, Specialty Bike Shop, Warehouse",
#         "relevance_score": 0.6264321804046631
#       },
#       {
#         "content": "Column name: product_line\nColumn data type: VARCHAR(50)\nColumn description: Línea de productos en la que se especializa el distribuidor. Ej. Road, Mountain, Touring.",
#         "relevance_score": 0.6174139082431793
#       },
#       {
#         "content": "Column name: first_order_year\nColumn data type: INT4\nColumn description: Año de primera compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#         "relevance_score": 0.6171914935112
#       },
#       {
#         "content": "Column name: number_employees\nColumn data type: INT4\nColumn description: Cantidad de empleados de la tienda / distribuidor.",
#         "relevance_score": 0.6160523891448975
#       },
#       {
#         "content": "Column name: order_frequency\nColumn data type: BPCHAR(1)\nColumn description: Frecuencia con la que se espera que compre un distribuidor. A=Anually(Anual), S=Semestrally(Semestral), Q=Quaterlly(Trimestral).",
#         "relevance_score": 0.6116629540920258
#       },
#       {
#         "content": "Column name: year_opened\nColumn data type: NUMERIC\nColumn description: Año de apertura de la tienda / distribuidor.",
#         "relevance_score": 0.5899373888969421
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_person\nTable description: Tabla de dimensión que almacena la información detallada de cada vendedor. Relevante cuando se nos pide sacar información relativa a las ventas que ha hecho cada vendedor, ya que en esta tabla se tiene el nombre de cada uno.\nTable PRIMARY KEY:\n- employee_key",
#       "relevance_score": 0.6044377684593201
#     },
#     "columns": [
#       {
#         "content": "Column name: title\nColumn data type: VARCHAR(50)\nColumn description: Título que ese vendedor tiene dentro de la compañía como empleado.",
#         "relevance_score": 0.6241055130958557
#       },
#       {
#         "content": "Column name: employee_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del vendedor.",
#         "relevance_score": 0.6201631426811218
#       },
#       {
#         "content": "Column name: sales_person_flag\nColumn data type: BOOL\nColumn description: Indicador que se trata de un empleado vendedor. SIEMPRE vendrá a true.",
#         "relevance_score": 0.6072057485580444
#       },
#       {
#         "content": "Column name: gender\nColumn data type: BPCHAR(1)\nColumn description: Género del vendedor. F=Female(Mujer), M=Male(Hombre)",
#         "relevance_score": 0.6046651005744934
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_customer\nTable description: Tabla de dimensión que almacena la información detallada de cada cliente que haya comprado online (por internet). Relevante cuando se hacen consultas relativas a clientes, como su nombre, análisis por género y estado civil o ingresos de los mismos.\nTable PRIMARY KEY:\n- customer_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#       "relevance_score": 0.602695494890213
#     },
#     "columns": [
#       {
#         "content": "Column name: customer_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del cliente.",
#         "relevance_score": 0.6145213544368744
#       },
#       {
#         "content": "Column name: total_children\nColumn data type: INT2\nColumn description: Cantidad total de hijos del cliente.",
#         "relevance_score": 0.60736483335495
#       },
#       {
#         "content": "Column name: spanish_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (ESPAÑOL).",
#         "relevance_score": 0.6037447154521942
#       },
#       {
#         "content": "Column name: english_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (INGLÉS).",
#         "relevance_score": 0.6027345359325409
#       },
#       {
#         "content": "Column name: english_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (INGLÉS).",
#         "relevance_score": 0.5994009375572205
#       },
#       {
#         "content": "Column name: number_cars_owned\nColumn data type: INT2\nColumn description: Cantidad de tarjetas de crédito que posee el cliente.",
#         "relevance_score": 0.5971830785274506
#       },
#       {
#         "content": "Column name: number_children_at_home\nColumn data type: INT2\nColumn description: Cantidad total de hijos convivientes del cliente.",
#         "relevance_score": 0.5964930355548859
#       },
#       {
#         "content": "Column name: commute_distance\nColumn data type: VARCHAR(15)\nColumn description: Distancia entre la casa del cliente y su lugar habitual de trabajo. Segmentado en 5 categorías: [\"0-1 Miles\", \"1-2 Miles\", \"2-5 Miles\", \"5-10 Miles\", \"10+ Miles\"]",
#         "relevance_score": 0.5964852869510651
#       },
#       {
#         "content": "Column name: yearly_income\nColumn data type: NUMERIC\nColumn description: Ingreso anual del cliente en USD.",
#         "relevance_score": 0.5949546694755554
#       },
#       {
#         "content": "Column name: spanish_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (ESPAÑOL).",
#         "relevance_score": 0.5924133062362671
#       },
#       {
#         "content": "Column name: house_owner\nColumn data type: BOOL\nColumn description: Indicador de si el cliente es propietario. True=Propietario, False=No Propietario",
#         "relevance_score": 0.5923815667629242
#       },
#       {
#         "content": "Column name: gender\nColumn data type: VARCHAR(1)\nColumn description: Género del cliente. F=Female(Mujer), M=Male(Hombre)",
#         "relevance_score": 0.5921235084533691
#       },
#       {
#         "content": "Column name: birth_date\nColumn data type: DATE\nColumn description: Fecha de nacimiento del cliente.",
#         "relevance_score": 0.5831007361412048
#       },
#       {
#         "content": "Column name: marital_status\nColumn data type: BPCHAR(1)\nColumn description: Estado civil del cliente. M=Married(Casada/o), S=Single(Soltera/o)",
#         "relevance_score": 0.5698195099830627
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_territory\nTable description: Tabla de dimensión que almacena la información detallada de cada cada división territorial de ventas. Relevante cuando se quieren hacer análisis de venta a nivel territorial.\nTable PRIMARY KEY:\n- sales_territory_key",
#       "relevance_score": 0.5998295545578003
#     },
#     "columns": [
#       {
#         "content": "Column name: sales_territory_country\nColumn data type: VARCHAR(50)\nColumn description: País al que corresponde cada territorio de ventas. Ej. United States, France.",
#         "relevance_score": 0.6070562601089478
#       },
#       {
#         "content": "Column name: sales_territory_group\nColumn data type: VARCHAR(50)\nColumn description: Agrupación territorial a la que pertenece cada territorio de ventas. Ej. North America, Europe.",
#         "relevance_score": 0.6023726463317871
#       },
#       {
#         "content": "Column name: sales_territory_region\nColumn data type: VARCHAR(50)\nColumn description: Región a la que corresponde cada territorio de ventas, contextualizado dentro de cada country. En caso de que no haya región, será el propio country. Ej. Southeast, France.",
#         "relevance_score": 0.6009357869625092
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_geography\nTable description: Tabla de dimensión que almacena información detallada sobre datos geográficos. Relevante cuando se desea analizar información desglosada a nivel ciudades, códigos postales, estados, países, etc.\nTable PRIMARY KEY:\n- geography_key\nTable FOREIGN KEYS (Column name, Reference):\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#       "relevance_score": 0.5863727927207947
#     },
#     "columns": [
#       {
#         "content": "Column name: english_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (INGLÉS).",
#         "relevance_score": 0.6106633543968201
#       },
#       {
#         "content": "Column name: country_region_code\nColumn data type: VARCHAR(3)\nColumn description: Código del país.",
#         "relevance_score": 0.6051188111305237
#       },
#       {
#         "content": "Column name: postal_code\nColumn data type: VARCHAR(15)\nColumn description: Código postal",
#         "relevance_score": 0.6034467220306396
#       },
#       {
#         "content": "Column name: city\nColumn data type: VARCHAR(30)\nColumn description: Nombre de la ciudad.",
#         "relevance_score": 0.5998468995094299
#       },
#       {
#         "content": "Column name: state_province_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del estado/provincia.",
#         "relevance_score": 0.5981569290161133
#       },
#       {
#         "content": "Column name: state_province_code\nColumn data type: VARCHAR(3)\nColumn description: Código del estado/provincia.",
#         "relevance_score": 0.5965031683444977
#       },
#       {
#         "content": "Column name: spanish_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (ESPAÑOL).",
#         "relevance_score": 0.5921602249145508
#       }
#     ]
#   }
# ]

# %%
print(relevant_columns)
# Out:
# [{'table_summary': {'content': 'Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)', 'relevance_score': 0.6411375403404236}, 'columns': [{'content': 'Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.', 'relevance_score': 0.6759496331214905}, {'content': 'Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.', 'relevance_score': 0.6552140712738037}, {'content': 'Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.', 'relevance_score': 0.6396479904651642}, {'content': 'Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.', 'relevance_score': 0.6371793448925018}, {'content': 'Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. reseller_sales=Pedido realizado por un vendedor para una tienda/distribuidor, internet_sales=Pedido realizado en línea por un cliente.', 'relevance_score': 0.6369858980178833}, {'content': 'Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.', 'relevance_score': 0.6300035417079926}, {'content': 'Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.', 'relevance_score': 0.6297131776809692}, {'content': 'Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado.', 'relevance_score': 0.6289900541305542}, {'content': 'Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.', 'relevance_score': 0.6257866024971008}, {'content': 'Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.', 'relevance_score': 0.623193085193634}, {'content': 'Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.', 'relevance_score': 0.6226969361305237}, {'content': 'Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.', 'relevance_score': 0.6190215349197388}, {'content': 'Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. NUNCA vendrá a NULL, dado que se  ...

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0)

SYSTEM_PROMPT = """
You are a context summarizer that receives retrieval documents in JSON format.
Your role is to:

1. Analyze the given JSON documents carefully.
2. Identify and extract only the information relevant to answer the user's question.
3. Summarize relevant tables, columns, keys, and descriptions into a clear and concise text.
4. Exclude any irrelevant or low-relevance details.
5. Ensure factual accuracy; do not fabricate information.
6. Do NOT generate or suggest any SQL queries.
7. When it is possible, match the language of the query fields to the user's query. For example, if user's query is in spanish, use `spanish_...`.
8. Match the language of the summary to the user's query.

Input:
- Retrieval documents (JSON): {retrieval_documents}

Output:
- A concise summary of relevant context—focused on tables, columns, keys, and descriptions—that will help generate an accurate SQL query. Don't suggest any query, only bring information in plain text. 
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': json.dumps(relevant_columns, ensure_ascii=False)
})

Markdown(contexto_resumido)
# Out:
# Para obtener información sobre los 10 artículos más comprados, se pueden considerar las siguientes tablas y columnas relevantes de la base de datos `adventure_works_dw`:
#
# 1. **Tabla: fact_sales**
#    - **Descripción**: Contiene el detalle de las órdenes de ventas entregadas, con granularidad a nivel de línea.
#    - **Claves Primarias**:
#      - `sales_order_number`
#      - `sales_order_line_number`
#    - **Columnas relevantes**:
#      - `order_quantity`: Cantidad vendida de cada producto.
#      - `product_key`: Clave del producto (clave foránea que se relaciona con la tabla `dim_product`).
#
# 2. **Tabla: dim_product**
#    - **Descripción**: Almacena información detallada de cada producto vendido.
#    - **Clave Primaria**:
#      - `product_key`
#    - **Columnas relevantes**:
#      - `english_product_name`: Nombre del producto (en inglés).
#      - `spanish_product_category_name`: Categoría principal a la que pertenece el producto (en español).
#
# Para determinar los artículos más comprados, se puede utilizar la columna `order_quantity` de la tabla `fact_sales` junto con la clave del producto para hacer referencia a la tabla `dim_product` y obtener los nombres de los productos.

# %% [markdown]
# #### LangChain: Chroma DB + Google GenAI Embeddings

# %% [markdown]
# Ahora haremos una segunda implementación de prueba de Chroma valiéndonos de funcionalidades de la librería LangChain, usando un modelo de embeddings de Google Gemini a través de Gemini API, pero trabajando con VertexAI de fondo, lo que nos permite asegurar que los datos permanezcan en la region / location deseada.
#
# Dado que la clase implementada por LangChain para utilizar embeddings de Gemini API no soporta usar VertexAI por detrás, hemos procedido a implementar una clase personalizada que sí nos los permite, a la que hemos llamado `GenAIExtendedEmbeddingFunction`.
#
# Generamos una instancia de la clase y verificamos que los parámetros son los esperados:

# %%
genai_embeddings = GenAIExtendedEmbeddingFunction(model= GENAI_EMBEDDING_MODEL)
print(f'VertexAI: {genai_embeddings.genai_client._api_client.vertexai}')
print(f'Project: {genai_embeddings.genai_client._api_client.project}')
print(f'Location: {genai_embeddings.genai_client._api_client.location}')
print(f'Auth Tokens: {genai_embeddings.genai_client.auth_tokens}')
# Out:
# VertexAI: True
# Project: gen-lang-client-0151767776
# Location: europe-west1
# Auth Tokens: <google.genai.tokens.Tokens object at 0x0000027B349EAB90>

# %% [markdown]
# El próximo paso es crear un cliente persistente de Chroma DB, e inicializar las colecciones tanto a nivel de tablas como de columnas. Al inicializar las colecciones, especificaremos que queremos usar como métrica de distancia la distancia de Coseno, que se calcula de la siguiente manera:
#
# $$Distancia = 1 - \frac{A \cdot B}{\|A\| \|B\|}$$
#
# Donde:
# * $A \cdot B$ es el producto punto (producto escalar) de los vectores $A$ y $B$.
# * $∥A∥$ y $∥B∥$ son las magnitudes (o normas euclidianas) de los vectores $A$ y $B$, respectivamente.
# ​
#
# La métrica **Distancia del Coseno** mide solo el ángulo entre vectores, lo que lo hace ideal para embeddings de texto, y particularmente para modelos de embeddings como el que usaremos [(`gemini-embedding-001`) cuyos valores vienen normalizados](https://ai.google.dev/gemini-api/docs/embeddings#quality-for-smaller-dimensions).
#
# Como es fácil ver en su expresión, esta métrica de distancia devuelve valores en el rango $[0, 2]$. Cuanto más cerca de 0, más similares serán los vectores $A$ y $B$. Esto nos deja en la necesidad de definir una métrica de `relevance_score` personalizada, que nos permita reescalar los resultados en valores comprendidos entre $[0, 1]$, siendo los valores más cercanos a 1 indicativo de mayor similitud entre los vectores. Esta métrica la hemos definido en la función `cosine_distance_relevance_score_fn` de la siguiente manera:
#
# $$R_{score} = 1 - \frac{Distancia}{2}$$

# %%
test_genai_embeddings_path = '../data/embeddings/tests/genai'
chroma_client = chromadb.PersistentClient(path= test_genai_embeddings_path)
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)


with open(MDL_PATH, 'r', encoding='utf-8') as mdl_file:
    mdl_data = yaml.safe_load(mdl_file)


tables_summary_chunks = chunk_mdl_by_table_summary(mdl_data)
if tables_summary_chunks:
    try:
        chroma_client.delete_collection(TABLES_SUMMARY_COLLECTION_NAME)
    except:
        pass

    tables_summary_collection = Chroma(
        client= chroma_client,
        collection_name= TABLES_SUMMARY_COLLECTION_NAME,
        embedding_function= genai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(tables_summary_chunks, tables_summary_collection)


columns_chunks = chunk_mdl_by_column(mdl_data)
if columns_chunks:
    try:
        chroma_client.delete_collection(COLUMNS_COLLECTION_NAME)
    except:
        pass

    columns_collection = Chroma(
        client= chroma_client,
        collection_name= COLUMNS_COLLECTION_NAME,
        embedding_function= genai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(columns_chunks, columns_collection)

# %% [markdown]
# Lanzamos ahora una consulta a cada una de las colecciones creadas:

# %%
test_genai_embeddings_path = '../data/embeddings/tests/genai'
chroma_client = chromadb.PersistentClient(path= test_genai_embeddings_path)
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)

tables_summary_collection = Chroma(
    client= chroma_client,
    collection_name= TABLES_SUMMARY_COLLECTION_NAME,
    relevance_score_fn= cosine_distance_relevance_score_fn,
    embedding_function= genai_embeddings
)

columns_collection = Chroma(
    client= chroma_client,
    collection_name= COLUMNS_COLLECTION_NAME,
    relevance_score_fn= cosine_distance_relevance_score_fn,
    embedding_function= genai_embeddings
)

# %%
QUERY = 'Los 10 artículos más comprados.'

# %%
tables_summary_results = tables_summary_collection.similarity_search_with_relevance_scores(
    query= QUERY,
    k= 10,
    score_threshold= 0.75
)

relevant_columns = []
for table_result in tables_summary_results:
    database_name = table_result[0].metadata['database_name']
    schema_name = table_result[0].metadata['schema_name']
    table_name = table_result[0].metadata['table_name']

    table_filter = {
        "$and": [
            {"database_name": {"$eq": database_name}},
            {"schema_name": {"$eq": schema_name}},
            {"table_name": {"$eq": table_name}}
        ]
    }

    columns_results = columns_collection.similarity_search_with_relevance_scores(
        query= QUERY,
        k= 15,
        filter=table_filter,
        score_threshold= 0.75
    )

    if columns_results:
        relevant_columns.append({
            'table_summary': {
                'content': table_result[0].page_content,
                'relevance_score': table_result[1]
            },
            'columns': [{'content': col[0].page_content, 'relevance_score': col[1]} for col in columns_results]
        })

if not relevant_columns:
    relevant_columns = [f'No docs retrieved for the query "{QUERY}"']

print(json.dumps(relevant_columns, indent=2, ensure_ascii=False))
# Out:
# No relevant docs were retrieved using the relevance score threshold 0.75
# [
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#       "relevance_score": 0.8164841830730438
#     },
#     "columns": [
#       {
#         "content": "Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.",
#         "relevance_score": 0.8307240903377533
#       },
#       {
#         "content": "Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.",
#         "relevance_score": 0.8191922307014465
#       },
#       {
#         "content": "Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.",
#         "relevance_score": 0.8191659450531006
#       },
#       {
#         "content": "Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. reseller_sales=Pedido realizado por un vendedor para una tienda/distribuidor, internet_sales=Pedido realizado en línea por un cliente.",
#         "relevance_score": 0.8173243403434753
#       },
#       {
#         "content": "Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado.",
#         "relevance_score": 0.8153335452079773
#       },
#       {
#         "content": "Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.",
#         "relevance_score": 0.8134251534938812
#       },
#       {
#         "content": "Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#         "relevance_score": 0.8132243752479553
#       },
#       {
#         "content": "Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.",
#         "relevance_score": 0.8120576441287994
#       },
#       {
#         "content": "Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.",
#         "relevance_score": 0.8111945390701294
#       },
#       {
#         "content": "Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.",
#         "relevance_score": 0.8065207004547119
#       },
#       {
#         "content": "Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.",
#         "relevance_score": 0.8065106868743896
#       },
#       {
#         "content": "Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.",
#         "relevance_score": 0.8064069747924805
#       },
#       {
#         "content": "Column name: tax_amt\nColumn data type: NUMERIC\nColumn description: Importe de impuestos en USD aplicable a la línea de orden de venta.",
#         "relevance_score": 0.8057128489017487
#       },
#       {
#         "content": "Column name: product_standard_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de cada unidad de producto.",
#         "relevance_score": 0.8025481998920441
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_product\nTable description: Tabla de dimensión que almacena la información detallada de cada producto que alguna vez haya sido vendido. Relevante para cualquier consulta en la que se nos pida listar productos por su nombre.\nTable PRIMARY KEY:\n- product_key",
#       "relevance_score": 0.815522164106369
#     },
#     "columns": [
#       {
#         "content": "Column name: list_price\nColumn data type: NUMERIC\nColumn description: Precio de venta del producto en USD.",
#         "relevance_score": 0.826146811246872
#       },
#       {
#         "content": "Column name: finished_goods_flag\nColumn data type: BOOL\nColumn description: Indicador de si se trata de un producto final vendible. 0 = El producto no es un artículo vendible, 1 = El producto es vendible.",
#         "relevance_score": 0.82537841796875
#       },
#       {
#         "content": "Column name: active\nColumn data type: BOOL\nColumn description: Indicador de si el producto sigue disponible para la venta.",
#         "relevance_score": 0.8233605325222015
#       },
#       {
#         "content": "Column name: style\nColumn data type: BPCHAR(2)\nColumn description: Público para el que está pensado el producto. W=Womens(Mujeres), M=Mens(Hombres), U=Universal.  Puede venir a NULL.",
#         "relevance_score": 0.8195931911468506
#       },
#       {
#         "content": "Column name: english_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.8188004493713379
#       },
#       {
#         "content": "Column name: english_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.8172828555107117
#       },
#       {
#         "content": "Column name: spanish_product_category_name\nColumn data type: VARCHAR(50)\nColumn description: Categoría principal a la que pertenece el producto (ESPAÑOL). NUNCA viene a NULL.",
#         "relevance_score": 0.8167966604232788
#       },
#       {
#         "content": "Column name: english_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (INGLÉS). NUNCA viene a NULL.",
#         "relevance_score": 0.8156057298183441
#       },
#       {
#         "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto estuvo disponible para la venta.",
#         "relevance_score": 0.8153622150421143
#       },
#       {
#         "content": "Column name: safety_stock_level\nColumn data type: INT2\nColumn description: Nivel de stock mínimo del producto.",
#         "relevance_score": 0.8147757053375244
#       },
#       {
#         "content": "Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que el producto dejó de estar disponible para la venta. En caso de que siga disponible, vendrá a NULL.",
#         "relevance_score": 0.8147149980068207
#       },
#       {
#         "content": "Column name: class\nColumn data type: BPCHAR(2)\nColumn description: Gama a la que pertenece el producto. H=High(Alta), M=Medium(Media), L=Low(Baja). Puede venir a NULL.",
#         "relevance_score": 0.8146228790283203
#       },
#       {
#         "content": "Column name: size\nColumn data type: VARCHAR(50)\nColumn description: Talla del producto. Ej. 48, L. Puede venir a NULL.",
#         "relevance_score": 0.8142132759094238
#       },
#       {
#         "content": "Column name: spanish_product_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del producto (ESPAÑOL). Puede venir a NULL.",
#         "relevance_score": 0.8136493265628815
#       },
#       {
#         "content": "Column name: spanish_product_subcategory_name\nColumn data type: VARCHAR(50)\nColumn description: Sub-categoría a la que pertenece el producto (ESPAÑOL). NUNCA viene a NULL.",
#         "relevance_score": 0.8136186599731445
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_customer\nTable description: Tabla de dimensión que almacena la información detallada de cada cliente que haya comprado online (por internet). Relevante cuando se hacen consultas relativas a clientes, como su nombre, análisis por género y estado civil o ingresos de los mismos.\nTable PRIMARY KEY:\n- customer_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#       "relevance_score": 0.8073857426643372
#     },
#     "columns": [
#       {
#         "content": "Column name: total_children\nColumn data type: INT2\nColumn description: Cantidad total de hijos del cliente.",
#         "relevance_score": 0.8068451583385468
#       },
#       {
#         "content": "Column name: commute_distance\nColumn data type: VARCHAR(15)\nColumn description: Distancia entre la casa del cliente y su lugar habitual de trabajo. Segmentado en 5 categorías: [\"0-1 Miles\", \"1-2 Miles\", \"2-5 Miles\", \"5-10 Miles\", \"10+ Miles\"]",
#         "relevance_score": 0.8046850264072418
#       },
#       {
#         "content": "Column name: gender\nColumn data type: VARCHAR(1)\nColumn description: Género del cliente. F=Female(Mujer), M=Male(Hombre)",
#         "relevance_score": 0.8046623468399048
#       },
#       {
#         "content": "Column name: number_cars_owned\nColumn data type: INT2\nColumn description: Cantidad de tarjetas de crédito que posee el cliente.",
#         "relevance_score": 0.8042223453521729
#       },
#       {
#         "content": "Column name: house_owner\nColumn data type: BOOL\nColumn description: Indicador de si el cliente es propietario. True=Propietario, False=No Propietario",
#         "relevance_score": 0.8039150536060333
#       },
#       {
#         "content": "Column name: customer_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del cliente.",
#         "relevance_score": 0.8033779859542847
#       },
#       {
#         "content": "Column name: number_children_at_home\nColumn data type: INT2\nColumn description: Cantidad total de hijos convivientes del cliente.",
#         "relevance_score": 0.8027271032333374
#       },
#       {
#         "content": "Column name: yearly_income\nColumn data type: NUMERIC\nColumn description: Ingreso anual del cliente en USD.",
#         "relevance_score": 0.7981598675251007
#       },
#       {
#         "content": "Column name: english_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (INGLÉS).",
#         "relevance_score": 0.7957025170326233
#       },
#       {
#         "content": "Column name: english_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (INGLÉS).",
#         "relevance_score": 0.7942386269569397
#       },
#       {
#         "content": "Column name: birth_date\nColumn data type: DATE\nColumn description: Fecha de nacimiento del cliente.",
#         "relevance_score": 0.7926647663116455
#       },
#       {
#         "content": "Column name: spanish_occupation\nColumn data type: VARCHAR(100)\nColumn description: Ocupación del cliente (ESPAÑOL).",
#         "relevance_score": 0.7923164665699005
#       },
#       {
#         "content": "Column name: marital_status\nColumn data type: BPCHAR(1)\nColumn description: Estado civil del cliente. M=Married(Casada/o), S=Single(Soltera/o)",
#         "relevance_score": 0.7920047044754028
#       },
#       {
#         "content": "Column name: spanish_education\nColumn data type: VARCHAR(40)\nColumn description: Nivel de educación del cliente (ESPAÑOL).",
#         "relevance_score": 0.7916126847267151
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_reason\nTable description: Tabla de dimensión que almacena la información detallada de cada motivo de venta. Relevante cuando se busca comprender los principales motivos por los que se han logrado las ventas.\nTable PRIMARY KEY:\n- sales_reason_key",
#       "relevance_score": 0.8043583631515503
#     },
#     "columns": [
#       {
#         "content": "Column name: sales_reason_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del motivo de venta. NUNCA viene a NULL.Ej. Price, On Promotion, Magazine Advertisement.",
#         "relevance_score": 0.8135405480861664
#       },
#       {
#         "content": "Column name: sales_reason_reason_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo del motivo de venta. NUNCA viene a NULL. Ej. Other, Promotion, Marketing.",
#         "relevance_score": 0.8016178607940674
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_promotion\nTable description: Tabla de dimensión que almacena la información detallada de las diferentes promociones / descuentos que pueden aplicarse a las ventas. Relevante cuando se quiere segmentar las promociones que han sido aplicadas en las ventas.\nTable PRIMARY KEY:\n- promotion_key",
#       "relevance_score": 0.8031019866466522
#     },
#     "columns": [
#       {
#         "content": "Column name: max_qty\nColumn data type: INT4\nColumn description: Cantidad máxima a la que será aplicable la promoción. En caso de venir a NULL, significa que no hay límite.",
#         "relevance_score": 0.8087416291236877
#       },
#       {
#         "content": "Column name: min_qty\nColumn data type: INT4\nColumn description: Cantidad mínima necesaria para aplicar la promoción. NUNCA será NULL.",
#         "relevance_score": 0.8086340129375458
#       },
#       {
#         "content": "Column name: spanish_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (ESPAÑOL). NUNCA será NULL. Ej. Sin descuento, Descuento por volumen, Descuento de temporada.",
#         "relevance_score": 0.806676834821701
#       },
#       {
#         "content": "Column name: english_promotion_type\nColumn data type: VARCHAR(50)\nColumn description: Tipo de promoción (INGLÉS). NUNCA será NULL. Ej. No Discount, Volume Discount, Seasonal Discount.",
#         "relevance_score": 0.8057229220867157
#       },
#       {
#         "content": "Column name: english_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (INGLÉS). NUNCA será NULL. Indica si es aplicable a un distribuidor (Reseller) o a un cliente final (Customer).",
#         "relevance_score": 0.8036239445209503
#       },
#       {
#         "content": "Column name: english_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (INGLÉS). NUNCA será NULL.",
#         "relevance_score": 0.8027088642120361
#       },
#       {
#         "content": "Column name: spanish_promotion_category\nColumn data type: VARCHAR(50)\nColumn description: Categoría de la promoción (ESPAÑOL). NUNCA será NULL. Indica si es aplicable a un distribuidor (Distribuidor) o a un cliente final (Cliente).",
#         "relevance_score": 0.8024724125862122
#       },
#       {
#         "content": "Column name: spanish_promotion_name\nColumn data type: VARCHAR(255)\nColumn description: Nombre de la promoción (ESPAÑOL). NUNCA será NULL.",
#         "relevance_score": 0.8012619018554688
#       },
#       {
#         "content": "Column name: start_date\nColumn data type: DATE\nColumn description: Fecha en la que comienza a ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#         "relevance_score": 0.7987690567970276
#       },
#       {
#         "content": "Column name: discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicable a la promoción, en decimal. Comprendido entre 0 y 1. NUNCA será NULL. Ej. 0, 0.02, 0.05.",
#         "relevance_score": 0.7987129092216492
#       },
#       {
#         "content": "Column name: end_date\nColumn data type: DATE\nColumn description: Fecha en la que deja de ser válida la promoción. En caso de venir a NULL, su vigencia es ilimitada.",
#         "relevance_score": 0.7963288426399231
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_reseller\nTable description: Tabla de dimensión que almacena la información detallada de cada tienda/distribuidor. Relevante siempre que se pida obtener listado con datos de tiendas/distribuidores porque en esta tabla se almacenan sus nombres.\nTable PRIMARY KEY:\n- reseller_key\nTable FOREIGN KEYS (Column name, Reference):\n- (geography_key, sales.dim_geography.geography_key)",
#       "relevance_score": 0.8029375076293945
#     },
#     "columns": [
#       {
#         "content": "Column name: last_order_year\nColumn data type: INT4\nColumn description: Año de última compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#         "relevance_score": 0.8174338936805725
#       },
#       {
#         "content": "Column name: reseller_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre de la tienda / distribuidor.",
#         "relevance_score": 0.8164613842964172
#       },
#       {
#         "content": "Column name: order_frequency\nColumn data type: BPCHAR(1)\nColumn description: Frecuencia con la que se espera que compre un distribuidor. A=Anually(Anual), S=Semestrally(Semestral), Q=Quaterlly(Trimestral).",
#         "relevance_score": 0.8150111138820648
#       },
#       {
#         "content": "Column name: first_order_year\nColumn data type: INT4\nColumn description: Año de primera compra del distribuidor. Si viene a NULL es que nunca ha comprado.",
#         "relevance_score": 0.8124534487724304
#       },
#       {
#         "content": "Column name: business_type\nColumn data type: VARCHAR(20)\nColumn description: Tipo de negocio / tienda del que se trata. Ej. Value Added Reseller, Specialty Bike Shop, Warehouse",
#         "relevance_score": 0.8073215186595917
#       },
#       {
#         "content": "Column name: number_employees\nColumn data type: INT4\nColumn description: Cantidad de empleados de la tienda / distribuidor.",
#         "relevance_score": 0.8055285215377808
#       },
#       {
#         "content": "Column name: product_line\nColumn data type: VARCHAR(50)\nColumn description: Línea de productos en la que se especializa el distribuidor. Ej. Road, Mountain, Touring.",
#         "relevance_score": 0.8032395839691162
#       },
#       {
#         "content": "Column name: year_opened\nColumn data type: NUMERIC\nColumn description: Año de apertura de la tienda / distribuidor.",
#         "relevance_score": 0.8026675879955292
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_territory\nTable description: Tabla de dimensión que almacena la información detallada de cada cada división territorial de ventas. Relevante cuando se quieren hacer análisis de venta a nivel territorial.\nTable PRIMARY KEY:\n- sales_territory_key",
#       "relevance_score": 0.7996747493743896
#     },
#     "columns": [
#       {
#         "content": "Column name: sales_territory_country\nColumn data type: VARCHAR(50)\nColumn description: País al que corresponde cada territorio de ventas. Ej. United States, France.",
#         "relevance_score": 0.8017082214355469
#       },
#       {
#         "content": "Column name: sales_territory_group\nColumn data type: VARCHAR(50)\nColumn description: Agrupación territorial a la que pertenece cada territorio de ventas. Ej. North America, Europe.",
#         "relevance_score": 0.798997312784195
#       },
#       {
#         "content": "Column name: sales_territory_region\nColumn data type: VARCHAR(50)\nColumn description: Región a la que corresponde cada territorio de ventas, contextualizado dentro de cada country. En caso de que no haya región, será el propio country. Ej. Southeast, France.",
#         "relevance_score": 0.7961283922195435
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_sales_person\nTable description: Tabla de dimensión que almacena la información detallada de cada vendedor. Relevante cuando se nos pide sacar información relativa a las ventas que ha hecho cada vendedor, ya que en esta tabla se tiene el nombre de cada uno.\nTable PRIMARY KEY:\n- employee_key",
#       "relevance_score": 0.7995401322841644
#     },
#     "columns": [
#       {
#         "content": "Column name: gender\nColumn data type: BPCHAR(1)\nColumn description: Género del vendedor. F=Female(Mujer), M=Male(Hombre)",
#         "relevance_score": 0.8097613155841827
#       },
#       {
#         "content": "Column name: employee_full_name\nColumn data type: TEXT\nColumn description: Nombre/s y apellido/s del vendedor.",
#         "relevance_score": 0.8071203827857971
#       },
#       {
#         "content": "Column name: title\nColumn data type: VARCHAR(50)\nColumn description: Título que ese vendedor tiene dentro de la compañía como empleado.",
#         "relevance_score": 0.8020831942558289
#       },
#       {
#         "content": "Column name: sales_person_flag\nColumn data type: BOOL\nColumn description: Indicador que se trata de un empleado vendedor. SIEMPRE vendrá a true.",
#         "relevance_score": 0.7972428798675537
#       }
#     ]
#   },
#   {
#     "table_summary": {
#       "content": "Database: adventure_works_dw\nSchema: sales\nTable: dim_geography\nTable description: Tabla de dimensión que almacena información detallada sobre datos geográficos. Relevante cuando se desea analizar información desglosada a nivel ciudades, códigos postales, estados, países, etc.\nTable PRIMARY KEY:\n- geography_key\nTable FOREIGN KEYS (Column name, Reference):\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)",
#       "relevance_score": 0.7987412214279175
#     },
#     "columns": [
#       {
#         "content": "Column name: city\nColumn data type: VARCHAR(30)\nColumn description: Nombre de la ciudad.",
#         "relevance_score": 0.7981808185577393
#       },
#       {
#         "content": "Column name: english_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (INGLÉS).",
#         "relevance_score": 0.7949206829071045
#       },
#       {
#         "content": "Column name: state_province_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del estado/provincia.",
#         "relevance_score": 0.7939504086971283
#       },
#       {
#         "content": "Column name: postal_code\nColumn data type: VARCHAR(15)\nColumn description: Código postal",
#         "relevance_score": 0.7914683818817139
#       },
#       {
#         "content": "Column name: spanish_country_region_name\nColumn data type: VARCHAR(50)\nColumn description: Nombre del país (ESPAÑOL).",
#         "relevance_score": 0.7902377545833588
#       },
#       {
#         "content": "Column name: state_province_code\nColumn data type: VARCHAR(3)\nColumn description: Código del estado/provincia.",
#         "relevance_score": 0.7893475592136383
#       },
#       {
#         "content": "Column name: country_region_code\nColumn data type: VARCHAR(3)\nColumn description: Código del país.",
#         "relevance_score": 0.7884238064289093
#       }
#     ]
#   }
# ]

# %%
print(relevant_columns)
# Out:
# [{'table_summary': {'content': 'Database: adventure_works_dw\nSchema: sales\nTable: fact_sales\nTable description: Tabla de hechos que contiene el detalle de las ordenes de ventas que ya han sido entregadas, con una granularidad a nivel de línea, mostrando siempre la última versión de cada pedido. SIEMPRE que se soliciten datos de ventas, como cantidades vendidas, importe de ventas, costes de ventas, impuestos, costes de envío, deberán ser obtenidos de esta tabla. Permite hacer desgloses a nivel de productos, clientes, tiendas/distribuidores, división territorial, promociones aplicadas y vendedores involucrados.\nTable PRIMARY KEY:\n- sales_order_number\n- sales_order_line_number\nTable FOREIGN KEYS (Column name, Reference):\n- (product_key, sales.dim_product.product_key)\n- (reseller_key, sales.dim_reseller.reseller_key)\n- (employee_key, sales.dim_sales_person.employee_key)\n- (customer_key, sales.dim_customer.customer_key)\n- (promotion_key, sales.dim_promotion.promotion_key)\n- (sales_territory_key, sales.dim_sales_territory.sales_territory_key)', 'relevance_score': 0.8164841830730438}, 'columns': [{'content': 'Column name: order_quantity\nColumn data type: INT2\nColumn description: Cantidad vendida de cada producto.', 'relevance_score': 0.8307240903377533}, {'content': 'Column name: unit_price\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de cada unidad de producto.', 'relevance_score': 0.8191922307014465}, {'content': 'Column name: extended_amount\nColumn data type: NUMERIC\nColumn description: Precio de venta en USD de todas las unidades de producto. Se calcula como `order_quantity * unit_price`.', 'relevance_score': 0.8191659450531006}, {'content': 'Column name: sale_source\nColumn data type: TEXT\nColumn description: Indicador de la fuente por la que ha sido realizado el pedido. reseller_sales=Pedido realizado por un vendedor para una tienda/distribuidor, internet_sales=Pedido realizado en línea por un cliente.', 'relevance_score': 0.8173243403434753}, {'content': 'Column name: order_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué creado.', 'relevance_score': 0.8153335452079773}, {'content': 'Column name: freight\nColumn data type: NUMERIC\nColumn description: Coste de envío en USD atribuíble a cada línea de orden de venta. Se reparte el total del coste de envío del pedido proporcionalmente al `sales_amount` de cada una de sus líneas.', 'relevance_score': 0.8134251534938812}, {'content': 'Column name: ship_date\nColumn data type: DATE\nColumn description: Fecha en la que se envió el pedido al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.', 'relevance_score': 0.8132243752479553}, {'content': 'Column name: sales_amount\nColumn data type: NUMERIC\nColumn description: Subtotal en USD de la línea de orden de venta. Se calcula como `extended_amount - discount_amount`.', 'relevance_score': 0.8120576441287994}, {'content': 'Column name: total_product_cost\nColumn data type: NUMERIC\nColumn description: Coste estándar en USD de todas las unidades de producto. Se calcula como `order_quantity * product_standard_cost`.', 'relevance_score': 0.8111945390701294}, {'content': 'Column name: due_date\nColumn data type: DATE\nColumn description: Fecha en la que el pedido fué entregado al cliente. NUNCA vendrá a NULL, dado que se trata de todos pedidos que ya han sido entregados.', 'relevance_score': 0.8065207004547119}, {'content': 'Column name: unit_price_discount_pct\nColumn data type: FLOAT8\nColumn description: Porcentaje de descuento aplicado sobre el precio unitario del producto. Está indicado en decimal, es decir, su rango va de 0 a 1.', 'relevance_score': 0.8065106868743896}, {'content': 'Column name: discount_amount\nColumn data type: FLOAT8\nColumn description: Importe total de descuento en USD. Se calcula como `extended_amount * unit_price_discount_pct`.', 'relevance_score': 0.8064069747924805}, {'content': 'Column name: ta ...

# %%
llm = AzureChatOpenAI(model='gpt-4o-mini', temperature=0)

SYSTEM_PROMPT = """
You are a context summarizer that receives retrieval documents in JSON format.
Your role is to:

1. Analyze the given JSON documents carefully.
2. Identify and extract only the information relevant to answer the user's question.
3. Summarize relevant tables, columns, keys, and descriptions into a clear and concise text.
4. Exclude any irrelevant or low-relevance details.
5. Ensure factual accuracy; do not fabricate information.
6. Do NOT generate or suggest any SQL queries.
7. When it is possible, match the language of the query fields to the user's query. For example, if user's query is in spanish, use `spanish_...`.
8. Match the language of the summary to the user's query.

Input:
- Retrieval documents (JSON): {retrieval_documents}

Output:
- A concise summary of relevant context—focused on tables, columns, keys, and descriptions—that will help generate an accurate SQL query. Don't suggest any query, only bring information in plain text. 
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", "{user_query}")
])

summarizer_chain = prompt | llm | StrOutputParser()

contexto_resumido = summarizer_chain.invoke({
    'user_query': QUERY,
    'retrieval_documents': json.dumps(relevant_columns, ensure_ascii=False)
})

Markdown(contexto_resumido)
# Out:
# Para obtener información sobre los 10 artículos más comprados, se pueden considerar las siguientes tablas y columnas relevantes de la base de datos `adventure_works_dw` en el esquema `sales`:
#
# 1. **Tabla: fact_sales**
#    - **Descripción**: Contiene el detalle de las órdenes de ventas entregadas, con granularidad a nivel de línea.
#    - **Claves Primarias**:
#      - `sales_order_number`
#      - `sales_order_line_number`
#    - **Columnas relevantes**:
#      - `order_quantity`: Cantidad vendida de cada producto.
#      - `product_key`: Clave del producto (relacionada con la tabla `dim_product`).
#
# 2. **Tabla: dim_product**
#    - **Descripción**: Almacena información detallada de cada producto vendido.
#    - **Clave Primaria**:
#      - `product_key`
#    - **Columnas relevantes**:
#      - `english_product_name`: Nombre del producto (en inglés).
#      - `spanish_product_name`: Nombre del producto (en español).
#      - `list_price`: Precio de venta del producto en USD.
#
# Para realizar un análisis sobre los artículos más comprados, se utilizarían principalmente las columnas `order_quantity` de la tabla `fact_sales` y `product_key` para relacionar con la tabla `dim_product`, donde se puede obtener el nombre y precio de los productos.

# %% [markdown]
# #### Conclusiones e Implementación Final
#
# Como podemos ver, siguiendo el mismo proceso para ambos modelos de embeddings, el modelo `gemini-embedding-001` de Google, aunque parece devolver resultados similares que los que se obtienen con `text-embedding-3-small` de OpenAI, consigue mejores resultados en términos de relevancia. Esto nos hace pensar que es mejor al capturar la semántica de nuestro documentos frente a la de las consultas.
#
# Esto puede deberse, en gran medida, a que , aunque ambos modelos presentan un **tamaño de embeddings de 3072**, el modelo de Google presenta un rendimiento destacable en tareas multilingües, como puede apreciarse en el [paper de su presentación](https://arxiv.org/html/2503.07891v1). Este es un punto no menor al trabajar nuestra documentación, ya que la misma mezcla conceptos en inglés (nombres de tablas y campos) y en español (descripciones), como asi también al momento de consultar, que podrá hacerse en cualquiera de estos 2 idiomas de manera indistinta.
#
# Teniendo en cuenta estas conclusiones, finalmente, **procedemos a implementar nuestras colecciones de `Chroma DB` de manera definitiva usando el modelo `gemini-embedding-001`**.

# %%
chroma_client = chromadb.PersistentClient(path= CHROMA_DB_PATH)
genai_embeddings = GenAIExtendedEmbeddingFunction(GENAI_EMBEDDING_MODEL)


with open(MDL_PATH, 'r', encoding='utf-8') as mdl_file:
    mdl_data = yaml.safe_load(mdl_file)


tables_summary_chunks = chunk_mdl_by_table_summary(mdl_data)
if tables_summary_chunks:
    try:
        chroma_client.delete_collection(TABLES_SUMMARY_COLLECTION_NAME)
    except:
        pass

    tables_summary_collection = Chroma(
        client= chroma_client,
        collection_name= TABLES_SUMMARY_COLLECTION_NAME,
        embedding_function= genai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(tables_summary_chunks, tables_summary_collection)


columns_chunks = chunk_mdl_by_column(mdl_data)
if columns_chunks:
    try:
        chroma_client.delete_collection(COLUMNS_COLLECTION_NAME)
    except:
        pass

    columns_collection = Chroma(
        client= chroma_client,
        collection_name= COLUMNS_COLLECTION_NAME,
        embedding_function= genai_embeddings,
        collection_configuration= {'hnsw': {'space': 'cosine'}},
        create_collection_if_not_exists= True
    )

    add_docs_to_chroma_col(columns_chunks, columns_collection)

# %% [markdown]
# ## Fichero MarkDown con Reglas de Negocio

# %% [markdown]
# ## Fichero JSON con Ejemplos de Consultas
